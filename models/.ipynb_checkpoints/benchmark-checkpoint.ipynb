# %% [markdown]
# # preparation

# %%
import pandas as pd
import numpy as np

#モデル
import lightgbm as lgb

#パラメータ探索
import optuna

#クロスバリデーション
from sklearn.model_selection import KFold

#エヴァリュエーション
from sklearn.metrics import precision_score, recall_score, mean_squared_error

#可視化
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

#保存
import pickle

# %%
#データを読み込む
uma_race_df = pd.read_pickle('../datasets/traindata/uma_race.pkl')
payout_df = pd.read_pickle('../datasets/traindata/payout.pkl')
n_payout_df = pd.read_pickle('../datasets/traindata/n_payout.pkl')

# %%
#データを結合する
payout_df = pd.concat([payout_df, n_payout_df], axis=0).reset_index(drop=True)

# %% [markdown]
# ### データの削除

# %%
#海外のレースを削除
uma_race_df['keibajo_code'] = pd.to_numeric(uma_race_df['keibajo_code'], errors='coerce')
uma_race_df = uma_race_df.dropna(subset=['keibajo_code'])
uma_race_df['keibajo_code']  = uma_race_df['keibajo_code'] .astype(int)

#レースに参加できていない競走馬を削除
uma_race_df= uma_race_df[uma_race_df['kakutei_chakujun'] != 0]

# %% [markdown]
# # LightGBM

# %% [markdown]
# ## グループクエリ用のカラムを作成

# %%
# 新しいグループを作成
uma_race_df['group'] = uma_race_df['kaisai_nen'].astype(str) +"-"+ uma_race_df['kaisai_tsukihi'].astype(str) +"-"+  uma_race_df['keibajo_code'].astype(str) +"-"+  uma_race_df['race_bango'].astype(str)
payout_df['group'] = payout_df['kaisai_nen'].astype(str) +"-"+ payout_df['kaisai_tsukihi'].astype(str) +"-"+  payout_df['keibajo_code'].astype(str) +"-"+  payout_df['race_bango'].astype(str)

# %% [markdown]
# ## LightGBM

# %% [markdown]
# ### テスト用と学習用のデータに分け、モデルを作成

# %%
# 2010年から2019年のデータを学習データとして取得
train_data = uma_race_df[uma_race_df['kaisai_nen'].isin([2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019])]

# ランキング学習のために必要な特徴量とターゲットを設定
features = [
            'kaisai_nen',
            'kaisai_tsukihi',
            'keibajo_code',
            # 'kaisai_kai',
            # 'kaisai_nichime',
            'race_bango',
            'wakuban',
            'umaban',
            'ketto_toroku_bango',
            # 'bamei',
            'umakigo_code',
            'seibetsu_code',
            'hinshu_code',
            'moshoku_code',
            'barei',
            'tozai_shozoku_code',
            'chokyoshi_code',
            'banushi_code',
            # 'banushimei',
            'futan_juryo',
            'blinker_shiyo_kubun',
            'kishu_code',
            # 'kishumei_ryakusho',
            'kishu_minarai_code',
            'bataiju',
            'zogen_fugo',
            'zogen_sa',
            'ijo_kubun_code',
            # 'nyusen_juni',
            ## 'kakutei_chakujun',
            # 'dochaku_kubun',
            # 'dochaku_tosu',
            # 'soha_time',
            # 'chakusa_code_1',
            # 'chakusa_code_2',
            # 'chakusa_code_3',
            # 'corner_1',
            # 'corner_2',
            # 'corner_3',
            # 'corner_4',
            # 'tansho_odds',
            # 'tansho_ninkijun',
            # 'kakutoku_honshokin',
            # 'kakutoku_fukashokin',
            # 'kohan_4f',
            # 'kohan_3f',
            # 'aiteuma_joho_1',
            # 'aiteuma_joho_2',
            # 'aiteuma_joho_3',
            # 'time_sa',
            # 'record_koshin_kubun',
            #'kyakushitsu_hantei',
            ]


target = 'kakutei_chakujun'

# LightGBM用のデータセットを作成
train_dataset = lgb.Dataset(train_data[features], label=train_data[target])

# LightGBMのパラメータを設定
params = {
    'objective': 'regression',
    'metric': 'rmse', 
    'boosting_type': 'gbdt',
    'num_leaves': 31,
    'learning_rate': 0.05,
    'feature_fraction': 0.9
}

# k=5のFOLDでデータを分割
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# 各FOLDでのモデルを保存するためのリスト
models = []

# LightGBMモデルを訓練
for train_index, valid_index in kf.split(train_data):
    train_fold_data = train_data.iloc[train_index]
    valid_fold_data = train_data.iloc[valid_index]
    
    train_dataset = lgb.Dataset(train_fold_data[features], label=train_fold_data[target])
    valid_dataset = lgb.Dataset(valid_fold_data[features], label=valid_fold_data[target])
    
    model = lgb.train(params, train_dataset, num_boost_round=1000, valid_sets=[valid_dataset], early_stopping_rounds=100, verbose_eval=100)
    models.append(model)
# Out:
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.016465 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1642
# [LightGBM] [Info] Number of data points in the train set: 635508, number of used features: 23
# [LightGBM] [Info] Start training from score 7.054953
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 3.76239
# [200]	valid_0's rmse: 3.72142
# [300]	valid_0's rmse: 3.70718
# [400]	valid_0's rmse: 3.69818
# [500]	valid_0's rmse: 3.69165
# [600]	valid_0's rmse: 3.68654
# [700]	valid_0's rmse: 3.68284
# [800]	valid_0's rmse: 3.67927
# [900]	valid_0's rmse: 3.67679
# [1000]	valid_0's rmse: 3.67446
# Did not meet early stopping. Best iteration is:
# [999]	valid_0's rmse: 3.67445
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.020520 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1633
# [LightGBM] [Info] Number of data points in the train set: 635508, number of used features: 23
# [LightGBM] [Info] Start training from score 7.055266
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 3.76951
# [200]	valid_0's rmse: 3.72919
# [300]	valid_0's rmse: 3.71449
# [400]	valid_0's rmse: 3.70657
# [500]	valid_0's rmse: 3.69934
# [600]	valid_0's rmse: 3.69454
# [700]	valid_0's rmse: 3.69106
# [800]	valid_0's rmse: 3.68702
# [900]	valid_0's rmse: 3.68393
# [1000]	valid_0's rmse: 3.68175
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 3.68175
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.021131 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1636
# [LightGBM] [Info] Number of data points in the train set: 635508, number of used features: 23
# [LightGBM] [Info] Start training from score 7.054789
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 3.77339
# [200]	valid_0's rmse: 3.73236
# [300]	valid_0's rmse: 3.71753
# [400]	valid_0's rmse: 3.70915
# [500]	valid_0's rmse: 3.70287
# [600]	valid_0's rmse: 3.69763
# [700]	valid_0's rmse: 3.69261
# [800]	valid_0's rmse: 3.68934
# [900]	valid_0's rmse: 3.68616
# [1000]	valid_0's rmse: 3.6835
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 3.6835
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.018167 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1639
# [LightGBM] [Info] Number of data points in the train set: 635508, number of used features: 23
# [LightGBM] [Info] Start training from score 7.053326
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 3.76771
# [200]	valid_0's rmse: 3.72698
# [300]	valid_0's rmse: 3.71204
# [400]	valid_0's rmse: 3.70436
# [500]	valid_0's rmse: 3.69779
# [600]	valid_0's rmse: 3.69251
# [700]	valid_0's rmse: 3.68901
# [800]	valid_0's rmse: 3.68544
# [900]	valid_0's rmse: 3.68261
# [1000]	valid_0's rmse: 3.67981
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 3.67981
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.021931 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1644
# [LightGBM] [Info] Number of data points in the train set: 635508, number of used features: 23
# [LightGBM] [Info] Start training from score 7.052467
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 3.76951
# [200]	valid_0's rmse: 3.72947
# [300]	valid_0's rmse: 3.7157
# [400]	valid_0's rmse: 3.70668
# [500]	valid_0's rmse: 3.7007
# [600]	valid_0's rmse: 3.69658
# [700]	valid_0's rmse: 3.69246
# [800]	valid_0's rmse: 3.6888
# [900]	valid_0's rmse: 3.68524
# [1000]	valid_0's rmse: 3.6828
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 3.6828

# %% [markdown]
# ### テストデータで予測

# %%
# 2020年から2022年のテストデータを取得
test_data_2020 = uma_race_df[uma_race_df['kaisai_nen'] == 2020].copy()
test_data_2021 = uma_race_df[uma_race_df['kaisai_nen'] == 2021].copy()
test_data_2022 = uma_race_df[uma_race_df['kaisai_nen'] == 2022].copy()

# 2021年と2022年のデータに対して予測を行い、平均を取る
test_data_2020.loc[:, 'y_pred'] = sum([model.predict(test_data_2020[features], num_iteration=model.best_iteration) for model in models]) / len(models)
test_data_2021.loc[:, 'y_pred'] = sum([model.predict(test_data_2021[features], num_iteration=model.best_iteration) for model in models]) / len(models)
test_data_2022.loc[:, 'y_pred'] = sum([model.predict(test_data_2022[features], num_iteration=model.best_iteration) for model in models]) / len(models)

# 予測されたランクをグループごとに計算
test_data_2020.loc[:, 'predicted_rank'] = test_data_2020.groupby('group')['y_pred'].rank(method='min')
test_data_2021.loc[:, 'predicted_rank'] = test_data_2021.groupby('group')['y_pred'].rank(method='min')
test_data_2022.loc[:, 'predicted_rank'] = test_data_2022.groupby('group')['y_pred'].rank(method='min')

# 結果を表示
test_data_2021[['group', 'predicted_rank', 'kakutei_chakujun']]
# Out:
#                   group  predicted_rank  kakutei_chakujun
# 883806   2021-101-45-10             1.0                 3
# 883807   2021-101-45-10             6.0                 6
# 883808   2021-101-45-10             5.0                 5
# 883809   2021-101-45-10             3.0                 4
# 883810   2021-101-45-10             2.0                 1
# ...                 ...             ...               ...
# 1069380  2021-1209-44-1             7.0                 9
# 1069381  2021-1209-44-1             1.0                 2
# 1069387  2021-1209-44-1             3.0                10
# 1069388   2021-902-30-5             1.0                 1
# 1069389  2021-1209-44-1             6.0                 1
#
# [71525 rows x 3 columns]

# %% [markdown]
# ## モデル評価

# %% [markdown]
# ### RMSE

# %%
# RMSEを計算
rmse_2020 = np.sqrt(mean_squared_error(test_data_2020['predicted_rank'], test_data_2020['kakutei_chakujun']))
print(f"2021 RMSE: {rmse_2020:.3%}")
rmse_2021 = np.sqrt(mean_squared_error(test_data_2021['predicted_rank'], test_data_2021['kakutei_chakujun']))
print(f"2021 RMSE: {rmse_2021:.3%}")
rmse_2022 = np.sqrt(mean_squared_error(test_data_2022['predicted_rank'], test_data_2022['kakutei_chakujun']))
print(f"2022 RMSE: {rmse_2022:.3%}")
rmse_mean = np.mean([rmse_2020, rmse_2021, rmse_2022])
print(f"Mean RMSE: {rmse_mean:.3%}")
# Out:
# 2021 RMSE: 458.986%
# 2021 RMSE: 467.215%
# 2022 RMSE: 463.303%
# Mean RMSE: 463.168%

# %% [markdown]
# ### precision@5&recall@5

# %%
#precision@5とrecall@5を計算
def precision_at_5(predictions, actual):
    top_5_predictions = predictions.argsort()[-5:][::-1]  # 予測の上位5頭のインデックス
    top_3_actual = actual.argsort()[-3:][::-1]  # 実際の上位3頭のインデックス
    common_elements = np.intersect1d(top_5_predictions, top_3_actual)  # 共通の要素を抽出
    precision = len(common_elements) / 5
    return precision

def recall_at_5(predictions, actual):
    top_5_predictions = predictions.argsort()[-5:][::-1]  # 予測の上位5頭のインデックス
    top_3_actual = actual.argsort()[-3:][::-1]  # 実際の上位3頭のインデックス
    common_elements = np.intersect1d(top_5_predictions, top_3_actual)  # 共通の要素を抽出
    recall = len(common_elements) / 3
    return recall

# %%
group_ids_2020 = test_data_2020['group'].unique()
precisions = []
recalls = []

#各レースごとでPrecision@5とRecall@5を計算
for group_id in group_ids_2020:
    test_data = test_data_2020[test_data_2020['group'] == group_id]
    p = precision_at_5(test_data['predicted_rank'].values, test_data['kakutei_chakujun'].values)
    r = recall_at_5(test_data['predicted_rank'].values, test_data['kakutei_chakujun'].values)
    precisions.append(p)
    recalls.append(r)

precision_5_2020 = np.mean(precisions)
recall_5_2020 = np.mean(recalls)

print(f"2020 Precision@5: {precision_5_2020:.3%}")
print(f"2020 Recall@5: {recall_5_2020:.3%}")


group_ids_2021 = test_data_2021['group'].unique()
precisions = []
recalls = []

#各レースごとでPrecision@5とRecall@5を計算
for group_id in group_ids_2021:
    test_data = test_data_2021[test_data_2021['group'] == group_id]
    p = precision_at_5(test_data['predicted_rank'].values, test_data['kakutei_chakujun'].values)
    r = recall_at_5(test_data['predicted_rank'].values, test_data['kakutei_chakujun'].values)
    precisions.append(p)
    recalls.append(r)

precision_5_2021 = np.mean(precisions)
recall_5_2021 = np.mean(recalls)

print(f"2021 Precision@5: {precision_5_2021:.3%}")
print(f"2021 Recall@5: {recall_5_2021:.3%}")


roup_ids_2022 = test_data_2022['group'].unique()
precisions = []
recalls = []

for group_id in roup_ids_2022:
    test_data = test_data_2022[test_data_2022['group'] == group_id]
    p = precision_at_5(test_data['predicted_rank'].values, test_data['kakutei_chakujun'].values)
    r = recall_at_5(test_data['predicted_rank'].values, test_data['kakutei_chakujun'].values)
    precisions.append(p)
    recalls.append(r)

precision_5_2022 = np.mean(precisions)
recall_5_2022 = np.mean(recalls)

print(f"2022 Precision@5: {precision_5_2022:.3%}")
print(f"2022 Recall@5: {recall_5_2022:.3%}")


precision_5_mean = np.mean([precision_5_2020, precision_5_2021, precision_5_2022])
recall_5_mean = np.mean([recall_5_2020, recall_5_2021, recall_5_2022])

print(f"Mean Precision@5: {precision_5_mean:.3%}")
print(f"Mean Recall@5: {recall_5_mean:.3%}")
# Out:
# 2020 Precision@5: 34.167%
# 2020 Recall@5: 56.944%
# 2021 Precision@5: 33.146%
# 2021 Recall@5: 55.243%
# 2022 Precision@5: 33.627%
# 2022 Recall@5: 56.046%
# Mean Precision@5: 33.647%
# Mean Recall@5: 56.078%

# %% [markdown]
# ### 収支(三連複五頭ボックス)

# %%
# 各レースごとに予測ランキング上位5頭のうち、実際の上位3頭がすべて入っているかを確認する関数
def check_top3_in_top5_predictions(group):
    predicted_top5 = group.nsmallest(5, 'y_pred').index.tolist()
    actual_top3 = group.nsmallest(3, 'kakutei_chakujun').index.tolist()
    return all([horse in predicted_top5 for horse in actual_top3])

# %%
# 各レースで上記の関数を適用
results_2020 = test_data_2020.groupby('group').apply(check_top3_in_top5_predictions)
results_2021 = test_data_2021.groupby('group').apply(check_top3_in_top5_predictions)
results_2022 = test_data_2022.groupby('group').apply(check_top3_in_top5_predictions)

# 予測モデルが成功したレースのインデックスを取得する
successful_groups_2020 = results_2020[results_2020].index
successful_groups_2021 = results_2021[results_2021].index
successful_groups_2022 = results_2022[results_2022].index

# そのインデックスを使用して、harai_dfから対応する支払倍率を取得する
successful_payout_2020 = payout_df[payout_df['group'].isin(successful_groups_2020)]
successful_payout_2021 = payout_df[payout_df['group'].isin(successful_groups_2021)]
successful_payout_2022 = payout_df[payout_df['group'].isin(successful_groups_2022)]

payouts_2020 = successful_payout_2020['haraimodoshi_sanrenpuku_1b']
payouts_2021 = successful_payout_2021['haraimodoshi_sanrenpuku_1b']
payouts_2022 = successful_payout_2022['haraimodoshi_sanrenpuku_1b']

# すべての成功したレースに対して、100円をかけた場合の支払いを計算する
total_payout_2020 = (payouts_2020).sum()
total_payout_2021 = (payouts_2021).sum()
total_payout_2022 = (payouts_2022).sum()

# 合計の支払いから、すべてのレースにかけた合計金額を引くことで、純利益を計算する
total_investment_2020 = test_data_2020['group'].nunique() * 1000
total_investment_2021 = test_data_2021['group'].nunique() * 1000
total_investment_2022 = test_data_2021['group'].nunique() * 1000

net_profit_2020 = total_payout_2020 - total_investment_2020
net_profit_2021 = total_payout_2021 - total_investment_2021
net_profit_2022 = total_payout_2022 - total_investment_2022

average_net_profit_2020 = net_profit_2020/len(test_data_2020)
average_net_profit_2021 = net_profit_2021/len(test_data_2021)
average_net_profit_2022 = net_profit_2020/len(test_data_2022)

print(f"2020 Average Net Profit: {average_net_profit_2020:.3f} yen")
print(f"2021 Average Net Profit: {average_net_profit_2021:.3f} yen")
print(f"2022 Average Net Profit: {average_net_profit_2022:.3f} yen")

mean_average_net_profit = np.mean([average_net_profit_2020, average_net_profit_2021, average_net_profit_2022])
print(f"Mean Average Net Profit: {mean_average_net_profit:.3f} yen")
# Out:
# 2020 Average Net Profit: -22.670 yen
# 2021 Average Net Profit: -31.640 yen
# 2022 Average Net Profit: -23.105 yen
# Mean Average Net Profit: -25.805 yen

# %%
# 1. 各レースごとに予測ランキング上位5頭のうち、実際の上位3頭がすべて入っているかを確認する関数
def check_top3_in_top5_predictions(group):
    predicted_top5 = group.nsmallest(5, 'y_pred').index.tolist()
    actual_top3 = group.nsmallest(3, 'kakutei_chakujun').index.tolist()
    return all([horse in predicted_top5 for horse in actual_top3])

# 2. 各グループの利益を計算する関数
def calculate_group_profit(group):
    if check_top3_in_top5_predictions(group):
        payout_value = group['haraimodoshi_sanrenpuku_1b'].iloc[0]
        return payout_value - 1000
    else:
        return -1000

# 3. 各テストデータに対して利益を計算し、新しいカラムとして追加
for test_data in [test_data_2020, test_data_2021, test_data_2022]:
    # test_dataとpayout_dfをマージ
    merged_data = pd.merge(test_data, payout_df[['group', 'haraimodoshi_sanrenpuku_1b']], on='group', how='left')
    profits = merged_data.groupby('group').apply(calculate_group_profit).reset_index()
    profits.columns = ['group', 'profit']
    test_data = pd.merge(test_data, profits, on='group', how='left')

# %% [markdown]
# ### 予測を見る

# %%
# # ```
# # すべての予測を見たい時用（処理時間かかる）
# # ```

# #グループごとの予測値と実際値を見てみる
# for group_id in group_ids_2021:
#     test_data = test_data_2021[test_data_2021['group'] == group_id]
#     sorted_test_data = test_data.sort_values(by='kakutei_chakujun')
#     print(sorted_test_data[['group', 'predicted_rank', 'kakutei_chakujun']])

# %% [markdown]
# # モデル保存

# %%
# モデルを保存
with open('bestmodels/benchmark.pkl', 'wb') as f:
    pickle.dump(models, f)

# %% [markdown]
# # 分析

# %%
# models[0]の特徴量の重要度を取得
feature_importance = models[0].feature_importance(importance_type='gain')

# 特徴量の名前と重要度をDataFrameに変換
importance_df = pd.DataFrame({
    'Feature': features,
    'Importance': feature_importance
})

# 重要度の降順にソート
importance_df = importance_df.sort_values(by='Importance', ascending=False)

# プロット
plt.figure(figsize=(10, 8))
sns.barplot(data=importance_df, x='Importance', y='Feature')
plt.title('Feature Importance')
plt.tight_layout()
plt.show()

# %%
# 予測ランキングの上位5頭を1、それ以外を0とする
test_data_2021.loc[:, 'predicted_top5'] = test_data_2021.groupby('group')['y_pred'].rank(ascending=True).apply(lambda x: 1 if x <= 5 else 0)

# 実際のランキングの上位3頭を1、それ以外を0とする
test_data_2021.loc[:, 'actual_top3'] = test_data_2021['kakutei_chakujun'].apply(lambda x: 1 if x <= 3 else 0)

# Confusion Matrixを計算
cm = confusion_matrix(test_data_2021['actual_top3'], test_data_2021['predicted_top5'])

# Confusion Matrixを表示
x_label = ['Not Top 5', 'Top 5']
y_label = ['Not Top 3', 'Top 3']
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=x_label, yticklabels=y_label)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

# %%
#正解したレースの特徴を調べる

# %%
successful_groups = test_data_2021.groupby('group').apply(check_top3_in_top5_predictions)
successful_races = test_data_2021[test_data_2021['group'].isin(successful_groups[successful_groups].index)]

# %%
successful_races
# Out:
#         kaisai_nen  kaisai_tsukihi  keibajo_code  kaisai_kai  kaisai_nichime  \
# 883806        2021             101            45          12               1
# 883807        2021             101            45          12               1
# 883808        2021             101            45          12               1
# 883809        2021             101            45          12               1
# 883810        2021             101            45          12               1
# ...            ...             ...           ...         ...             ...
# 956269        2021            1231            50          21               3
# 956270        2021            1231            50          21               3
# 956271        2021            1231            50          21               3
# 956272        2021            1231            50          21               3
# 956273        2021            1231            50          21               3
#
#         race_bango  wakuban  umaban  ketto_toroku_bango               bamei  \
# 883806          10        1       1          2016105658  アイオロス
# 883807          10        2       2          2017100660  ポピュラーソング
# 883808          10        3       3          2013101325  モンスターキング
# 883809          10        4       4          2016100496  アルネゴー
# 883810          10        5       5          2015101657  シカゴジャズ
# ...            ...      ...     ...                 ...                 ...
# 956269           8        6       8          2018106503  ドラマティコ
# 956270           8        7       9          2018100467  メイショウヨサレ
# 956271           8        7      10          2018104420  ベストインクラス
# 956272           8        8      11          2018106609  プレカーリー
# 956273           8        8      12          2018106231  ゴールドマイヤー
#
#         ...                aiteuma_joho_2                aiteuma_joho_3  \
# 883806  ...  0000000000　　　　　　　　　　　　　　　　　　  0000000000
# 883807  ...  0000000000　　　　　　　　　　　　　　　　　　  0000000000
# 883808  ...  0000000000　　　　　　　　　　　　　　　　　　  0000000000
# 883809  ...  0000000000　　　　　　　　　　　　　　　　　　  0000000000
# 883810  ...  0000000000　　　　　　　　　　　　　　　　　　  0000000000
# ...     ...                           ...                           ...
# 956269  ...  0000000000　　　　　　　　　　　　　　　　　　  0000000000
# 956270  ...  0000000000　　　　　　　　　　　　　　　　　　  0000000000
# 956271  ...  0000000000　　　　　　　　　　　　　　　　　　  0000000000
# 956272  ...  0000000000　　　　　　　　　　　　　　　　　　  0000000000
# 956273  ...  0000000000　　　　　　　　　　　　　　　　　　  0000000000
#
#         time_sa  record_koshin_kubun  kyakushitsu_hantei           group  \
# 883806        7                    0                   1  2021-101-45-10
# 883807       35                    0                   4  2021-101-45-10
# 883808       26                    0                   2  2021-101-45-10
# 883809       21                    0                   4  2021-101-45-10
# 883810       -4                    0                   1  2021-101-45-10
# ...         ...                  ...                 ...             ...
# 956269        8                    0                   3  2021-1231-50-8
# 956270        7                    0                   2  2021-1231-50-8
# 956271        4                    0                   2  2021-1231-50-8
# 956272       18                    0                   4  2021-1231-50-8
# 956273        6                    0                   3  2021-1231-50-8
#
#           y_pred  predicted_rank predicted_top5  actual_top3
# 883806  5.667301             1.0              1            1
# 883807  7.050420             6.0              0            0
# 883808  6.916133             5.0              1            0
# 883809  5.983292             3.0              1            0
# 883810  5.797060             2.0              1            1
# ...          ...             ...            ...          ...
# 956269  6.339185             8.0              0            0
# 956270  6.776335            11.0              0            0
# 956271  4.873211             2.0              1            1
# 956272  6.504713             9.0              0            0
# 956273  5.706946             6.0              0            0
#
# [10697 rows x 57 columns]

# %%
# 全体のJyoCDの分布を取得
total_counts = test_data_2021['keibajo_code'].value_counts()

# successful_racesの中のJyoCDの分布を取得
success_counts = successful_races['keibajo_code'].value_counts()

# 正解したレースの割合を計算
success_ratio = success_counts / total_counts

# データを双方向の棒グラフで可視化
labels = success_ratio.index
x = np.arange(len(labels))
width = 0.35

fig, ax1 = plt.subplots(figsize=(15, 7))

color = 'tab:blue'
ax1.set_xlabel('keibajo_code')
ax1.set_ylabel('Success Ratio', color=color)
ax1.bar(x - width/2, success_ratio, width, color=color, label='Success Ratio')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_xticks(x)
ax1.set_xticklabels(labels, rotation=45)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Total Races', color=color)
ax2.bar(x + width/2, total_counts, width, color=color, label='Total Races')
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()
plt.title('Success Ratio and Total Races by keibajo_code')
plt.show()

# %%
# 各競馬場での成功したレースの支払いを合計
total_payouts = successful_payout_2021.groupby('keibajo_code')['haraimodoshi_sanrenpuku_1b'].sum()

# 各競馬場での投資額を計算
total_investments = test_data_2021['keibajo_code'].value_counts() * 1000

# 各競馬場での純利益を計算
net_profits = total_payouts - total_investments 

# データを棒グラフで可視化
net_profits.sort_values(ascending=False).plot(kind='bar', figsize=(12, 6), color='lightcoral')
plt.title('Net Profit by keibajo_code')
plt.xlabel('keibajo_code')
plt.ylabel('Net Profit')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
total_payouts
# Out:
# keibajo_code
# 1     167220.0
# 2      79100.0
# 3     102620.0
# 4     260710.0
# 5     325100.0
# 6     359260.0
# 7     519610.0
# 9     349980.0
# 10    310430.0
# 30    162320.0
# 35     49170.0
# 36     70070.0
# 42     39570.0
# 43     21710.0
# 44     58200.0
# 45     36660.0
# 46     59050.0
# 47     50880.0
# 48    188270.0
# 50    226290.0
# 51     38310.0
# 54     21430.0
# 55     33000.0
# Name: haraimodoshi_sanrenpuku_1b, dtype: float64

# %%
total_investments
# Out:
# keibajo_code
# 9     8223000
# 5     7534000
# 6     7290000
# 7     7260000
# 4     6182000
# 10    4909000
# 50    4349000
# 48    3562000
# 30    3056000
# 1     2133000
# 3     2086000
# 2     1859000
# 44    1697000
# 46    1531000
# 45    1516000
# 51    1475000
# 35    1314000
# 43    1243000
# 55    1059000
# 47     922000
# 54     871000
# 36     799000
# 42     655000
# Name: count, dtype: int64

# %%
net_profits
# Out:
# keibajo_code
# 1    -1965780.0
# 2    -1779900.0
# 3    -1983380.0
# 4    -5921290.0
# 5    -7208900.0
# 6    -6930740.0
# 7    -6740390.0
# 9    -7873020.0
# 10   -4598570.0
# 30   -2893680.0
# 35   -1264830.0
# 36    -728930.0
# 42    -615430.0
# 43   -1221290.0
# 44   -1638800.0
# 45   -1479340.0
# 46   -1471950.0
# 47    -871120.0
# 48   -3373730.0
# 50   -4122710.0
# 51   -1436690.0
# 54    -849570.0
# 55   -1026000.0
# dtype: float64

# %%
def objective(trial):
    # Optunaで調整するパラメータを設定
    params = {
        'objective': 'regression',
        'metric': 'rmse',
        'boosting_type': 'gbdt',
        'num_leaves': trial.suggest_int('num_leaves', 2, 256),
        'learning_rate': trial.suggest_float('learning_rate', 1e-4, 1e-1, log=True),
        'feature_fraction': trial.suggest_float('feature_fraction', 0.4, 1.0),
    }
    
    # k=5のFOLDでデータを分割
    kf = KFold(n_splits=5, shuffle=True, random_state=42)
    
    # 各FOLDでの評価値を保存するためのリスト
    rmses = []
    
    # LightGBMモデルを訓練
    for train_index, valid_index in kf.split(train_data):
        train_fold_data = train_data.iloc[train_index]
        valid_fold_data = train_data.iloc[valid_index]
        
        train_dataset = lgb.Dataset(train_fold_data[features], label=train_fold_data[target])
        valid_dataset = lgb.Dataset(valid_fold_data[features], label=valid_fold_data[target])
        
        model = lgb.train(params, train_dataset, num_boost_round=1000, valid_sets=[valid_dataset], early_stopping_rounds=100, verbose_eval=100)
        
        # RMSEを計算して保存
        y_pred = model.predict(valid_fold_data[features])
        rmse = np.sqrt(mean_squared_error(valid_fold_data[target], y_pred))
        rmses.append(rmse)
    
    # 5-FOLDの平均RMSEを返す
    return np.mean(rmses)

# Optunaでのパラメータ探索を実行
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=10)

# 最適なパラメータ
best_params = study.best_params
best_params['metric'] = 'rmse'  # ここでmetricを追加

# KFoldでのモデル訓練
kf = KFold(n_splits=5, shuffle=True, random_state=42)
models = []

for train_index, valid_index in kf.split(train_data):
    train_fold_data = train_data.iloc[train_index]
    valid_fold_data = train_data.iloc[valid_index]
    
    train_dataset = lgb.Dataset(train_fold_data[features], label=train_fold_data[target])
    valid_dataset = lgb.Dataset(valid_fold_data[features], label=valid_fold_data[target])
    
    model = lgb.train(best_params, train_dataset, num_boost_round=500, valid_sets=[valid_dataset], early_stopping_rounds=20, verbose_eval=100)  # ここでearly_stopping_roundsを50に変更
    models.append(model)
# Out:
# [I 2023-09-26 12:14:50,291] A new study created in memory with name: no-name-43d3120b-f7c7-44b9-b049-e9aa03d97896
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.095648 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1642
# [LightGBM] [Info] Number of data points in the train set: 635508, number of used features: 23
# [LightGBM] [Info] Start training from score 7.054953
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 4.14112
# [200]	valid_0's rmse: 4.13438
# [300]	valid_0's rmse: 4.12781
# [400]	valid_0's rmse: 4.12135
# [500]	valid_0's rmse: 4.11501
# [600]	valid_0's rmse: 4.10882
# [700]	valid_0's rmse: 4.10275
# [800]	valid_0's rmse: 4.0968
# [900]	valid_0's rmse: 4.09101
# [1000]	valid_0's rmse: 4.08534
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse:
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 3.68559
# [200]	valid_0's rmse: 3.66443
# [300]	valid_0's rmse: 3.65299
# [400]	valid_0's rmse: 3.64375
# [500]	valid_0's rmse: 3.63891
# [600]	valid_0's rmse: 3.63418
# [700]	valid_0's rmse: 3.63091
# [800]	valid_0's rmse: 3.62639
# [900]	valid_0's rmse: 3.62424
# [1000]	valid_0's rmse: 3.62152
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 3.62152
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012142 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1644
# [LightGBM] [Info] Number of data points in the train set: 635508, number of used features: 23
# [LightGBM] [Info] Start training from score 7.052467
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 3.68938
# [200]	valid_0's rmse: 3.669
# [300]	valid_0's rmse: 3.65823
# [400]	valid_0's rmse: 3.64877
# [500]	valid_0's rmse: 3.64163
# [600]	valid_0's rmse: 3.63642
# [700]	valid_0's rmse: 3.63258
# [800]	valid_0's rmse: 3.62916
# [900]	valid_0's rmse: 3.62586
# [1000]	valid_0's rmse: 3.62444
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 3.62444
# [I 2023-09-26 12:48:48,253] Trial 9 finished with value: 3.620507534524679 and parameters: {'num_leaves': 198, 'learning_rate': 0.09647776897929414, 'feature_fraction': 0.5802731030133007}. Best is trial 9 with value: 3.620507534524679.
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.015407 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1642
# [LightGBM] [Info] Number of data points in the train set: 635508, number of used features: 23
# [LightGBM] [Info] Start training from score 7.054953
# Training until validation scores don't improve for 20 rounds
# [100]	valid_0's rmse: 3.67912
# [200]	valid_0's rmse: 3.65983
# [300]	valid_0's rmse: 3.6481
# [400]	valid_0's rmse: 3.63802
# [500]	valid_0's rmse: 3.63186
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's rmse: 3.63186
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013765 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1633
# [LightGBM] [Info] Number of data points in the train set: 635508, number of used features: 23
# [LightGBM] [Info] Start training from score 7.055266
# Training until validation scores don't improve for 20 rounds
# [100]	valid_0's rmse: 3.68762
# [200]	valid_0's rmse: 3.66617
# [300]	valid_0's rmse: 3.654
# [400]	valid_0's rmse: 3.64298
# [500]	valid_0's rmse: 3.63736
# Did not meet early stopping. Best iteration is:
# [491]	valid_0's rmse: 3.63726
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.015738 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1636
# [LightGBM] [Info] Number of data points in the train set: 635508, number of used features: 23
# [LightGBM] [Info] Start training from score 7.054789
# Training until validation scores don't improve for 20 rounds
# [100]	valid_0's rmse: 3.68732
# [200]	valid_0's rmse: 3.66373
# [300]	valid_0's rmse: 3.65197
# [400]	valid_0's rmse: 3.64139
# [500]	valid_0's rmse: 3.63541
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's rmse: 3.63541
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.015408 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1639
# [LightGBM] [Info] Number of data points in the train set: 635508, number of used features: 23
# [LightGBM] [Info] Start training from score 7.053326
# Training until validation scores don't improve for 20 rounds
# [100]	valid_0's rmse: 3.68559
# [200]	valid_0's rmse: 3.66443
# [300]	valid_0's rmse: 3.65299
# [400]	valid_0's rmse: 3.64375
# [500]	valid_0's rmse: 3.63891
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's rmse: 3.63891
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013928 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1644
# [LightGBM] [Info] Number of data points in the train set: 635508, number of used features: 23
# [LightGBM] [Info] Start training from score 7.052467
# Training until validation scores don't improve for 20 rounds
# [100]	valid_0's rmse: 3.68938
# [200]	valid_0's rmse: 3.669
# [300]	valid_0's rmse: 3.65823
# [400]	valid_0's rmse: 3.64877
# [500]	valid_0's rmse: 3.64163
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's rmse: 3.64163

# %%
# 2020年から2022年のテストデータを取得
test_data_2020 = uma_race_df[uma_race_df['kaisai_nen'] == 2020].copy()
test_data_2021 = uma_race_df[uma_race_df['kaisai_nen'] == 2021].copy()
test_data_2022 = uma_race_df[uma_race_df['kaisai_nen'] == 2022].copy()

# 2021年と2022年のデータに対して予測を行い、平均を取る
test_data_2020.loc[:, 'y_pred'] = sum([model.predict(test_data_2020[features], num_iteration=model.best_iteration) for model in models]) / len(models)
test_data_2021.loc[:, 'y_pred'] = sum([model.predict(test_data_2021[features], num_iteration=model.best_iteration) for model in models]) / len(models)
test_data_2022.loc[:, 'y_pred'] = sum([model.predict(test_data_2022[features], num_iteration=model.best_iteration) for model in models]) / len(models)

# 予測されたランクをグループごとに計算
test_data_2020.loc[:, 'predicted_rank'] = test_data_2020.groupby('group')['y_pred'].rank(method='min')
test_data_2021.loc[:, 'predicted_rank'] = test_data_2021.groupby('group')['y_pred'].rank(method='min')
test_data_2022.loc[:, 'predicted_rank'] = test_data_2022.groupby('group')['y_pred'].rank(method='min')

# 結果を表示
test_data_2021[['group', 'predicted_rank', 'kakutei_chakujun']]
# Out:
#                   group  predicted_rank  kakutei_chakujun
# 883806   2021-101-45-10             2.0                 3
# 883807   2021-101-45-10             6.0                 6
# 883808   2021-101-45-10             5.0                 5
# 883809   2021-101-45-10             3.0                 4
# 883810   2021-101-45-10             1.0                 1
# ...                 ...             ...               ...
# 1069380  2021-1209-44-1            10.0                 9
# 1069381  2021-1209-44-1             1.0                 2
# 1069387  2021-1209-44-1             3.0                10
# 1069388   2021-902-30-5             1.0                 1
# 1069389  2021-1209-44-1             5.0                 1
#
# [71525 rows x 3 columns]

# %%
# RMSEを計算
rmse_2020 = np.sqrt(mean_squared_error(test_data_2020['predicted_rank'], test_data_2020['kakutei_chakujun']))
print(f"2021 RMSE: {rmse_2020:.3%}")
rmse_2021 = np.sqrt(mean_squared_error(test_data_2021['predicted_rank'], test_data_2021['kakutei_chakujun']))
print(f"2021 RMSE: {rmse_2021:.3%}")
rmse_2022 = np.sqrt(mean_squared_error(test_data_2022['predicted_rank'], test_data_2022['kakutei_chakujun']))
print(f"2022 RMSE: {rmse_2022:.3%}")
rmse_mean = np.mean([rmse_2020, rmse_2021, rmse_2022])
print(f"Mean RMSE: {rmse_mean:.3%}")

group_ids_2020 = test_data_2020['group'].unique()
precisions = []
recalls = []

#各レースごとでPrecision@5とRecall@5を計算
for group_id in group_ids_2020:
    test_data = test_data_2020[test_data_2020['group'] == group_id]
    p = precision_at_5(test_data['predicted_rank'].values, test_data['kakutei_chakujun'].values)
    r = recall_at_5(test_data['predicted_rank'].values, test_data['kakutei_chakujun'].values)
    precisions.append(p)
    recalls.append(r)

precision_5_2020 = np.mean(precisions)
recall_5_2020 = np.mean(recalls)

print(f"2020 Precision@5: {precision_5_2020:.3%}")
print(f"2020 Recall@5: {recall_5_2020:.3%}")


group_ids_2021 = test_data_2021['group'].unique()
precisions = []
recalls = []

#各レースごとでPrecision@5とRecall@5を計算
for group_id in group_ids_2021:
    test_data = test_data_2021[test_data_2021['group'] == group_id]
    p = precision_at_5(test_data['predicted_rank'].values, test_data['kakutei_chakujun'].values)
    r = recall_at_5(test_data['predicted_rank'].values, test_data['kakutei_chakujun'].values)
    precisions.append(p)
    recalls.append(r)

precision_5_2021 = np.mean(precisions)
recall_5_2021 = np.mean(recalls)

print(f"2021 Precision@5: {precision_5_2021:.3%}")
print(f"2021 Recall@5: {recall_5_2021:.3%}")


roup_ids_2022 = test_data_2022['group'].unique()
precisions = []
recalls = []

for group_id in roup_ids_2022:
    test_data = test_data_2022[test_data_2022['group'] == group_id]
    p = precision_at_5(test_data['predicted_rank'].values, test_data['kakutei_chakujun'].values)
    r = recall_at_5(test_data['predicted_rank'].values, test_data['kakutei_chakujun'].values)
    precisions.append(p)
    recalls.append(r)

precision_5_2022 = np.mean(precisions)
recall_5_2022 = np.mean(recalls)

print(f"2022 Precision@5: {precision_5_2022:.3%}")
print(f"2022 Recall@5: {recall_5_2022:.3%}")


precision_5_mean = np.mean([precision_5_2020, precision_5_2021, precision_5_2022])
recall_5_mean = np.mean([recall_5_2020, recall_5_2021, recall_5_2022])

print(f"Mean Precision@5: {precision_5_mean:.3%}")
print(f"Mean Recall@5: {recall_5_mean:.3%}")

# 各レースで上記の関数を適用
results_2020 = test_data_2020.groupby('group').apply(check_top3_in_top5_predictions)
results_2021 = test_data_2021.groupby('group').apply(check_top3_in_top5_predictions)
results_2022 = test_data_2022.groupby('group').apply(check_top3_in_top5_predictions)

# 予測モデルが成功したレースのインデックスを取得する
successful_groups_2020 = results_2020[results_2020].index
successful_groups_2021 = results_2021[results_2021].index
successful_groups_2022 = results_2022[results_2022].index

# そのインデックスを使用して、harai_dfから対応する支払倍率を取得する
successful_payout_2020 = payout_df[payout_df['group'].isin(successful_groups_2020)]
successful_payout_2021 = payout_df[payout_df['group'].isin(successful_groups_2021)]
successful_payout_2022 = payout_df[payout_df['group'].isin(successful_groups_2022)]

payouts_2020 = successful_payout_2020['haraimodoshi_sanrenpuku_1b']
payouts_2021 = successful_payout_2021['haraimodoshi_sanrenpuku_1b']
payouts_2022 = successful_payout_2022['haraimodoshi_sanrenpuku_1b']

# すべての成功したレースに対して、100円をかけた場合の支払いを計算する
total_payout_2020 = (payouts_2020).sum()
total_payout_2021 = (payouts_2021).sum()
total_payout_2022 = (payouts_2022).sum()

# 合計の支払いから、すべてのレースにかけた合計金額を引くことで、純利益を計算する
total_investment_2020 = test_data_2020['group'].nunique() * 1000
total_investment_2021 = test_data_2021['group'].nunique() * 1000
total_investment_2022 = test_data_2021['group'].nunique() * 1000

net_profit_2020 = total_payout_2020 - total_investment_2020
net_profit_2021 = total_payout_2021 - total_investment_2021
net_profit_2022 = total_payout_2022 - total_investment_2022

average_net_profit_2020 = net_profit_2020/len(test_data_2020)
average_net_profit_2021 = net_profit_2021/len(test_data_2021)
average_net_profit_2022 = net_profit_2020/len(test_data_2022)

print(f"2020 Average Net Profit: {average_net_profit_2020:.3f} yen")
print(f"2021 Average Net Profit: {average_net_profit_2021:.3f} yen")
print(f"2022 Average Net Profit: {average_net_profit_2022:.3f} yen")

mean_average_net_profit = np.mean([average_net_profit_2020, average_net_profit_2021, average_net_profit_2022])
print(f"Mean Average Net Profit: {mean_average_net_profit:.3f} yen")
# Out:
# 2021 RMSE: 456.333%
# 2021 RMSE: 467.830%
# 2022 RMSE: 464.061%
# Mean RMSE: 462.741%
# 2020 Precision@5: 34.419%
# 2020 Recall@5: 57.365%
# 2021 Precision@5: 33.298%
# 2021 Recall@5: 55.496%
# 2022 Precision@5: 33.661%
# 2022 Recall@5: 56.102%
# Mean Precision@5: 33.793%
# Mean Recall@5: 56.321%
# 2020 Average Net Profit: -24.961 yen
# 2021 Average Net Profit: -29.869 yen
# 2022 Average Net Profit: -25.440 yen
# Mean Average Net Profit: -26.756 yen

# %%
# モデルを保存
with open('bestmodels/benchmark_optunaed.pkl', 'wb') as f:
    pickle.dump(models, f)
