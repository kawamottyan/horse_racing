# %% [markdown]
# 佐賀 ダート

# %% [markdown]
# # preparation

# %%
import pandas as pd
import numpy as np
from scipy import stats
from sklearn.preprocessing import MinMaxScaler

#モデル
import lightgbm as lgb

#パラメータ探索
import optuna

#クロスバリデーション
from sklearn.model_selection import KFold

#エヴァリュエーション
from sklearn.metrics import precision_score, recall_score, mean_squared_error

#可視化
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score, classification_report

#保存
import pickle

# %%
#42, 36, 54, 47, 55

# %%
#データを読み込む
j_uma_race_df = pd.read_pickle('../datasets/traindata/j_uma_race.pkl')
j_race_df = pd.read_pickle('../datasets/traindata/j_race.pkl')
# j_payout_df = pd.read_pickle('../datasets/traindata/j_payout.pkl')

n_uma_race_df = pd.read_pickle('../datasets/traindata/n_uma_race.pkl')
n_race_df = pd.read_pickle('../datasets/traindata/n_race.pkl')
n_payout_df = pd.read_pickle('../datasets/traindata/n_payout.pkl')

# %% [markdown]
# ### データの削除

# %%
#浦和競馬場に絞る
pd.set_option('display.max_columns', None)
urayasu_uma_race = n_uma_race_df[n_uma_race_df['keibajo_code'].astype(str) == '55']
urayasu_race = n_race_df[n_race_df['keibajo_code'].astype(str) == '55']
urayasu_uma_race
# Out:
#          kaisai_nen  kaisai_tsukihi keibajo_code  kaisai_kai  kaisai_nichime  \
# 96             2023             916           55          11               1
# 97             2023             916           55          11               1
# 98             2023             916           55          11               1
# 99             2023             916           55          11               1
# 100            2023             916           55          11               1
# ...             ...             ...          ...         ...             ...
# 2040558        2023             903           55          10               4
# 2040559        2023             903           55          10               4
# 2040560        2023             903           55          10               4
# 2040561        2023             903           55          10               4
# 2040562        2023             903           55          10               4
#
#          race_bango  wakuban  umaban  ketto_toroku_bango               bamei  \
# 96                1        1       1          2016101416  ロダルキラー
# 97                1        2       2          2019102139  クラトス
# 98                1        3       3          2016105355  ハッピーアロー
# 99                1        4       4          2016103133  クーザ
# 100               1        5       5          2018101203  シルバーテゾロ
# ...             ...      ...     ...                 ...                 ...
# 2040558          11        6       8          2020104487  スマイリングウェイ
# 2040559          11        7       9          2020102877  エルフォルク
# 2040560          11        7      10          2020106620  ラージフィールド
# 2040561          11        8      11          2020105838  マテキ
# 2040562          11        8      12          2020106327  プラチナリボン
#
#          umakigo_code  seibetsu_code  hinshu_code  moshoku_code  barei  \
# 96                  0              1          1.0             1      7
# 97                  0              3          1.0             3      4
# 98                  0              2          1.0             4      7
# 99                  0              1          1.0             3      7
# 100                 0              1          1.0             3      5
# ...               ...            ...          ...           ...    ...
# 2040558             0              2          1.0             1      3
# 2040559             0              2          1.0             1      3
# 2040560             0              3          1.0             3      3
# 2040561             0              2          1.0             3      3
# 2040562             0              1          1.0             3      3
#
#          tozai_shozoku_code  chokyoshi_code  banushi_code  \
# 96                        3            5059             0
# 97                        3           20418             0
# 98                        3            5741        228031
# 99                        3           20408             0
# 100                       3            5624        333031
# ...                     ...             ...           ...
# 2040558                   3            5741             0
# 2040559                   3            5770        382803
# 2040560                   3            5624        851030
# 2040561                   3            5759        228031
# 2040562                   3            5106        372008
#
#                                banushimei  futan_juryo  blinker_shiyo_kubun  \
# 96       北原　大史　　　　　　　　　　　　　　　　　　　　　　　　　　　        560.0                    0
# 97       遠藤　喜和　　　　　　　　　　　　　　　　　　　　　　　　　　　        560.0                    0
# 98       小橋　亮太　　　　　　　　　　　　　　　　　　　　　　　　　　　        540.0                    0
# 99       高橋　伸一　　　　　　　　　　　　　　　　　　　　　　　　　　　        550.0                    0
# 100      大田　恭充　　　　　　　　　　　　　　　　　　　　　　　　　　　        560.0                    0
# ...                                   ...          ...                  ...
# 2040558  鶴　俊邦　　　　　　　　　　　　　　　　　　　　　　　　　　　　        510.0                    0
# 2040559  本城　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　        540.0                    0
# 2040560  梶原　哲朗　　　　　　　　　　　　　　　　　　　　　　　　　　　        560.0                    0
# 2040561  小橋　亮太　　　　　　　　　　　　　　　　　　　　　　　　　　　        530.0                    0
# 2040562  三宅　勝俊　　　　　　　　　　　　　　　　　　　　　　　　　　　        560.0                    0
#
#          kishu_code kishumei_ryakusho  kishu_minarai_code  bataiju  \
# 96             5491              田中直人                   0    519.0
# 97             5587              小松丈二                   0    420.0
# 98             5601              金山昇馬                   0    428.0
# 99            21339              中山蓮王                   1    477.0
# 100            5645              川島拓　                   0    435.0
# ...             ...               ...                 ...      ...
# 2040558       21329              青海大樹                   3    442.0
# 2040559        5587              小松丈二                   0    444.0
# 2040560        5579              出水拓人                   0    475.0
# 2040561       21339              中山蓮王                   1    413.0
# 2040562        5609              飛田愛斗                   0    483.0
#
#          zogen_fugo  zogen_sa  ijo_kubun_code  nyusen_juni  kakutei_chakujun  \
# 96                2       3.0               0            1                 1
# 97                0       1.0               0            7                 7
# 98                2      12.0               0            4                 4
# 99                0       2.0               0           12                12
# 100               0       2.0               0            5                 5
# ...             ...       ...             ...          ...               ...
# 2040558           2      14.0               0            7                 7
# 2040559           2       6.0               0            4                 4
# 2040560           2      17.0               0            2                 2
# 2040561           2       1.0               0            8                 8
# 2040562           2       9.0               0            3                 3
#
#          dochaku_kubun  dochaku_tosu  soha_time  chakusa_code_1  \
# 96                   0             0       1315             NaN
# 97                   0             0       1355             2.0
# 98                   0             0       1342             7.0
# 99                   0             0       1374           112.0
# 100                  0             0       1349             4.0
# ...                ...           ...        ...             ...
# 2040558              0             0       1270           112.0
# 2040559              0             0       1255             2.0
# 2040560              0             0       1247             NaN
# 2040561              0             0       1270             NaN
# 2040562              0             0       1251             2.0
#
#          chakusa_code_2  chakusa_code_3  corner_1  corner_2  corner_3  \
# 96                  NaN             NaN         6         4         2
# 97                  NaN             NaN        10        10         8
# 98                  NaN             NaN         3         3         4
# 99                  NaN             NaN        12        12        12
# 100                 NaN             NaN         8         7         7
# ...                 ...             ...       ...       ...       ...
# 2040558             NaN             NaN        10        11        10
# 2040559             NaN             NaN         9         9         6
# 2040560             NaN             NaN         2         2         2
# 2040561             NaN             NaN         3         3         4
# 2040562             NaN             NaN         8         8         7
#
#          corner_4  tansho_odds  tansho_ninkijun  kakutoku_honshokin  \
# 96              2           12                1                3500
# 97              8         2458               12                   0
# 98              4          414                3                 420
# 99             12         1553                9                   0
# 100             7          683                5                 280
# ...           ...          ...              ...                 ...
# 2040558         9          315                7                   0
# 2040559         4           38                3                 480
# 2040560         1           48                4                1280
# 2040561         5          763               11                   0
# 2040562         6           37                2                 720
#
#          kakutoku_fukashokin  kohan_4f  kohan_3f  \
# 96                         0         0       381
# 97                         0         0       404
# 98                         0         0       402
# 99                         0         0       404
# 100                        0         0       400
# ...                      ...       ...       ...
# 2040558                    0         0       401
# 2040559                    0         0       390
# 2040560                    0         0       399
# 2040561                    0         0       418
# 2040562                    0         0       391
#
#                        aiteuma_joho_1                aiteuma_joho_2  \
# 96       2017105721クリノアンカーマン　　　　　　　　　  0000000000
# 97       2016101416ロダルキラー　　　　　　　　　　　　  0000000000
# 98       2016101416ロダルキラー　　　　　　　　　　　　  0000000000
# 99       2016101416ロダルキラー　　　　　　　　　　　　  0000000000
# 100      2016101416ロダルキラー　　　　　　　　　　　　  0000000000
# ...                               ...                           ...
# 2040558  2020105011アグリモニー　　　　　　　　　　　　  0000000000
# 2040559  2020105011アグリモニー　　　　　　　　　　　　  0000000000
# 2040560  2020105011アグリモニー　　　　　　　　　　　　  0000000000
# 2040561  2020105011アグリモニー　　　　　　　　　　　　  0000000000
# 2040562  2020105011アグリモニー　　　　　　　　　　　　  0000000000
#
#                        aiteuma_joho_3  time_sa  record_koshin_kubun  \
# 96       0000000000　　　　　　　　　　　　　　　　　　        0                    0
# 97       0000000000　　　　　　　　　　　　　　　　　　       40                    0
# 98       0000000000　　　　　　　　　　　　　　　　　　       27                    0
# 99       0000000000　　　　　　　　　　　　　　　　　　       59                    0
# 100      0000000000　　　　　　　　　　　　　　　　　　       34                    0
# ...                               ...      ...                  ...
# 2040558  0000000000　　　　　　　　　　　　　　　　　　       23                    0
# 2040559  0000000000　　　　　　　　　　　　　　　　　　        8                    0
# 2040560  0000000000　　　　　　　　　　　　　　　　　　        0                    0
# 2040561  0000000000　　　　　　　　　　　　　　　　　　       23                    0
# 2040562  0000000000　　　　　　　　　　　　　　　　　　        4                    0
#
#          kyakushitsu_hantei
# 96                        0
# 97                        0
# 98                        0
# 99                        0
# 100                       0
# ...                     ...
# 2040558                   0
# 2040559                   0
# 2040560                   0
# 2040561                   0
# 2040562                   0
#
# [150516 rows x 52 columns]

# %% [markdown]
# # LightGBM

# %% [markdown]
# ## グループクエリ用のカラムを作成

# %%
# 新しいグループを作成
urayasu_uma_race['group'] = urayasu_uma_race['kaisai_nen'].astype(int).astype(str) +"-"+ urayasu_uma_race['kaisai_tsukihi'].astype(int).astype(str) +"-"+  urayasu_uma_race['keibajo_code'].astype(int).astype(str) +"-"+  urayasu_uma_race['race_bango'].astype(int).astype(str)
urayasu_race['group'] = urayasu_race['kaisai_nen'].astype(int).astype(str) +"-"+ urayasu_race['kaisai_tsukihi'].astype(int).astype(str) +"-"+  urayasu_race['keibajo_code'].astype(int).astype(str) +"-"+  urayasu_race['race_bango'].astype(int).astype(str)
n_payout_df['group'] = n_payout_df['kaisai_nen'].astype(int).astype(str) +"-"+ n_payout_df['kaisai_tsukihi'].astype(int).astype(str) +"-"+  n_payout_df['keibajo_code'].astype(int).astype(str) +"-"+  n_payout_df['race_bango'].astype(int).astype(str)
# Out:
# C:\Users\kawam\AppData\Local\Temp\ipykernel_10152\3114523199.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   urayasu_uma_race['group'] = urayasu_uma_race['kaisai_nen'].astype(int).astype(str) +"-"+ urayasu_uma_race['kaisai_tsukihi'].astype(int).astype(str) +"-"+  urayasu_uma_race['keibajo_code'].astype(int).astype(str) +"-"+  urayasu_uma_race['race_bango'].astype(int).astype(str)
# C:\Users\kawam\AppData\Local\Temp\ipykernel_10152\3114523199.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   urayasu_race['group'] = urayasu_race['kaisai_nen'].astype(int).astype(str) +"-"+ urayasu_race['kaisai_tsukihi'].astype(int).astype(str) +"-"+  urayasu_race['keibajo_code'].astype(int).astype(str) +"-"+  urayasu_race['race_bango'].astype(int).astype(str)

# %%
urayasu_uma_race['group'].unique()
# Out:
# array(['2023-916-55-1', '2023-916-55-2', '2023-916-55-3', ...,
#        '2023-903-55-9', '2023-903-55-10', '2023-903-55-11'], dtype=object)

# %%
urayasu_race['group'].unique()
# Out:
# array(['2021-103-55-1', '2021-103-55-2', '2021-103-55-3', ...,
#        '2020-1227-55-9', '2020-1227-55-10', '2020-1227-55-11'],
#       dtype=object)

# %%
urayasu_race = urayasu_race.drop(['kaisai_nen', 'kaisai_tsukihi', 'keibajo_code', 'kaisai_kai', 'kaisai_nichime', 'race_bango'],axis=1)
n_payout_df = n_payout_df.drop(['kaisai_nen', 'kaisai_tsukihi', 'keibajo_code', 'kaisai_kai', 'kaisai_nichime', 'race_bango', 'toroku_tosu', 'shusso_tosu'],axis=1)

# %%
merged_df = pd.merge(urayasu_uma_race, urayasu_race, on='group', how='left')
merged_df = pd.merge(merged_df, n_payout_df, on='group', how='left')
merged_df['group'].nunique()
# Out:
# 16370

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150516 entries, 0 to 150515
# Data columns (total 82 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   kaisai_nen                  150516 non-null  int64
#  1   kaisai_tsukihi              150516 non-null  int64
#  2   keibajo_code                150516 non-null  object
#  3   kaisai_kai                  150516 non-null  int64
#  4   kaisai_nichime              150516 non-null  int64
#  5   race_bango                  150516 non-null  int64
#  6   wakuban                     150516 non-null  int64
#  7   umaban                      150516 non-null  int64
#  8   ketto_toroku_bango          150516 non-null  int64
#  9   bamei                       150516 non-null  object
#  10  umakigo_code                150516 non-null  int64
#  11  seibetsu_code               150516 non-null  int64
#  12  hinshu_code                 150516 non-null  float64
#  13  moshoku_code                150516 non-null  int64
#  14  barei                       150516 non-null  int64
#  15  tozai_shozoku_code          150516 non-null  int64
#  16  chokyoshi_code              150516 non-null  int64
#  17  banushi_code                150516 non-null  int64
#  18  banushimei                  150516 non-null  object
#  19  futan_juryo                 150516 non-null  float64
#  20  blinker_shiyo_kubun         150516 non-null  int64
#  21  kishu_code                  150516 non-null  int64
#  22  kishumei_ryakusho           150516 non-null  object
#  23  kishu_minarai_code          150516 non-null  int64
#  24  bataiju                     150336 non-null  float64
#  25  zogen_fugo                  150516 non-null  int64
#  26  zogen_sa                    149066 non-null  float64
#  27  ijo_kubun_code              150516 non-null  int64
#  28  nyusen_juni                 150516 non-null  int64
#  29  kakutei_chakujun            150516 non-null  int64
#  30  dochaku_kubun               150516 non-null  int64
#  31  dochaku_tosu                150516 non-null  int64
#  32  soha_time                   150516 non-null  int64
#  33  chakusa_code_1              104246 non-null  float64
#  34  chakusa_code_2              4 non-null       float64
#  35  chakusa_code_3              0 non-null       float64
#  36  corner_1                    150516 non-null  int64
#  37  corner_2                    150516 non-null  int64
#  38  corner_3                    150516 non-null  int64
#  39  corner_4                    150516 non-null  int64
#  40  tansho_odds                 150516 non-null  int64
#  41  tansho_ninkijun             150516 non-null  int64
#  42  kakutoku_honshokin          150516 non-null  int64
#  43  kakutoku_fukashokin         150516 non-null  int64
#  44  kohan_4f                    150516 non-null  int64
#  45  kohan_3f                    150516 non-null  int64
#  46  aiteuma_joho_1              150516 non-null  object
#  47  aiteuma_joho_2              150516 non-null  object
#  48  aiteuma_joho_3              150516 non-null  object
#  49  time_sa                     150516 non-null  int64
#  50  record_koshin_kubun         150516 non-null  int64
#  51  kyakushitsu_hantei          150516 non-null  int64
#  52  group                       150516 non-null  object
#  53  yobi_code                   150516 non-null  int64
#  54  jusho_kaiji                 150516 non-null  int64
#  55  grade_code                  150516 non-null  int64
#  56  kyoso_shubetsu_code         150516 non-null  int64
#  57  kyoso_kigo_code             150516 non-null  int64
#  58  juryo_shubetsu_code         150516 non-null  int64
#  59  kyoso_joken_code_2sai       150516 non-null  int64
#  60  kyoso_joken_code_3sai       150516 non-null  int64
#  61  kyoso_joken_code_4sai       150516 non-null  int64
#  62  kyoso_joken_code_5sai_ijo   150516 non-null  int64
#  63  kyoso_joken_code            150516 non-null  int64
#  64  kyori                       150516 non-null  int64
#  65  track_code                  150516 non-null  int64
#  66  course_kubun                150516 non-null  int64
#  67  honshokin                   150516 non-null  float64
#  68  fukashokin                  150516 non-null  int64
#  69  hasso_jikoku                150516 non-null  int64
#  70  toroku_tosu                 150516 non-null  int64
#  71  shusso_tosu                 150516 non-null  int64
#  72  nyusen_tosu                 150516 non-null  int64
#  73  tenko_code                  150516 non-null  int64
#  74  babajotai_code_shiba        150516 non-null  int64
#  75  babajotai_code_dirt         150516 non-null  float64
#  76  fuseiritsu_flag_sanrenpuku  149008 non-null  float64
#  77  tokubarai_flag_sanrenpuku   149008 non-null  float64
#  78  henkan_flag_sanrenpuku      149008 non-null  float64
#  79  haraimodoshi_sanrenpuku_1a  149008 non-null  float64
#  80  haraimodoshi_sanrenpuku_1b  148991 non-null  float64
#  81  haraimodoshi_sanrenpuku_1c  148089 non-null  float64
# dtypes: float64(15), int64(59), object(8)
# memory usage: 94.2+ MB

# %%
pd.set_option('display.max_columns', None)
merged_df.head(1)
# Out:
#    kaisai_nen  kaisai_tsukihi keibajo_code  kaisai_kai  kaisai_nichime  \
# 0        2023             916           55          11               1
#
#    race_bango  wakuban  umaban  ketto_toroku_bango               bamei  \
# 0           1        1       1          2016101416  ロダルキラー
#
#    umakigo_code  seibetsu_code  hinshu_code  moshoku_code  barei  \
# 0             0              1          1.0             1      7
#
#    tozai_shozoku_code  chokyoshi_code  banushi_code  \
# 0                   3            5059             0
#
#                          banushimei  futan_juryo  blinker_shiyo_kubun  \
# 0  北原　大史　　　　　　　　　　　　　　　　　　　　　　　　　　　        560.0                    0
#
#    kishu_code kishumei_ryakusho  kishu_minarai_code  bataiju  zogen_fugo  \
# 0        5491              田中直人                   0    519.0           2
#
#    zogen_sa  ijo_kubun_code  nyusen_juni  kakutei_chakujun  dochaku_kubun  \
# 0       3.0               0            1                 1              0
#
#    dochaku_tosu  soha_time  chakusa_code_1  chakusa_code_2  chakusa_code_3  \
# 0             0       1315             NaN             NaN             NaN
#
#    corner_1  corner_2  corner_3  corner_4  tansho_odds  tansho_ninkijun  \
# 0         6         4         2         2           12                1
#
#    kakutoku_honshokin  kakutoku_fukashokin  kohan_4f  kohan_3f  \
# 0                3500                    0         0       381
#
#                  aiteuma_joho_1                aiteuma_joho_2  \
# 0  2017105721クリノアンカーマン　　　　　　　　　  0000000000
#
#                  aiteuma_joho_3  time_sa  record_koshin_kubun  \
# 0  0000000000　　　　　　　　　　　　　　　　　　        0                    0
#
#    kyakushitsu_hantei          group  yobi_code  jusho_kaiji  grade_code  \
# 0                   0  2023-916-55-1          1            0           0
#
#    kyoso_shubetsu_code  kyoso_kigo_code  juryo_shubetsu_code  \
# 0                   14                0                    3
#
#    kyoso_joken_code_2sai  kyoso_joken_code_3sai  kyoso_joken_code_4sai  \
# 0                      0                      0                      0
#
#    kyoso_joken_code_5sai_ijo  kyoso_joken_code  kyori  track_code  \
# 0                          0                 0   1400          24
#
#    course_kubun     honshokin  fukashokin  hasso_jikoku  toroku_tosu  \
# 0             0  3.500000e+51           0          1440           12
#
#    shusso_tosu  nyusen_tosu  tenko_code  babajotai_code_shiba  \
# 0           12           12           1                     0
#
#    babajotai_code_dirt  fuseiritsu_flag_sanrenpuku  tokubarai_flag_sanrenpuku  \
# 0                  4.0                         0.0                        0.0
#
#    henkan_flag_sanrenpuku  haraimodoshi_sanrenpuku_1a  \
# 0                     0.0                     10810.0
#
#    haraimodoshi_sanrenpuku_1b  haraimodoshi_sanrenpuku_1c
# 0                       580.0                         3.0

# %%
merged_df['kaisai_nen'].value_counts()
# Out:
# kaisai_nen
# 2021    13118
# 2022    12655
# 2019    12434
# 2020    12370
# 2018    12219
# 2017    10566
# 2015    10213
# 2016     9973
# 2014     9878
# 2012     9801
# 2023     9690
# 2013     9260
# 2010     9236
# 2011     9103
# Name: count, dtype: int64

# %%
merged_df['kyori'].value_counts()
# Out:
# kyori
# 1400    81072
# 1300    45417
# 1750     8301
# 900      8245
# 1800     5839
# 2000     1461
# 2500      128
# 1860       53
# Name: count, dtype: int64

# %%
merged_df['track_code'].value_counts()
# 24	平地　ダート 右回り	ダート・右	Dirt
# Out:
# track_code
# 24    150516
# Name: count, dtype: int64

# %%
merged_df = merged_df[merged_df['track_code'] == 24]

# %%
merged_df['grade_code'].value_counts()
# 1	G1（平地競走）
# 2	G2（平地競走）
# 3	G3（平地競走）
# 4	グレードのない重賞
# 5	重賞以外の特別競走
# 6	J･G1（障害競走）
# 7	J･G2（障害競走）
# 8	J･G3（障害競走）
# 0	一般競走　または未設定・未整備時の初期値(主に地方競馬・海外国際レースに関するデータ)
# Out:
# grade_code
# 0    141272
# 5      8921
# 3       323
# Name: count, dtype: int64

# %%
merged_df['umakigo_code'].value_counts()
# 00	下記以外　または未設定・未整備時の初期値(主に地方競馬・海外国際レースに関するデータ)
# Out:
# umakigo_code
# 0    150516
# Name: count, dtype: int64

# %%
merged_df['seibetsu_code'].value_counts()
# 0	未設定・未整備時の初期値(主に地方競馬・海外国際レースに関するデータ)
# 1	牡馬
# 2	牝馬
# 3	セン馬
# Out:
# seibetsu_code
# 2    76697
# 1    65255
# 3     8564
# Name: count, dtype: int64

# %%
merged_df['hinshu_code'].value_counts()
# 0	未設定・未整備時の初期値(主に地方競馬・海外国際レースに関するデータ)
# 1	サラブレッド	サラ	サラブレッドとして登録したもの。
# 2	サラブレッド系種	サラ系	アラブの血量が２５％未満
# 3	準サラブレッド	準サラ	昭和49年6月1日の登録規定改定により「準サラ」は「サラ系」となり、「準サラ」の品種は廃止された。
# 4	軽半血種	軽半	アングロノルマン、アングロノルマン系種または中半血種と連続2代以上にあたり、軽種を交配したもの。軽半血種相互の交配によって生まれたもの。
# 5	アングロアラブ	アア	アラブの血量が２５％以上（父母の組み合わせにより「アラ系」と異なる。）
# 6	アラブ系種	アラ系	アラブの血量が２５％以上（父母の組み合わせにより「アア」と異なる。）
# 7	アラブ	アラブ	純血のアラブ
# 8	中半血種	中半	異種の中間相互、中半血種の中間相互、の交配で生まれたもの。中半血種と軽種、アングロノルマンとサラブレッドを除く軽種、重半血種と軽種を交配して生まれたもの。
# Out:
# hinshu_code
# 1.0    150169
# 2.0       347
# Name: count, dtype: int64

# %%
merged_df['moshoku_code'].value_counts()
# 00	未設定・未整備時の初期値(主に地方競馬・海外国際レースに関するデータ)
# 01	栗毛	chestnut	ch.
# 02	栃栗毛	dark chestnut	d.ch.
# 03	鹿毛	bay	b.
# 04	黒鹿毛	dark bay	d.b.
# 05	青鹿毛	brown	br.
# 06	青毛	black	bl.
# 07	芦毛	grey	g.
# 08	栗粕毛		
# 09	鹿粕毛		
# 10	青粕毛		
# 11	白毛	white	w.
# Out:
# moshoku_code
# 3    62957
# 1    36628
# 4    30626
# 5    10240
# 7     7797
# 6     1764
# 2      504
# Name: count, dtype: int64

# %%
merged_df['barei'].value_counts()
# Out:
# barei
# 4     41746
# 3     36387
# 5     29353
# 6     17868
# 7     10302
# 2      6952
# 8      5405
# 9      1812
# 10      502
# 11      177
# 12       12
# Name: count, dtype: int64

# %%
merged_df['kishu_code'].value_counts()
# Out:
# kishu_code
# 5229     9479
# 5548     9005
# 5478     8949
# 5501     8536
# 5491     8337
#          ...
# 1117        1
# 21268       1
# 5135        1
# 5282        1
# 1170        1
# Name: count, Length: 332, dtype: int64

# %%
merged_df['chokyoshi_code'].value_counts()
# Out:
# chokyoshi_code
# 5005     9769
# 5456     8046
# 5624     7710
# 5106     7412
# 20293    7057
#          ...
# 390         1
# 5645        1
# 5235        1
# 5553        1
# 5567        1
# Name: count, Length: 283, dtype: int64

# %%
merged_df['banushi_code'].value_counts()
# Out:
# banushi_code
# 0         57920
# 514009     5457
# 489033     4136
# 92803      3971
# 674004     3753
#           ...
# 990033        1
# 222007        1
# 78700         1
# 747030        1
# 399803        1
# Name: count, Length: 610, dtype: int64

# %%
merged_df['kishu_minarai_code'].value_counts()
# 0	下記以外　または未設定・未整備時の初期値(主に地方競馬・海外国際レースに関するデータ)
# 1	☆	1Kg減	通算免許期間が3年未満の騎手で勝利数が51回以上100回以下(2004年から) 通算免許期間が3年未満の騎手で勝利数が31回以上100回以下(2003年まで)
# 2	△	2Kg減	通算免許期間が3年未満の騎手で勝利数が31回以上50回以下(2004年から) 通算免許期間が3年未満の騎手で勝利数が21回以上30回以下(2003年まで)
# 3	▲	3Kg減	通算免許期間が3年未満の騎手で勝利数が30回以下(2004年から) 通算免許期間が3年未満の騎手で勝利数が20回以下(2003年まで)
# Out:
# kishu_minarai_code
# 0    128050
# 1      9096
# 3      7542
# 2      5613
# 4       215
# Name: count, dtype: int64

# %%
merged_df['futan_juryo'].value_counts()
# Out:
# futan_juryo
# 540.0    64547
# 560.0    59476
# 530.0     9167
# 550.0     8883
# 510.0     4268
# 520.0     3647
# 570.0      249
# 500.0      217
# 580.0       25
# 490.0       17
# 590.0        6
# 575.0        5
# 585.0        4
# 555.0        2
# 565.0        2
# 595.0        1
# Name: count, dtype: int64

# %%
merged_df['bataiju'].value_counts()
# Out:
# bataiju
# 460.0    2117
# 456.0    2026
# 470.0    1919
# 463.0    1910
# 450.0    1871
#          ...
# 324.0       1
# 341.0       1
# 345.0       1
# 343.0       1
# 332.0       1
# Name: count, Length: 278, dtype: int64

# %%
merged_df['hutan_wariai'] = merged_df['futan_juryo'] / merged_df['bataiju']

# %%
merged_df['zogen_fugo'].value_counts()
# Out:
# zogen_fugo
# 2    67750
# 0    65227
# 1    17539
# Name: count, dtype: int64

# %%
merged_df['zogen_sa'].value_counts()
# Out:
# zogen_sa
# 1.0      24625
# 2.0      23073
# 3.0      19575
# 4.0      15847
# 0.0      14615
# 5.0      12543
# 6.0       9589
# 7.0       7112
# 8.0       5211
# 9.0       3824
# 10.0      2791
# 11.0      1893
# 12.0      1504
# 999.0     1474
# 13.0      1110
# 14.0       846
# 15.0       607
# 16.0       490
# 17.0       392
# 18.0       319
# 19.0       248
# 20.0       234
# 21.0       193
# 22.0       144
# 23.0       143
# 24.0       112
# 26.0        94
# 25.0        85
# 27.0        78
# 29.0        43
# 28.0        41
# 30.0        39
# 31.0        29
# 32.0        26
# 34.0        20
# 33.0        17
# 35.0        12
# 36.0        12
# 38.0         7
# 37.0         7
# 40.0         7
# 43.0         6
# 39.0         5
# 41.0         4
# 44.0         4
# 45.0         4
# 42.0         3
# 50.0         2
# 47.0         1
# 64.0         1
# 60.0         1
# 71.0         1
# 48.0         1
# 51.0         1
# 52.0         1
# Name: count, dtype: int64

# %%
def combine_sign_and_diff(row):
    if row['zogen_fugo'] == 2:
        return row['zogen_sa']
    elif row['zogen_fugo'] == 0:
        return -row['zogen_sa']
    else:
        return 0

merged_df['zogen_ryou'] = merged_df.apply(combine_sign_and_diff, axis=1)

scaler = MinMaxScaler()
merged_df['zogen_ryou'] = scaler.fit_transform(merged_df[['zogen_ryou']])

# %%
merged_df['ijo_kubun_code'].value_counts()
# 0	下記以外　または未設定・未整備時の初期値(主に地方競馬・海外国際レースに関するデータ)
# 1	出走取消	取消	SCRATCHED	S
# 2	発走除外	発除	EXCLUDED BY STARTERS	ES
# 3	競走除外	競除	EXCLUDED BY STEWARDS	ER
# 4	競走中止	中止	FALL TO FINISH	FF
# 5	失格	失格	DISQUALIFIED	DQ
# 6	落馬再騎乗	再騎	REMOUNT AFTER A CROPPER	RM
# 7	降着	降着	DISQUALIFIED AND PLACED	DQ&P
# Out:
# ijo_kubun_code
# 0    149139
# 4       629
# 3       451
# 1       292
# 7         4
# 5         1
# Name: count, dtype: int64

# %%
merged_df = merged_df[merged_df['ijo_kubun_code'] == 0]

# %%
merged_df['kyoso_shubetsu_code'].value_counts()
# 00	未設定・未整備時の初期値(主に地方競馬・海外国際レースに関するデータ)
# 11	サラブレッド系2歳	サラ２才	サラ系２歳	サラ系２歳	TWO-YEAR-OLDS
# 12	サラブレッド系3歳	サラ３才	サラ系３歳	サラ系３歳	THREE-YEAR-OLDS
# 13	サラブレッド系3歳以上	サラ３上	サラ系３歳上	サラ系３歳以上	THREE-YEAR-OLDS & UP
# 14	サラブレッド系4歳以上	サラ４上	サラ系４歳上	サラ系４歳以上	FOUR-YEAR-OLDS & UP
# 18	サラブレッド系障害3歳以上	障害３上	障害３歳上	サラ障害３歳以上	THREE-YEAR-OLDS & UP STEEPLE-CHASE
# 19	サラブレッド系障害4歳以上	障害４上	障害４歳上	サラ障害４歳以上	FOUR-YEAR-OLDS & UP STEEPLE-CHASE
# 21	アラブ系2歳	アラ２才	アラ系２歳	アラブ系２歳	TWO-YEAR-OLDS ANGLO-ARABS
# 22	アラブ系3歳	アラ３才	アラ系３歳	アラブ系３歳	THREE-YEAR-OLDS ANGLO-ARABS
# 23	アラブ系3歳以上	アラ３上	アラ系３歳上	アラブ系３歳以上	THREE-YEAR-OLDS & UP ANGLO-ARABS
# 24	アラブ系4歳以上	アラ４上	アラ系４歳上	アラブ系４歳以上	FOUR-YEAR-OLDS & UP ANGLO-ARABS
# Out:
# kyoso_shubetsu_code
# 14    63617
# 13    55141
# 12    23546
# 11     6804
# 1        20
# 49       11
# Name: count, dtype: int64

# %%
j_race_df['kyoso_shubetsu_code'].value_counts()
# Out:
# kyoso_shubetsu_code
# 12    21794
# 0     19750
# 13    18724
# 14    13839
# 11    11907
# 18     1007
# 19      760
# Name: count, dtype: int64

# %%
merged_df['kyoso_kigo_code'].value_counts()
# 000	記号なし　または未設定・未整備時の初期値(主に地方競馬・海外国際レースに関するデータ)
# 001	(指定)	DSN
# 002	見習騎手 (2003年までの表記)若手騎手 (2004年からの表記)	
# 003	[指定]	DES
# 004	(特指)	SD
# Out:
# kyoso_kigo_code
# 0       148225
# 1301       690
# 1300       224
# Name: count, dtype: int64

# %%
merged_df['juryo_shubetsu_code'].value_counts()
# 0	未設定・未整備時の初期値(主に地方競馬・海外国際レースに関するデータ)
# 1	ハンデ	HANDICAP	出走馬の実績等を考慮し、ハンデキャッパーが負担重量を決定するレース
# 2	別定	SPECIAL WEIGHT	レースごとに負担重量を決定する基準が設けられているレース
# 3	馬齢	WEIGHT FOR AGE	馬の年齢や性別によって負担重量を決定するレース
# 4	定量	SPECIAL WEIGHT	別定レースであって、馬の年齢や性別によって負担重量を決定するレース
# Out:
# juryo_shubetsu_code
# 3    132949
# 2     15923
# 1       157
# 0        65
# 4        45
# Name: count, dtype: int64

# %%
merged_df['kyoso_joken_code'].value_counts()
# 000	未設定・未整備時の初期値(主に地方競馬・海外国際レースに関するデータ)
# 001	１００万円以下	1,000,000 & LESS	収得賞金が100万円以下の馬が出走できる。
# 002	２００万円以下	2,000,000 & LESS	収得賞金が200万円以下の馬が出走できる。
# 003	３００万円以下	3,000,000 & LESS	収得賞金が300万円以下の馬が出走できる。
# 099	９９００万円以下	99,000,000 & LESS	収得賞金が9900万円以下の馬が出走できる。
# 100	１億円以下	100,000,000 & LESS	収得賞金が1億円以下の馬が出走できる。
# 701	新馬	NEWCOMER	サラブレッド系の未出走馬が出走できる。
# 702	未出走	UNRACED	当該競馬以外の競馬(地方競馬または外国の競馬を含む)において、出走したことがなく、当該競馬において、第1着または重賞競走の第2着になったことのない馬が出走できる。
# 703	未勝利	MAIDEN	該当競馬以外の競馬(地方競馬または外国の競馬を含む)において出走し、収得賞金がない馬が出走できる。また未出走馬も出走できる。
# 999	オープン	OPEN	特に記載のない限り、すべての馬が出走できる競走
# Out:
# kyoso_joken_code
# 0    149139
# Name: count, dtype: int64

# %%
merged_df['course_kubun'].value_counts()
# 半角2文字　使用するコースを設定
# "A " ～ "E " を設定 尚、2002年以前の東京競馬場は"A1"、"A2"も存在
# Out:
# course_kubun
# 0    149139
# Name: count, dtype: int64

# %%
merged_df['shusso_tosu'].value_counts()
# Out:
# shusso_tosu
# 9     34658
# 10    34602
# 8     29353
# 11    21420
# 12    13962
# 7     10347
# 6      2558
# 0      1516
# 5       634
# 4        80
# 3         9
# Name: count, dtype: int64

# %%
merged_df['tenko_code'].value_counts()
# 0	未設定・未整備時の初期値(主に地方競馬・海外国際レースに関するデータ)
# 1	晴	Fine
# 2	曇	Cloudy
# 3	雨	Rainy
# 4	小雨	Drizzle
# 5	雪	Snow
# 6	小雪	Light Snow
# Out:
# tenko_code
# 1    68986
# 2    60708
# 3    15844
# 4     1464
# 0     1248
# 5      767
# 6      122
# Name: count, dtype: int64

# %%
merged_df['babajotai_code_shiba'].value_counts()
# Out:
# babajotai_code_shiba
# 0    149139
# Name: count, dtype: int64

# %%
merged_df['babajotai_code_dirt'].value_counts()
# 0	未設定・未整備時の初期値(主に地方競馬・海外国際レースに関するデータ)
# 1	良	Firm	Standard
# 2	稍重	Good	Good
# 3	重	Yielding	Muddy
# 4	不良	Soft	Sloppy
# Out:
# babajotai_code_dirt
# 1.0    69650
# 4.0    34733
# 2.0    24457
# 3.0    19051
# 0.0     1248
# Name: count, dtype: int64

# %%
merged_df['haraimodoshi_sanrenpuku_1b'].value_counts()
# Out:
# haraimodoshi_sanrenpuku_1b
# 300.0      1082
# 430.0       985
# 280.0       969
# 220.0       959
# 480.0       950
#            ...
# 38580.0       7
# 9290.0        7
# 19140.0       7
# 25930.0       7
# 17730.0       6
# Name: count, Length: 2235, dtype: int64

# %% [markdown]
# ## LightGBM

# %% [markdown]
# ### テスト用と学習用のデータに分け、モデルを作成

# %%
# 2010年から2019年のデータを学習データとして取得
train_data = merged_df[merged_df['kaisai_nen'].isin([2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019])]

# ランキング学習のために必要な特徴量とターゲットを設定
features = [
            'kyori',
            'grade_code',
            'seibetsu_code',
            'moshoku_code',
            'barei',
            'chokyoshi_code',
            'banushi_code',
            'kishu_code',
            'kishu_minarai_code',
            'kyoso_shubetsu_code',
            'juryo_shubetsu_code',
            'shusso_tosu',
            'tenko_code',
            'babajotai_code_dirt',
            'hutan_wariai',
            'zogen_ryou',
            ]

target = 'kakutei_chakujun'

# LightGBM用のデータセットを作成
train_dataset = lgb.Dataset(train_data[features], label=train_data[target])

def objective(trial):
    # Optunaで調整するパラメータを設定
    params = {
        'objective': 'regression',
        'metric': 'rmse',
        'boosting_type': 'gbdt',
        'num_leaves': trial.suggest_int('num_leaves', 2, 256),
        'learning_rate': trial.suggest_float('learning_rate', 1e-4, 1e-1, log=True),
        'feature_fraction': trial.suggest_float('feature_fraction', 0.4, 1.0),
    }
    
    # k=5のFOLDでデータを分割
    kf = KFold(n_splits=5, shuffle=True, random_state=42)
    
    # 各FOLDでの評価値を保存するためのリスト
    rmses = []
    
    # LightGBMモデルを訓練
    for train_index, valid_index in kf.split(train_data):
        train_fold_data = train_data.iloc[train_index]
        valid_fold_data = train_data.iloc[valid_index]
        
        train_dataset = lgb.Dataset(train_fold_data[features], label=train_fold_data[target])
        valid_dataset = lgb.Dataset(valid_fold_data[features], label=valid_fold_data[target])
        
        model = lgb.train(params, train_dataset, num_boost_round=1000, valid_sets=[valid_dataset], early_stopping_rounds=100, verbose_eval=100)
        
        # RMSEを計算して保存
        y_pred = model.predict(valid_fold_data[features])
        rmse = np.sqrt(mean_squared_error(valid_fold_data[target], y_pred))
        rmses.append(rmse)
    
    # 5-FOLDの平均RMSEを返す
    return np.mean(rmses)

# Optunaでのパラメータ探索を実行
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=10)

# 最適なパラメータ
best_params = study.best_params
best_params['metric'] = 'rmse'  # ここでmetricを追加

# KFoldでのモデル訓練
kf = KFold(n_splits=5, shuffle=True, random_state=42)
models = []

for train_index, valid_index in kf.split(train_data):
    train_fold_data = train_data.iloc[train_index]
    valid_fold_data = train_data.iloc[valid_index]
    
    train_dataset = lgb.Dataset(train_fold_data[features], label=train_fold_data[target])
    valid_dataset = lgb.Dataset(valid_fold_data[features], label=valid_fold_data[target])
    
    model = lgb.train(best_params, train_dataset, num_boost_round=500, valid_sets=[valid_dataset], early_stopping_rounds=20, verbose_eval=100)  # ここでearly_stopping_roundsを50に変更
    models.append(model)
# Out:
# [I 2023-10-07 23:23:57,935] A new study created in memory with name: no-name-355bbcf8-fc08-4756-bfc3-c9eabe9279fa
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005379 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 931
# [LightGBM] [Info] Number of data points in the train set: 81458, number of used features: 16
# [LightGBM] [Info] Start training from score 4.972121
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.40071
# [200]	valid_0's rmse: 2.37564
# [300]	valid_0's rmse: 2.36527
# [400]	valid_0's rmse: 2.36144
# [500]	valid_0's rmse: 2.36032
# [600]	valid_0's rmse: 2.35891
# Early stopping, best iteration is:
# [544]	valid_0's rmse: 2.3583
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005426 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 936
# [LightGBM] [Info] Number of data points in the train set: 81458, number of used features: 16
# [LightGBM] [Info] Start training from score 4.974355
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.38618
# [200]	valid_0's rmse: 2.36171
# [300]	valid_0's rmse: 2.35459
# [400]	valid_0's rmse: 2.34863
# [500]	valid_0's rmse: 2.34546
# [600]	valid_0's rmse: 2.34325
# [700]	valid_0's rmse: 2.34275
# Early stopping, best iteration is:
# [626]	valid_0's rmse: 2.34217
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005125 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 932
# [LightGBM] [Info] Number of data points in the train set: 81458, number of used features: 16
# [LightGBM] [Info] Start training from score 4.973864
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.3968
# [200]	valid_0's rmse: 2.37467
# [300]	valid_0's rmse: 2.36296
# [400]	valid_0's rmse: 2.35739
# [500]	valid_0's rmse: 2.35581
# Early stopping, best iteration is:
# [463]	valid_0's rmse: 2.35519
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.010084 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 927
# [LightGBM] [Info] Number of data points in the train set: 81459, number of used features: 16
# [LightGBM] [Info] Start training from score 4.972023
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.38221
# [200]	valid_0's rmse: 2.35987
# [300]	valid_0's rmse: 2.35165
# [400]	valid_0's rmse: 2.34699
# [500]	valid_0's rmse: 2.3463
# Early stopping, best iteration is:
# [478]	valid_0's rmse: 2.34572
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.115477 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 928
# [LightGBM] [Info] Number of data points in the train set: 81459, number of used features: 16
# [LightGBM] [Info] Start training from score 4.971569
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.38357
# [200]	valid_0's rmse: 2.35849
# [300]	valid_0's rmse: 2.34749
# [400]	valid_0's rmse: 2.34255
# [500]	valid_0's rmse: 2.34013
# [600]	valid_0's rmse: 2.34053
# Early stopping, best iteration is:
# [534]	valid_0's rmse: 2.33925
# [I 2023-10-07 23:26:07,365] Trial 0 finished with value: 2.348128249245517 and parameters: {'num_leaves': 192, 'learning_rate': 0.06608095088939601, 'feature_fraction': 0.768434069235673}. Best is trial 0 with value: 2.348128249245517.
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004315 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 931
# [LightGBM] [Info] Number of data points in the train set: 81458, number of used features: 16
# [LightGBM] [Info] Start training from score 4.972121
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.73711
# [200]	valid_0's rmse: 2.73288
# [300]	valid_0's rmse: 2.72867
# [400]	valid_0's rmse: 2.72452
# [500]	valid_0's rmse: 2.72015
# [600]	valid_0's rmse: 2.71612
# [700]	valid_0's rmse: 2.71212
# [800]	valid_0's rmse: 2.7083
# [900]	valid_0's rmse: 2.70432
# [1000]	valid_0's rmse: 2.70056
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 2.70056
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004335 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 936
# [LightGBM] [Info] Number of data points in the train set: 81458, number of used features: 16
# [LightGBM] [Info] Start training from score 4.974355
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.72087
# [200]	valid_0's rmse: 2.71658
# [300]	valid_0's rmse: 2.71232
# [400]	valid_0's rmse: 2.70812
# [500]	valid_0's rmse: 2.70371
# [600]	valid_0's rmse: 2.69964
# [700]	valid_0's rmse: 2.69559
# [800]	valid_0's rmse: 2.69173
# [900]	valid_0's rmse: 2.68771
# [1000]	valid_0's rmse: 2.68391
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 2.68391
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005796 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 932
# [LightGBM] [Info] Number of data points in the train set: 81458, number of used features: 16
# [LightGBM] [Info] Start training from score 4.973864
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.72495
# [200]	valid_0's rmse: 2.72071
# [300]	valid_0's rmse: 2.71649
# [400]	valid_0's rmse: 2.71234
# [500]	valid_0's rmse: 2.70797
# [600]	valid_0's rmse: 2.70395
# [700]	valid_0's rmse: 2.69996
# [800]	valid_0's rmse: 2.69613
# [900]	valid_0's rmse: 2.69215
# [1000]	valid_0's rmse: 2.68839
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 2.68839
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003323 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 927
# [LightGBM] [Info] Number of data points in the train set: 81459, number of used features: 16
# [LightGBM] [Info] Start training from score 4.972023
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.70465
# [200]	valid_0's rmse: 2.70049
# [300]	valid_0's rmse: 2.69633
# [400]	valid_0's rmse: 2.69224
# [500]	valid_0's rmse: 2.68794
# [600]	valid_0's rmse: 2.68399
# [700]	valid_0's rmse: 2.68007
# [800]	valid_0's rmse: 2.67631
# [900]	valid_0's rmse: 2.67239
# [1000]	valid_0's rmse: 2.6687
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 2.6687
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004482 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 928
# [LightGBM] [Info] Number of data points in the train set: 81459, number of used features: 16
# [LightGBM] [Info] Start training from score 4.971569
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.73106
# [200]	valid_0's rmse: 2.72668
# [300]	valid_0's rmse: 2.72232
# [400]	valid_0's rmse: 2.718
# [500]	valid_0's rmse: 2.71347
# [600]	valid_0's rmse: 2.70929
# [700]	valid_0's rmse: 2.70515
# [800]	valid_0's rmse: 2.70119
# [900]	valid_0's rmse: 2.69706
# [1000]	valid_0's rmse: 2.69317
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 2.69317
# [I 2023-10-07 23:27:57,797] Trial 1 finished with value: 2.6869462795596535 and parameters: {'num_leaves': 72, 'learning_rate': 0.0001545110278110741, 'feature_fraction': 0.4823528903803823}. Best is trial 0 with value: 2.348128249245517.
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005176 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 931
# [LightGBM] [Info] Number of data points in the train set: 81458, number of used features: 16
# [LightGBM] [Info] Start training from score 4.972121
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.71328
# [200]	valid_0's rmse: 2.68786
# [300]	valid_0's rmse: 2.6654
# [400]	valid_0's rmse: 2.64557
# [500]	valid_0's rmse: 2.62764
# [600]	valid_0's rmse: 2.61195
# [700]	valid_0's rmse: 2.59777
# [800]	valid_0's rmse: 2.58539
# [900]	valid_0's rmse: 2.57436
# [1000]	valid_0's rmse: 2.56453
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 2.56453
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.008285 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 936
# [LightGBM] [Info] Number of data points in the train set: 81458, number of used features: 16
# [LightGBM] [Info] Start training from score 4.974355
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.69645
# [200]	valid_0's rmse: 2.67087
# [300]	valid_0's rmse: 2.64827
# [400]	valid_0's rmse: 2.62848
# [500]	valid_0's rmse: 2.61056
# [600]	valid_0's rmse: 2.5949
# [700]	valid_0's rmse: 2.5807
# [800]	valid_0's rmse: 2.56838
# [900]	valid_0's rmse: 2.55743
# [1000]	valid_0's rmse: 2.54769
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 2.54769
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.008185 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 932
# [LightGBM] [Info] Number of data points in the train set: 81458, number of used features: 16
# [LightGBM] [Info] Start training from score 4.973864
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.70094
# [200]	valid_0's rmse: 2.67559
# [300]	valid_0's rmse: 2.65321
# [400]	valid_0's rmse: 2.63356
# [500]	valid_0's rmse: 2.61586
# [600]	valid_0's rmse: 2.6004
# [700]	valid_0's rmse: 2.58646
# [800]	valid_0's rmse: 2.57431
# [900]	valid_0's rmse: 2.56351
# [1000]	valid_0's rmse: 2.55392
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 2.55392
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.008634 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 927
# [LightGBM] [Info] Number of data points in the train set: 81459, number of used features: 16
# [LightGBM] [Info] Start training from score 4.972023
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.6811
# [200]	valid_0's rmse: 2.65654
# [300]	valid_0's rmse: 2.63494
# [400]	valid_0's rmse: 2.6158
# [500]	valid_0's rmse: 2.59852
# [600]	valid_0's rmse: 2.58349
# [700]	valid_0's rmse: 2.56982
# [800]	valid_0's rmse: 2.55796
# [900]	valid_0's rmse: 2.54744
# [1000]	valid_0's rmse: 2.5381
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 2.5381
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005129 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 928
# [LightGBM] [Info] Number of data points in the train set: 81459, number of used features: 16
# [LightGBM] [Info] Start training from score 4.971569
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.70603
# [200]	valid_0's rmse: 2.67974
# [300]	valid_0's rmse: 2.65662
# [400]	valid_0's rmse: 2.6362
# [500]	valid_0's rmse: 2.61761
# [600]	valid_0's rmse: 2.60139
# [700]	valid_0's rmse: 2.58678
# [800]	valid_0's rmse: 2.57414
# [900]	valid_0's rmse: 2.56284
# [1000]	valid_0's rmse: 2.55277
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 2.55277
# [I 2023-10-07 23:29:13,983] Trial 2 finished with value: 2.5514030410392126 and parameters: {'num_leaves': 47, 'learning_rate': 0.0008044049862091789, 'feature_fraction': 0.8295466002520185}. Best is trial 0 with value: 2.348128249245517.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.007294 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 931
# [LightGBM] [Info] Number of data points in the train set: 81458, number of used features: 16
# [LightGBM] [Info] Start training from score 4.972121
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.44233
# [200]	valid_0's rmse: 2.416
# [300]	valid_0's rmse: 2.40189
# [400]	valid_0's rmse: 2.39199
# [500]	valid_0's rmse: 2.38409
# [600]	valid_0's rmse: 2.37839
# [700]	valid_0's rmse: 2.3747
# [800]	valid_0's rmse: 2.37192
# [900]	valid_0's rmse: 2.36948
# [1000]	valid_0's rmse: 2.36695
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 2.36695
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004241 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 936
# [LightGBM] [Info] Number of data points in the train set: 81458, number of used features: 16
# [LightGBM] [Info] Start training from score 4.974355
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.42497
# [200]	valid_0's rmse: 2.39844
# [300]	valid_0's rmse: 2.38613
# [400]	valid_0's rmse: 2.37576
# [500]	valid_0's rmse: 2.36969
# [600]	valid_0's rmse: 2.36384
# [700]	valid_0's rmse: 2.35894
# [800]	valid_0's rmse: 2.35499
# [900]	valid_0's rmse: 2.35301
# [1000]	valid_0's rmse: 2.35064
# Did not meet early stopping. Best iteration is:
# [996]	valid_0's rmse: 2.3506
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.007479 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 932
# [LightGBM] [Info] Number of data points in the train set: 81458, number of used features: 16
# [LightGBM] [Info] Start training from score 4.973864
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.43525
# [200]	valid_0's rmse: 2.4066
# [300]	valid_0's rmse: 2.39395
# [400]	valid_0's rmse: 2.38393
# [500]	valid_0's rmse: 2.37655
# [600]	valid_0's rmse: 2.37062
# [700]	valid_0's rmse: 2.36614
# [800]	valid_0's rmse: 2.36323
# [900]	valid_0's rmse: 2.36038
# [1000]	valid_0's rmse: 2.35866
# Did not meet early stopping. Best iteration is:
# [993]	valid_0's rmse: 2.35866
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003969 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 927
# [LightGBM] [Info] Number of data points in the train set: 81459, number of used features: 16
# [LightGBM] [Info] Start training from score 4.972023
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.41885
# [200]	valid_0's rmse: 2.39241
# [300]	valid_0's rmse: 2.37761
# [400]	valid_0's rmse: 2.36845
# [500]	valid_0's rmse: 2.36066
# [600]	valid_0's rmse: 2.35501
# [700]	valid_0's rmse: 2.35041
# [800]	valid_0's rmse: 2.34683
# [900]	valid_0's rmse: 2.3446
# [1000]	valid_0's rmse: 2.34304
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 2.34304
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004133 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 928
# [LightGBM] [Info] Number of data points in the train set: 81459, number of used features: 16
# [LightGBM] [Info] Start training from score 4.971569
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.4284
# [200]	valid_0's rmse: 2.40003
# [300]	valid_0's rmse: 2.38518
# [400]	valid_0's rmse: 2.37518
# [500]	valid_0's rmse: 2.36894
# [600]	valid_0's rmse: 2.36308
# [700]	valid_0's rmse: 2.35813
# [800]	valid_0's rmse: 2.35477
# [900]	valid_0's rmse: 2.35283
# [1000]	valid_0's rmse: 2.35043
# Did not meet early stopping. Best iteration is:
# [992]	valid_0's rmse: 2.3502
# [I 2023-10-07 23:30:31,216] Trial 3 finished with value: 2.3538895987866395 and parameters: {'num_leaves': 68, 'learning_rate': 0.05015560085352231, 'feature_fraction': 0.6582923229469376}. Best is trial 0 with value: 2.348128249245517.
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003916 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 931
# [LightGBM] [Info] Number of data points in the train set: 81458, number of used features: 16
# [LightGBM] [Info] Start training from score 4.972121
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.73737
# [200]	valid_0's rmse: 2.73335
# [300]	valid_0's rmse: 2.72933
# [400]	valid_0's rmse: 2.72537
# [500]	valid_0's rmse: 2.72123
# [600]	valid_0's rmse: 2.71738
# [700]	valid_0's rmse: 2.71356
# [800]	valid_0's rmse: 2.70989
# [900]	valid_0's rmse: 2.70608
# [1000]	valid_0's rmse: 2.70246
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 2.70246
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002356 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 936
# [LightGBM] [Info] Number of data points in the train set: 81458, number of used features: 16
# [LightGBM] [Info] Start training from score 4.974355
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.72115
# [200]	valid_0's rmse: 2.71708
# [300]	valid_0's rmse: 2.71301
# [400]	valid_0's rmse: 2.709
# [500]	valid_0's rmse: 2.70482
# [600]	valid_0's rmse: 2.70094
# [700]	valid_0's rmse: 2.69708
# [800]	valid_0's rmse: 2.69339
# [900]	valid_0's rmse: 2.68954
# [1000]	valid_0's rmse: 2.68588
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 2.68588
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002696 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 932
# [LightGBM] [Info] Number of data points in the train set: 81458, number of used features: 16
# [LightGBM] [Info] Start training from score 4.973864
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.72522
# [200]	valid_0's rmse: 2.72121
# [300]	valid_0's rmse: 2.71717
# [400]	valid_0's rmse: 2.71322
# [500]	valid_0's rmse: 2.70909
# [600]	valid_0's rmse: 2.70525
# [700]	valid_0's rmse: 2.70145
# [800]	valid_0's rmse: 2.69778
# [900]	valid_0's rmse: 2.69397
# [1000]	valid_0's rmse: 2.69036
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 2.69036
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002126 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 927
# [LightGBM] [Info] Number of data points in the train set: 81459, number of used features: 16
# [LightGBM] [Info] Start training from score 4.972023
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.70491
# [200]	valid_0's rmse: 2.70095
# [300]	valid_0's rmse: 2.69697
# [400]	valid_0's rmse: 2.69306
# [500]	valid_0's rmse: 2.68898
# [600]	valid_0's rmse: 2.68519
# [700]	valid_0's rmse: 2.68144
# [800]	valid_0's rmse: 2.67783
# [900]	valid_0's rmse: 2.67406
# [1000]	valid_0's rmse: 2.67051
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 2.67051
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002521 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 928
# [LightGBM] [Info] Number of data points in the train set: 81459, number of used features: 16
# [LightGBM] [Info] Start training from score 4.971569
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.73135
# [200]	valid_0's rmse: 2.7272
# [300]	valid_0's rmse: 2.72305
# [400]	valid_0's rmse: 2.71895
# [500]	valid_0's rmse: 2.71467
# [600]	valid_0's rmse: 2.71071
# [700]	valid_0's rmse: 2.70676
# [800]	valid_0's rmse: 2.70298
# [900]	valid_0's rmse: 2.69904
# [1000]	valid_0's rmse: 2.6953
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 2.6953
# [I 2023-10-07 23:32:27,936] Trial 4 finished with value: 2.6889025641215105 and parameters: {'num_leaves': 146, 'learning_rate': 0.0001377196758022538, 'feature_fraction': 0.4777120258283214}. Best is trial 0 with value: 2.348128249245517.
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003071 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 931
# [LightGBM] [Info] Number of data points in the train set: 81458, number of used features: 16
# [LightGBM] [Info] Start training from score 4.972121
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.7252
# [200]	valid_0's rmse: 2.70965
# [300]	valid_0's rmse: 2.69506
# [400]	valid_0's rmse: 2.68138
# [500]	valid_0's rmse: 2.66829
# [600]	valid_0's rmse: 2.65605
# [700]	valid_0's rmse: 2.6444
# [800]	valid_0's rmse: 2.63338
# [900]	valid_0's rmse: 2.62291
# [1000]	valid_0's rmse: 2.61311
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 2.61311
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004549 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 936
# [LightGBM] [Info] Number of data points in the train set: 81458, number of used features: 16
# [LightGBM] [Info] Start training from score 4.974355
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.70886
# [200]	valid_0's rmse: 2.69318
# [300]	valid_0's rmse: 2.6785
# [400]	valid_0's rmse: 2.66473
# [500]	valid_0's rmse: 2.65158
# [600]	valid_0's rmse: 2.63935
# [700]	valid_0's rmse: 2.62773
# [800]	valid_0's rmse: 2.61673
# [900]	valid_0's rmse: 2.60632
# [1000]	valid_0's rmse: 2.59654
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 2.59654
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005136 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 932
# [LightGBM] [Info] Number of data points in the train set: 81458, number of used features: 16
# [LightGBM] [Info] Start training from score 4.973864
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.71317
# [200]	valid_0's rmse: 2.69777
# [300]	valid_0's rmse: 2.68332
# [400]	valid_0's rmse: 2.66974
# [500]	valid_0's rmse: 2.65679
# [600]	valid_0's rmse: 2.64471
# [700]	valid_0's rmse: 2.63324
# [800]	valid_0's rmse: 2.62229
# [900]	valid_0's rmse: 2.61191
# [1000]	valid_0's rmse: 2.60219
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 2.60219
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.007647 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 927
# [LightGBM] [Info] Number of data points in the train set: 81459, number of used features: 16
# [LightGBM] [Info] Start training from score 4.972023
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.69296
# [200]	valid_0's rmse: 2.67776
# [300]	valid_0's rmse: 2.66352
# [400]	valid_0's rmse: 2.65018
# [500]	valid_0's rmse: 2.63746
# [600]	valid_0's rmse: 2.62561
# [700]	valid_0's rmse: 2.61439
# [800]	valid_0's rmse: 2.60379
# [900]	valid_0's rmse: 2.59377
# [1000]	valid_0's rmse: 2.58435
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 2.58435
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003125 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 928
# [LightGBM] [Info] Number of data points in the train set: 81459, number of used features: 16
# [LightGBM] [Info] Start training from score 4.971569
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.71883
# [200]	valid_0's rmse: 2.70285
# [300]	valid_0's rmse: 2.6879
# [400]	valid_0's rmse: 2.67384
# [500]	valid_0's rmse: 2.66039
# [600]	valid_0's rmse: 2.64785
# [700]	valid_0's rmse: 2.6359
# [800]	valid_0's rmse: 2.62457
# [900]	valid_0's rmse: 2.61382
# [1000]	valid_0's rmse: 2.60373
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 2.60373
# [I 2023-10-07 23:34:58,762] Trial 5 finished with value: 2.599984057169708 and parameters: {'num_leaves': 243, 'learning_rate': 0.00041298970922068256, 'feature_fraction': 0.7557595201239663}. Best is trial 0 with value: 2.348128249245517.
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003123 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 931
# [LightGBM] [Info] Number of data points in the train set: 81458, number of used features: 16
# [LightGBM] [Info] Start training from score 4.972121
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.54831
# [200]	valid_0's rmse: 2.48386
# [300]	valid_0's rmse: 2.45473
# [400]	valid_0's rmse: 2.439
# [500]	valid_0's rmse: 2.42986
# [600]	valid_0's rmse: 2.4232
# [700]	valid_0's rmse: 2.4174
# [800]	valid_0's rmse: 2.41316
# [900]	valid_0's rmse: 2.41007
# [1000]	valid_0's rmse: 2.40677
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 2.40677
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001893 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 936
# [LightGBM] [Info] Number of data points in the train set: 81458, number of used features: 16
# [LightGBM] [Info] Start training from score 4.974355
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.53198
# [200]	valid_0's rmse: 2.46751
# [300]	valid_0's rmse: 2.43915
# [400]	valid_0's rmse: 2.42397
# [500]	valid_0's rmse: 2.41495
# [600]	valid_0's rmse: 2.40823
# [700]	valid_0's rmse: 2.40278
# [800]	valid_0's rmse: 2.39836
# [900]	valid_0's rmse: 2.39426
# [1000]	valid_0's rmse: 2.39103
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 2.39103
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002216 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 932
# [LightGBM] [Info] Number of data points in the train set: 81458, number of used features: 16
# [LightGBM] [Info] Start training from score 4.973864
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.53751
# [200]	valid_0's rmse: 2.47445
# [300]	valid_0's rmse: 2.44631
# [400]	valid_0's rmse: 2.4318
# [500]	valid_0's rmse: 2.42289
# [600]	valid_0's rmse: 2.41644
# [700]	valid_0's rmse: 2.41049
# [800]	valid_0's rmse: 2.40573
# [900]	valid_0's rmse: 2.40184
# [1000]	valid_0's rmse: 2.39882
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 2.39882
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002015 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 927
# [LightGBM] [Info] Number of data points in the train set: 81459, number of used features: 16
# [LightGBM] [Info] Start training from score 4.972023
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.52107
# [200]	valid_0's rmse: 2.45986
# [300]	valid_0's rmse: 2.43239
# [400]	valid_0's rmse: 2.41728
# [500]	valid_0's rmse: 2.40791
# [600]	valid_0's rmse: 2.40125
# [700]	valid_0's rmse: 2.39529
# [800]	valid_0's rmse: 2.39085
# [900]	valid_0's rmse: 2.38708
# [1000]	valid_0's rmse: 2.38393
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 2.38393
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002897 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 928
# [LightGBM] [Info] Number of data points in the train set: 81459, number of used features: 16
# [LightGBM] [Info] Start training from score 4.971569
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.5361
# [200]	valid_0's rmse: 2.46969
# [300]	valid_0's rmse: 2.44046
# [400]	valid_0's rmse: 2.42475
# [500]	valid_0's rmse: 2.41552
# [600]	valid_0's rmse: 2.4093
# [700]	valid_0's rmse: 2.40411
# [800]	valid_0's rmse: 2.40016
# [900]	valid_0's rmse: 2.3967
# [1000]	valid_0's rmse: 2.39271
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 2.39271
# [I 2023-10-07 23:35:40,219] Trial 6 finished with value: 2.3946536813786916 and parameters: {'num_leaves': 86, 'learning_rate': 0.01111745630114042, 'feature_fraction': 0.4984770702416367}. Best is trial 0 with value: 2.348128249245517.
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003527 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 931
# [LightGBM] [Info] Number of data points in the train set: 81458, number of used features: 16
# [LightGBM] [Info] Start training from score 4.972121
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.73528
# [200]	valid_0's rmse: 2.72916
# [300]	valid_0's rmse: 2.72316
# [400]	valid_0's rmse: 2.71729
# [500]	valid_0's rmse: 2.71125
# [600]	valid_0's rmse: 2.70545
# [700]	valid_0's rmse: 2.69997
# [800]	valid_0's rmse: 2.69474
# [900]	valid_0's rmse: 2.68929
# [1000]	valid_0's rmse: 2.68423
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 2.68423
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002346 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 936
# [LightGBM] [Info] Number of data points in the train set: 81458, number of used features: 16
# [LightGBM] [Info] Start training from score 4.974355
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.71903
# [200]	valid_0's rmse: 2.71283
# [300]	valid_0's rmse: 2.70676
# [400]	valid_0's rmse: 2.70084
# [500]	valid_0's rmse: 2.69475
# [600]	valid_0's rmse: 2.68892
# [700]	valid_0's rmse: 2.6834
# [800]	valid_0's rmse: 2.67813
# [900]	valid_0's rmse: 2.67263
# [1000]	valid_0's rmse: 2.66753
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 2.66753
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002297 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 932
# [LightGBM] [Info] Number of data points in the train set: 81458, number of used features: 16
# [LightGBM] [Info] Start training from score 4.973864
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.72313
# [200]	valid_0's rmse: 2.71702
# [300]	valid_0's rmse: 2.71101
# [400]	valid_0's rmse: 2.70516
# [500]	valid_0's rmse: 2.69914
# [600]	valid_0's rmse: 2.69337
# [700]	valid_0's rmse: 2.68793
# [800]	valid_0's rmse: 2.68267
# [900]	valid_0's rmse: 2.67722
# [1000]	valid_0's rmse: 2.67219
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 2.67219
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002046 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 927
# [LightGBM] [Info] Number of data points in the train set: 81459, number of used features: 16
# [LightGBM] [Info] Start training from score 4.972023
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.70284
# [200]	valid_0's rmse: 2.69681
# [300]	valid_0's rmse: 2.6909
# [400]	valid_0's rmse: 2.68511
# [500]	valid_0's rmse: 2.67917
# [600]	valid_0's rmse: 2.67347
# [700]	valid_0's rmse: 2.6681
# [800]	valid_0's rmse: 2.66294
# [900]	valid_0's rmse: 2.65757
# [1000]	valid_0's rmse: 2.65261
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 2.65261
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002502 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 928
# [LightGBM] [Info] Number of data points in the train set: 81459, number of used features: 16
# [LightGBM] [Info] Start training from score 4.971569
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.72919
# [200]	valid_0's rmse: 2.72286
# [300]	valid_0's rmse: 2.71666
# [400]	valid_0's rmse: 2.7106
# [500]	valid_0's rmse: 2.70436
# [600]	valid_0's rmse: 2.69838
# [700]	valid_0's rmse: 2.69273
# [800]	valid_0's rmse: 2.68732
# [900]	valid_0's rmse: 2.68168
# [1000]	valid_0's rmse: 2.67647
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 2.67647
# [I 2023-10-07 23:36:36,551] Trial 7 finished with value: 2.670607844352138 and parameters: {'num_leaves': 147, 'learning_rate': 0.0001940970176623374, 'feature_fraction': 0.5919245699560115}. Best is trial 0 with value: 2.348128249245517.
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002377 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 931
# [LightGBM] [Info] Number of data points in the train set: 81458, number of used features: 16
# [LightGBM] [Info] Start training from score 4.972121
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.72009
# [200]	valid_0's rmse: 2.70121
# [300]	valid_0's rmse: 2.68385
# [400]	valid_0's rmse: 2.66705
# [500]	valid_0's rmse: 2.65026
# [600]	valid_0's rmse: 2.63639
# [700]	valid_0's rmse: 2.6231
# [800]	valid_0's rmse: 2.61087
# [900]	valid_0's rmse: 2.59879
# [1000]	valid_0's rmse: 2.58809
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 2.58809
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001888 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 936
# [LightGBM] [Info] Number of data points in the train set: 81458, number of used features: 16
# [LightGBM] [Info] Start training from score 4.974355
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.70374
# [200]	valid_0's rmse: 2.68461
# [300]	valid_0's rmse: 2.6671
# [400]	valid_0's rmse: 2.65013
# [500]	valid_0's rmse: 2.63334
# [600]	valid_0's rmse: 2.61938
# [700]	valid_0's rmse: 2.60603
# [800]	valid_0's rmse: 2.59371
# [900]	valid_0's rmse: 2.58166
# [1000]	valid_0's rmse: 2.57089
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 2.57089
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002003 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 932
# [LightGBM] [Info] Number of data points in the train set: 81458, number of used features: 16
# [LightGBM] [Info] Start training from score 4.973864
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.70801
# [200]	valid_0's rmse: 2.68913
# [300]	valid_0's rmse: 2.67178
# [400]	valid_0's rmse: 2.65508
# [500]	valid_0's rmse: 2.63848
# [600]	valid_0's rmse: 2.62474
# [700]	valid_0's rmse: 2.61166
# [800]	valid_0's rmse: 2.59948
# [900]	valid_0's rmse: 2.58753
# [1000]	valid_0's rmse: 2.57693
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 2.57693
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002337 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 927
# [LightGBM] [Info] Number of data points in the train set: 81459, number of used features: 16
# [LightGBM] [Info] Start training from score 4.972023
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.68794
# [200]	valid_0's rmse: 2.66933
# [300]	valid_0's rmse: 2.6522
# [400]	valid_0's rmse: 2.63565
# [500]	valid_0's rmse: 2.61923
# [600]	valid_0's rmse: 2.60562
# [700]	valid_0's rmse: 2.59269
# [800]	valid_0's rmse: 2.58069
# [900]	valid_0's rmse: 2.56894
# [1000]	valid_0's rmse: 2.55856
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 2.55856
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002866 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 928
# [LightGBM] [Info] Number of data points in the train set: 81459, number of used features: 16
# [LightGBM] [Info] Start training from score 4.971569
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.71356
# [200]	valid_0's rmse: 2.69401
# [300]	valid_0's rmse: 2.67614
# [400]	valid_0's rmse: 2.65881
# [500]	valid_0's rmse: 2.64159
# [600]	valid_0's rmse: 2.62735
# [700]	valid_0's rmse: 2.6137
# [800]	valid_0's rmse: 2.60107
# [900]	valid_0's rmse: 2.58863
# [1000]	valid_0's rmse: 2.57764
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 2.57764
# [I 2023-10-07 23:37:25,982] Trial 8 finished with value: 2.574419490967615 and parameters: {'num_leaves': 151, 'learning_rate': 0.0007841846668900983, 'feature_fraction': 0.4088548473121184}. Best is trial 0 with value: 2.348128249245517.
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003107 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 931
# [LightGBM] [Info] Number of data points in the train set: 81458, number of used features: 16
# [LightGBM] [Info] Start training from score 4.972121
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.54101
# [200]	valid_0's rmse: 2.47472
# [300]	valid_0's rmse: 2.44591
# [400]	valid_0's rmse: 2.42813
# [500]	valid_0's rmse: 2.41647
# [600]	valid_0's rmse: 2.40704
# [700]	valid_0's rmse: 2.39786
# [800]	valid_0's rmse: 2.39089
# [900]	valid_0's rmse: 2.38675
# [1000]	valid_0's rmse: 2.38337
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 2.38337
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002424 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 936
# [LightGBM] [Info] Number of data points in the train set: 81458, number of used features: 16
# [LightGBM] [Info] Start training from score 4.974355
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.52451
# [200]	valid_0's rmse: 2.46121
# [300]	valid_0's rmse: 2.43357
# [400]	valid_0's rmse: 2.41644
# [500]	valid_0's rmse: 2.40382
# [600]	valid_0's rmse: 2.39276
# [700]	valid_0's rmse: 2.38345
# [800]	valid_0's rmse: 2.37629
# [900]	valid_0's rmse: 2.37107
# [1000]	valid_0's rmse: 2.36704
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 2.36704
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002963 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 932
# [LightGBM] [Info] Number of data points in the train set: 81458, number of used features: 16
# [LightGBM] [Info] Start training from score 4.973864
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.53099
# [200]	valid_0's rmse: 2.46773
# [300]	valid_0's rmse: 2.43997
# [400]	valid_0's rmse: 2.42338
# [500]	valid_0's rmse: 2.41213
# [600]	valid_0's rmse: 2.40119
# [700]	valid_0's rmse: 2.39243
# [800]	valid_0's rmse: 2.38529
# [900]	valid_0's rmse: 2.37994
# [1000]	valid_0's rmse: 2.37675
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 2.37675
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004870 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 927
# [LightGBM] [Info] Number of data points in the train set: 81459, number of used features: 16
# [LightGBM] [Info] Start training from score 4.972023
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.51591
# [200]	valid_0's rmse: 2.45555
# [300]	valid_0's rmse: 2.42777
# [400]	valid_0's rmse: 2.41139
# [500]	valid_0's rmse: 2.39934
# [600]	valid_0's rmse: 2.3879
# [700]	valid_0's rmse: 2.3775
# [800]	valid_0's rmse: 2.3701
# [900]	valid_0's rmse: 2.36537
# [1000]	valid_0's rmse: 2.36195
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 2.36195
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002493 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 928
# [LightGBM] [Info] Number of data points in the train set: 81459, number of used features: 16
# [LightGBM] [Info] Start training from score 4.971569
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.52903
# [200]	valid_0's rmse: 2.46195
# [300]	valid_0's rmse: 2.43286
# [400]	valid_0's rmse: 2.41596
# [500]	valid_0's rmse: 2.40467
# [600]	valid_0's rmse: 2.39437
# [700]	valid_0's rmse: 2.38373
# [800]	valid_0's rmse: 2.37691
# [900]	valid_0's rmse: 2.37212
# [1000]	valid_0's rmse: 2.36786
# Did not meet early stopping. Best iteration is:
# [999]	valid_0's rmse: 2.36786
# [I 2023-10-07 23:38:38,314] Trial 9 finished with value: 2.3713921277262364 and parameters: {'num_leaves': 255, 'learning_rate': 0.008005976617587406, 'feature_fraction': 0.837330974474216}. Best is trial 0 with value: 2.348128249245517.
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003722 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 931
# [LightGBM] [Info] Number of data points in the train set: 81458, number of used features: 16
# [LightGBM] [Info] Start training from score 4.972121
# Training until validation scores don't improve for 20 rounds
# [100]	valid_0's rmse: 2.40071
# [200]	valid_0's rmse: 2.37564
# [300]	valid_0's rmse: 2.36527
# [400]	valid_0's rmse: 2.36144
# Early stopping, best iteration is:
# [417]	valid_0's rmse: 2.36104
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002145 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 936
# [LightGBM] [Info] Number of data points in the train set: 81458, number of used features: 16
# [LightGBM] [Info] Start training from score 4.974355
# Training until validation scores don't improve for 20 rounds
# [100]	valid_0's rmse: 2.38618
# [200]	valid_0's rmse: 2.36171
# [300]	valid_0's rmse: 2.35459
# [400]	valid_0's rmse: 2.34863
# Early stopping, best iteration is:
# [474]	valid_0's rmse: 2.34538
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004220 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 932
# [LightGBM] [Info] Number of data points in the train set: 81458, number of used features: 16
# [LightGBM] [Info] Start training from score 4.973864
# Training until validation scores don't improve for 20 rounds
# [100]	valid_0's rmse: 2.3968
# [200]	valid_0's rmse: 2.37467
# [300]	valid_0's rmse: 2.36296
# [400]	valid_0's rmse: 2.35739
# Early stopping, best iteration is:
# [463]	valid_0's rmse: 2.35519
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002260 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 927
# [LightGBM] [Info] Number of data points in the train set: 81459, number of used features: 16
# [LightGBM] [Info] Start training from score 4.972023
# Training until validation scores don't improve for 20 rounds
# [100]	valid_0's rmse: 2.38221
# [200]	valid_0's rmse: 2.35987
# [300]	valid_0's rmse: 2.35165
# [400]	valid_0's rmse: 2.34699
# Early stopping, best iteration is:
# [419]	valid_0's rmse: 2.34671
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002542 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 928
# [LightGBM] [Info] Number of data points in the train set: 81459, number of used features: 16
# [LightGBM] [Info] Start training from score 4.971569
# Training until validation scores don't improve for 20 rounds
# [100]	valid_0's rmse: 2.38357
# [200]	valid_0's rmse: 2.35849
# [300]	valid_0's rmse: 2.34749
# [400]	valid_0's rmse: 2.34255
# Early stopping, best iteration is:
# [452]	valid_0's rmse: 2.33975

# %% [markdown]
# ### テストデータで予測

# %%
# 2020年から2022年のテストデータを取得
test_data_2020 = merged_df[merged_df['kaisai_nen'] == 2020].copy()
test_data_2021 = merged_df[merged_df['kaisai_nen'] == 2021].copy()
test_data_2022 = merged_df[merged_df['kaisai_nen'] == 2022].copy()

# 2021年と2022年のデータに対して予測を行い、平均を取る
test_data_2020.loc[:, 'y_pred'] = sum([model.predict(test_data_2020[features], num_iteration=model.best_iteration) for model in models]) / len(models)
test_data_2021.loc[:, 'y_pred'] = sum([model.predict(test_data_2021[features], num_iteration=model.best_iteration) for model in models]) / len(models)
test_data_2022.loc[:, 'y_pred'] = sum([model.predict(test_data_2022[features], num_iteration=model.best_iteration) for model in models]) / len(models)

# 予測されたランクをグループごとに計算
test_data_2020.loc[:, 'predicted_rank'] = test_data_2020.groupby('group')['y_pred'].rank(method='min')
test_data_2021.loc[:, 'predicted_rank'] = test_data_2021.groupby('group')['y_pred'].rank(method='min')
test_data_2022.loc[:, 'predicted_rank'] = test_data_2022.groupby('group')['y_pred'].rank(method='min')

# 結果を表示
test_data_2021[['group', 'predicted_rank', 'kakutei_chakujun']]
# Out:
#                   group  predicted_rank  kakutei_chakujun
# 115622    2021-103-55-1             4.0                 1
# 115623    2021-103-55-1             1.0                 4
# 115624    2021-103-55-1             3.0                 5
# 115625    2021-103-55-1             9.0                 3
# 115626    2021-103-55-1             6.0                10
# ...                 ...             ...               ...
# 128734  2021-1226-55-11             4.0                11
# 128736  2021-1226-55-11             7.0                 7
# 128737  2021-1226-55-11             1.0                 4
# 128738  2021-1226-55-11            11.0                10
# 128739  2021-1226-55-11             9.0                 8
#
# [12973 rows x 3 columns]

# %% [markdown]
# ## モデル評価

# %%
# RMSEを計算
rmse_2020 = np.sqrt(mean_squared_error(test_data_2020['predicted_rank'], test_data_2020['kakutei_chakujun']))
print(f"2021 RMSE: {rmse_2020:.3%}")
rmse_2021 = np.sqrt(mean_squared_error(test_data_2021['predicted_rank'], test_data_2021['kakutei_chakujun']))
print(f"2021 RMSE: {rmse_2021:.3%}")
rmse_2022 = np.sqrt(mean_squared_error(test_data_2022['predicted_rank'], test_data_2022['kakutei_chakujun']))
print(f"2022 RMSE: {rmse_2022:.3%}")
rmse_mean = np.mean([rmse_2020, rmse_2021, rmse_2022])
print(f"Mean RMSE: {rmse_mean:.3%}")
# Out:
# 2021 RMSE: 357.551%
# 2021 RMSE: 384.549%
# 2022 RMSE: 370.823%
# Mean RMSE: 370.974%

# %%
group_ids_2020 = test_data_2020['group'].unique()
precisions = []
recalls = []

# %%
def precision_at_5(predictions, actual):
    top_5_predictions = predictions.argsort()[-5:][::-1]  # 予測の上位5頭のインデックス
    top_3_actual = actual.argsort()[-3:][::-1]  # 実際の上位3頭のインデックス
    common_elements = np.intersect1d(top_5_predictions, top_3_actual)  # 共通の要素を抽出
    precision = len(common_elements) / 5
    return precision

def recall_at_5(predictions, actual):
    top_5_predictions = predictions.argsort()[-5:][::-1]  # 予測の上位5頭のインデックス
    top_3_actual = actual.argsort()[-3:][::-1]  # 実際の上位3頭のインデックス
    common_elements = np.intersect1d(top_5_predictions, top_3_actual)  # 共通の要素を抽出
    recall = len(common_elements) / 3
    return recall

# %%
def check_top3_in_top5_predictions(group):
    predicted_top5 = group.nsmallest(5, 'y_pred').index.tolist()
    actual_top3 = group.nsmallest(3, 'kakutei_chakujun').index.tolist()
    return all([horse in predicted_top5 for horse in actual_top3])

def calculate_group_profit(group):
    if check_top3_in_top5_predictions(group):
        payout_value = group['haraimodoshi_sanrenpuku_1b'].iloc[0]
        return payout_value - 1000
    else:
        return -1000

# %%
for test_data in [test_data_2020, test_data_2021, test_data_2022]:
    merged_data = test_data
    profits = merged_data.groupby('group').apply(calculate_group_profit).reset_index()
    profits.columns = ['group', 'profit']
    test_data = pd.merge(test_data, profits, on='group', how='left')

for group_id in group_ids_2020:
    test_data = test_data_2020[test_data_2020['group'] == group_id]
    p = precision_at_5(test_data['predicted_rank'].values, test_data['kakutei_chakujun'].values)
    r = recall_at_5(test_data['predicted_rank'].values, test_data['kakutei_chakujun'].values)
    precisions.append(p)
    recalls.append(r)

precision_5_2020 = np.mean(precisions)
recall_5_2020 = np.mean(recalls)

print(f"2020 Precision@5: {precision_5_2020:.3%}")
print(f"2020 Recall@5: {recall_5_2020:.3%}")

group_ids_2021 = test_data_2021['group'].unique()
precisions = []
recalls = []
# Out:
# 2020 Precision@5: 37.866%
# 2020 Recall@5: 63.111%

# %%
for group_id in group_ids_2021:
    test_data = test_data_2021[test_data_2021['group'] == group_id]
    p = precision_at_5(test_data['predicted_rank'].values, test_data['kakutei_chakujun'].values)
    r = recall_at_5(test_data['predicted_rank'].values, test_data['kakutei_chakujun'].values)
    precisions.append(p)
    recalls.append(r)

precision_5_2021 = np.mean(precisions)
recall_5_2021 = np.mean(recalls)

print(f"2021 Precision@5: {precision_5_2021:.3%}")
print(f"2021 Recall@5: {recall_5_2021:.3%}")


roup_ids_2022 = test_data_2022['group'].unique()
precisions = []
recalls = []

for group_id in roup_ids_2022:
    test_data = test_data_2022[test_data_2022['group'] == group_id]
    p = precision_at_5(test_data['predicted_rank'].values, test_data['kakutei_chakujun'].values)
    r = recall_at_5(test_data['predicted_rank'].values, test_data['kakutei_chakujun'].values)
    precisions.append(p)
    recalls.append(r)

precision_5_2022 = np.mean(precisions)
recall_5_2022 = np.mean(recalls)

print(f"2022 Precision@5: {precision_5_2022:.3%}")
print(f"2022 Recall@5: {recall_5_2022:.3%}")


precision_5_mean = np.mean([precision_5_2020, precision_5_2021, precision_5_2022])
recall_5_mean = np.mean([recall_5_2020, recall_5_2021, recall_5_2022])

print(f"Mean Precision@5: {precision_5_mean:.3%}")
print(f"Mean Recall@5: {recall_5_mean:.3%}")

# 各レースで上記の関数を適用
results_2020 = test_data_2020.groupby('group').apply(check_top3_in_top5_predictions)
results_2021 = test_data_2021.groupby('group').apply(check_top3_in_top5_predictions)
results_2022 = test_data_2022.groupby('group').apply(check_top3_in_top5_predictions)

# 予測モデルが成功したレースのインデックスを取得する
successful_groups_2020 = results_2020[results_2020].index
successful_groups_2021 = results_2021[results_2021].index
successful_groups_2022 = results_2022[results_2022].index

# そのインデックスを使用して、harai_dfから対応する支払倍率を取得する
successful_payout_2020 = merged_df[merged_df['group'].isin(successful_groups_2020)]
successful_payout_2021 = merged_df[merged_df['group'].isin(successful_groups_2021)]
successful_payout_2022 = merged_df[merged_df['group'].isin(successful_groups_2022)]

payouts_2020 = successful_payout_2020['haraimodoshi_sanrenpuku_1b']
payouts_2021 = successful_payout_2021['haraimodoshi_sanrenpuku_1b']
payouts_2022 = successful_payout_2022['haraimodoshi_sanrenpuku_1b']

# すべての成功したレースに対して、100円をかけた場合の支払いを計算する
total_payout_2020 = (payouts_2020).sum()
total_payout_2021 = (payouts_2021).sum()
total_payout_2022 = (payouts_2022).sum()

# 合計の支払いから、すべてのレースにかけた合計金額を引くことで、純利益を計算する
total_investment_2020 = test_data_2020['group'].nunique() * 1000
total_investment_2021 = test_data_2021['group'].nunique() * 1000
total_investment_2022 = test_data_2021['group'].nunique() * 1000

net_profit_2020 = total_payout_2020 - total_investment_2020
net_profit_2021 = total_payout_2021 - total_investment_2021
net_profit_2022 = total_payout_2022 - total_investment_2022

average_net_profit_2020 = net_profit_2020/len(test_data_2020)
average_net_profit_2021 = net_profit_2021/len(test_data_2021)
average_net_profit_2022 = net_profit_2020/len(test_data_2022)

print(f"2020 Average Net Profit: {average_net_profit_2020:.3f} yen")
print(f"2021 Average Net Profit: {average_net_profit_2021:.3f} yen")
print(f"2022 Average Net Profit: {average_net_profit_2022:.3f} yen")

mean_average_net_profit = np.mean([average_net_profit_2020, average_net_profit_2021, average_net_profit_2022])
print(f"Mean Average Net Profit: {mean_average_net_profit:.3f} yen")
# Out:
# 2021 Precision@5: 36.541%
# 2021 Recall@5: 60.901%
# 2022 Precision@5: 36.375%
# 2022 Recall@5: 60.625%
# Mean Precision@5: 36.927%
# Mean Recall@5: 61.545%
# 2020 Average Net Profit: 571.944 yen
# 2021 Average Net Profit: 583.348 yen
# 2022 Average Net Profit: 557.656 yen
# Mean Average Net Profit: 570.983 yen

# %%
# models[0]の特徴量の重要度を取得
feature_importance = models[0].feature_importance(importance_type='gain')

# 特徴量の名前と重要度をDataFrameに変換
importance_df = pd.DataFrame({
    'Feature': features,
    'Importance': feature_importance
})

# 重要度の降順にソート
importance_df = importance_df.sort_values(by='Importance', ascending=False)

# プロット
plt.figure(figsize=(10, 8))
sns.barplot(data=importance_df, x='Importance', y='Feature')
plt.title('Feature Importance')
plt.tight_layout()
plt.show()

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt

# # 1. 箱ひげ図
# for feature in features:
#     plt.figure(figsize=(10, 6))
#     sns.boxplot(x='kyakushitsu_hantei', y=feature, data=test_data_2020)
#     plt.title(f'Box plot of {feature} by label')
#     plt.show()

# # 2. バイオリンプロット
# for feature in features:
#     plt.figure(figsize=(10, 6))
#     sns.violinplot(x='kyakushitsu_hantei', y=feature, data=test_data_2020)
#     plt.title(f'Violin plot of {feature} by label')
#     plt.show()

# # 3. ペアプロット (特徴量が多すぎる場合は時間がかかる可能性があるので注意)
# sns.pairplot(test_data_2020, hue='kyakushitsu_hantei', vars=features)
# plt.show()

# %% [markdown]
# # モデル保存

# %%
# 学習
full_train_dataset = lgb.Dataset(merged_df[features], label=merged_df[target])
full_model = lgb.train(best_params, full_train_dataset, num_boost_round=500, verbose_eval=100)  # ここではvalid_setsやearly_stopping_roundsは使用しない

# モデルを保存
model_save_path = 'bestmodels/saga.pkl'
with open(model_save_path, 'wb') as f:
    pickle.dump(full_model, f)

print(f"Model saved to {model_save_path}")
# Out:
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003666 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 849
# [LightGBM] [Info] Number of data points in the train set: 149139, number of used features: 16
# [LightGBM] [Info] Start training from score 5.126573
# Model saved to bestmodels/saga.pkl
