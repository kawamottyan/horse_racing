# %% [markdown]
# # preparation

# %%
import pandas as pd
import numpy as np
from scipy import stats
from sklearn.preprocessing import MinMaxScaler

#モデル
import lightgbm as lgb

#パラメータ探索
import optuna

#クロスバリデーション
from sklearn.model_selection import KFold

#エヴァリュエーション
from sklearn.metrics import precision_score, recall_score, mean_squared_error

#可視化
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score, classification_report

#保存
import pickle

# %%
#42, 36, 54, 47, 55

# %%
#データを読み込む
j_uma_race_df = pd.read_pickle('../datasets/traindata/j_uma_race.pkl')
j_race_df = pd.read_pickle('../datasets/traindata/j_race.pkl')
# j_payout_df = pd.read_pickle('../datasets/traindata/j_payout.pkl')

n_uma_race_df = pd.read_pickle('../datasets/traindata/n_uma_race.pkl')
n_race_df = pd.read_pickle('../datasets/traindata/n_race.pkl')
n_payout_df = pd.read_pickle('../datasets/traindata/n_payout.pkl')

# %% [markdown]
# ### データの削除

# %%
#浦和競馬場に絞る
pd.set_option('display.max_columns', None)
urayasu_uma_race = n_uma_race_df[n_uma_race_df['keibajo_code'].astype(str) == '42']
urayasu_race = n_race_df[n_race_df['keibajo_code'].astype(str) == '42']
urayasu_uma_race
# Out:
#          kaisai_nen  kaisai_tsukihi keibajo_code  kaisai_kai  kaisai_nichime  \
# 3876           2010             106           42           9               1
# 3877           2010             106           42           9               1
# 3878           2010             106           42           9               1
# 3879           2010             106           42           9               1
# 3880           2010             106           42           9               1
# ...             ...             ...          ...         ...             ...
# 2039620        2023             901           42           6               5
# 2039621        2023             901           42           6               5
# 2039622        2023             901           42           6               5
# 2039623        2023             901           42           6               5
# 2039624        2023             901           42           6               5
#
#          race_bango  wakuban  umaban  ketto_toroku_bango               bamei  \
# 3876              1        1       1          2007100175  マリモゴゼン
# 3877              1        2       2          2007106295  ダッフィーキャスト
# 3878              1        3       3          2007102327  ハイサイキヨフミ
# 3879              1        4       4          2007101934  トーホーラムタラ
# 3880              1        5       5          2007105597  ブラウンランカー
# ...             ...      ...     ...                 ...                 ...
# 2039620          12        6       6          2019106318  エンバース
# 2039621          12        7       7          2019104782  ストームシャドウ
# 2039622          12        7       8          2019107077  シェナハート
# 2039623          12        8       9          2018102269  シークレットギア
# 2039624          12        8      10          2017103929  アキコノユメヲ
#
#          umakigo_code  seibetsu_code  hinshu_code  moshoku_code  barei  \
# 3876                0              2          1.0             1      3
# 3877                0              1          1.0             3      3
# 3878                0              1          1.0             3      3
# 3879                0              1          1.0             1      3
# 3880                0              1          1.0             3      3
# ...               ...            ...          ...           ...    ...
# 2039620             0              1          1.0             3      4
# 2039621             0              1          1.0             3      4
# 2039622             0              2          1.0             4      4
# 2039623             0              1          1.0             3      5
# 2039624             0              2          1.0             1      6
#
#          tozai_shozoku_code  chokyoshi_code  banushi_code  \
# 3876                      3            5651             0
# 3877                      3            5656             0
# 3878                      3           20421             0
# 3879                      3           20338             0
# 3880                      3            5101         95008
# ...                     ...             ...           ...
# 2039620                   3            5015        228031
# 2039621                   3            5496             0
# 2039622                   3           20593        897033
# 2039623                   3           20469        875800
# 2039624                   3           20697             0
#
#                                banushimei  futan_juryo  blinker_shiyo_kubun  \
# 3876     アイファー　　　　　　　　　　　　　　　　　　　　　　　　　　　        530.0                    0
# 3877     宮下　昌尚　　　　　　　　　　　　　　　　　　　　　　　　　　　        540.0                    0
# 3878     清水　透　　　　　　　　　　　　　　　　　　　　　　　　　　　　        540.0                    0
# 3879     東邦商事　　　　　　　　　　　　　　　　　　　　　　　　　　　　        540.0                    0
# 3880     小島　史代　　　　　　　　　　　　　　　　　　　　　　　　　　　        540.0                    0
# ...                                   ...          ...                  ...
# 2039620  小橋　亮太　　　　　　　　　　　　　　　　　　　　　　　　　　　        560.0                    0
# 2039621  大久保　秀一　　　　　　　　　　　　　　　　　　　　　　　　　　        560.0                    0
# 2039622  冨田　藤男　　　　　　　　　　　　　　　　　　　　　　　　　　　        500.0                    0
# 2039623  ＪＰＮ技研　　　　　　　　　　　　　　　　　　　　　　　　　　　        560.0                    0
# 2039624  門別　正　　　　　　　　　　　　　　　　　　　　　　　　　　　　        540.0                    0
#
#          kishu_code kishumei_ryakusho  kishu_minarai_code  bataiju  \
# 3876           5269              繁田健一                   0    429.0
# 3877          20465              山崎真　                   0    441.0
# 3878           5348              岡田大　                   0    480.0
# 3879            424              見沢譲治                   0    432.0
# 3880            817              的場文男                   0    457.0
# ...             ...               ...                 ...      ...
# 2039620        5348              岡田大　                   0    491.0
# 2039621       20485              笠野雄大                   0    480.0
# 2039622       21301              中島良美                   4    411.0
# 2039623        5248              加藤和博                   0    491.0
# 2039624        5272              岡村裕基                   0    427.0
#
#          zogen_fugo  zogen_sa  ijo_kubun_code  nyusen_juni  kakutei_chakujun  \
# 3876              2       5.0               0            8                 8
# 3877              0      10.0               0           11                11
# 3878              0       1.0               0           10                10
# 3879              0       2.0               0            6                 6
# 3880              0       2.0               0            9                 9
# ...             ...       ...             ...          ...               ...
# 2039620           0       2.0               0            5                 5
# 2039621           2       8.0               0            2                 2
# 2039622           0       9.0               0            7                 7
# 2039623           0       2.0               0            4                 4
# 2039624           0       3.0               0            8                 8
#
#          dochaku_kubun  dochaku_tosu  soha_time  chakusa_code_1  \
# 3876                 0             0       1355             NaN
# 3877                 0             0       1372             5.0
# 3878                 0             0       1363             4.0
# 3879                 0             0       1350           212.0
# 3880                 0             0       1356            12.0
# ...                ...           ...        ...             ...
# 2039620              0             0       2171             1.0
# 2039621              0             0       2163             4.0
# 2039622              0             0       2183             4.0
# 2039623              0             0       2169             2.0
# 2039624              0             0       2194             5.0
#
#          chakusa_code_2  chakusa_code_3  corner_1  corner_2  corner_3  \
# 3876                NaN             NaN         3         3         7
# 3877                NaN             NaN         1         1         4
# 3878                NaN             NaN         9        10        11
# 3879                NaN             NaN        10         9        10
# 3880                NaN             NaN         8         7         9
# ...                 ...             ...       ...       ...       ...
# 2039620             NaN             NaN         2         2         1
# 2039621             NaN             NaN         9         7         4
# 2039622             NaN             NaN         4         4         5
# 2039623             NaN             NaN         3         3         1
# 2039624             NaN             NaN        10        10        10
#
#          corner_4  tansho_odds  tansho_ninkijun  kakutoku_honshokin  \
# 3876            7            0                0                   0
# 3877           10            0                0                   0
# 3878           11            0                0                   0
# 3879            9            0                0                   0
# 3880            8            0                0                   0
# ...           ...          ...              ...                 ...
# 2039620         2          188                7                1400
# 2039621         4           63                4                5600
# 2039622         7          665                8                   0
# 2039623         3           58                3                2100
# 2039624        10          709                9                   0
#
#          kakutoku_fukashokin  kohan_4f  kohan_3f  \
# 3876                       0         0       428
# 3877                       0         0       446
# 3878                       0         0       427
# 3879                       0         0       416
# 3880                       0         0       427
# ...                      ...       ...       ...
# 2039620                    0         0       425
# 2039621                    0         0       412
# 2039622                    0         0       434
# 2039623                    0         0       423
# 2039624                    0         0       429
#
#                        aiteuma_joho_1                aiteuma_joho_2  \
# 3876     2007105254ファーストバレー　　　　　　　　　　  0000000000
# 3877     2007105254ファーストバレー　　　　　　　　　　  0000000000
# 3878     2007105254ファーストバレー　　　　　　　　　　  0000000000
# 3879     2007105254ファーストバレー　　　　　　　　　　  0000000000
# 3880     2007105254ファーストバレー　　　　　　　　　　  0000000000
# ...                               ...                           ...
# 2039620  2018105997カイジンビリーヴ　　　　　　　　　　  0000000000
# 2039621  2018105997カイジンビリーヴ　　　　　　　　　　  0000000000
# 2039622  2018105997カイジンビリーヴ　　　　　　　　　　  0000000000
# 2039623  2018105997カイジンビリーヴ　　　　　　　　　　  0000000000
# 2039624  2018105997カイジンビリーヴ　　　　　　　　　　  0000000000
#
#                        aiteuma_joho_3  time_sa  record_koshin_kubun  \
# 3876     0000000000　　　　　　　　　　　　　　　　　　       25                    0
# 3877     0000000000　　　　　　　　　　　　　　　　　　       42                    0
# 3878     0000000000　　　　　　　　　　　　　　　　　　       33                    0
# 3879     0000000000　　　　　　　　　　　　　　　　　　       20                    0
# 3880     0000000000　　　　　　　　　　　　　　　　　　       26                    0
# ...                               ...      ...                  ...
# 2039620  0000000000　　　　　　　　　　　　　　　　　　       17                    0
# 2039621  0000000000　　　　　　　　　　　　　　　　　　        9                    0
# 2039622  0000000000　　　　　　　　　　　　　　　　　　       29                    0
# 2039623  0000000000　　　　　　　　　　　　　　　　　　       15                    0
# 2039624  0000000000　　　　　　　　　　　　　　　　　　       40                    0
#
#          kyakushitsu_hantei
# 3876                      0
# 3877                      0
# 3878                      0
# 3879                      0
# 3880                      0
# ...                     ...
# 2039620                   0
# 2039621                   0
# 2039622                   0
# 2039623                   0
# 2039624                   0
#
# [91678 rows x 52 columns]

# %% [markdown]
# # LightGBM

# %% [markdown]
# ## グループクエリ用のカラムを作成

# %%
# 新しいグループを作成
urayasu_uma_race['group'] = urayasu_uma_race['kaisai_nen'].astype(int).astype(str) +"-"+ urayasu_uma_race['kaisai_tsukihi'].astype(int).astype(str) +"-"+  urayasu_uma_race['keibajo_code'].astype(int).astype(str) +"-"+  urayasu_uma_race['race_bango'].astype(int).astype(str)
urayasu_race['group'] = urayasu_race['kaisai_nen'].astype(int).astype(str) +"-"+ urayasu_race['kaisai_tsukihi'].astype(int).astype(str) +"-"+  urayasu_race['keibajo_code'].astype(int).astype(str) +"-"+  urayasu_race['race_bango'].astype(int).astype(str)
n_payout_df['group'] = n_payout_df['kaisai_nen'].astype(int).astype(str) +"-"+ n_payout_df['kaisai_tsukihi'].astype(int).astype(str) +"-"+  n_payout_df['keibajo_code'].astype(int).astype(str) +"-"+  n_payout_df['race_bango'].astype(int).astype(str)
# Out:
# C:\Users\kawam\AppData\Local\Temp\ipykernel_23896\3114523199.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   urayasu_uma_race['group'] = urayasu_uma_race['kaisai_nen'].astype(int).astype(str) +"-"+ urayasu_uma_race['kaisai_tsukihi'].astype(int).astype(str) +"-"+  urayasu_uma_race['keibajo_code'].astype(int).astype(str) +"-"+  urayasu_uma_race['race_bango'].astype(int).astype(str)
# C:\Users\kawam\AppData\Local\Temp\ipykernel_23896\3114523199.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   urayasu_race['group'] = urayasu_race['kaisai_nen'].astype(int).astype(str) +"-"+ urayasu_race['kaisai_tsukihi'].astype(int).astype(str) +"-"+  urayasu_race['keibajo_code'].astype(int).astype(str) +"-"+  urayasu_race['race_bango'].astype(int).astype(str)

# %%
urayasu_uma_race['group'].unique()
# Out:
# array(['2010-106-42-1', '2010-106-42-2', '2010-106-42-3', ...,
#        '2023-901-42-10', '2023-901-42-11', '2023-901-42-12'], dtype=object)

# %%
urayasu_race['group'].unique()
# Out:
# array(['2021-106-42-1', '2021-106-42-2', '2021-106-42-3', ...,
#        '2020-1225-42-9', '2020-1225-42-10', '2020-1225-42-11'],
#       dtype=object)

# %%
urayasu_race = urayasu_race.drop(['kaisai_nen', 'kaisai_tsukihi', 'keibajo_code', 'kaisai_kai', 'kaisai_nichime', 'race_bango'],axis=1)
n_payout_df = n_payout_df.drop(['kaisai_nen', 'kaisai_tsukihi', 'keibajo_code', 'kaisai_kai', 'kaisai_nichime', 'race_bango', 'toroku_tosu', 'shusso_tosu'],axis=1)

# %%
merged_df = pd.merge(urayasu_uma_race, urayasu_race, on='group', how='left')
merged_df = pd.merge(merged_df, n_payout_df, on='group', how='left')
merged_df['group'].nunique()
# Out:
# 8343

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91678 entries, 0 to 91677
# Data columns (total 82 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   kaisai_nen                  91678 non-null  int64
#  1   kaisai_tsukihi              91678 non-null  int64
#  2   keibajo_code                91678 non-null  object
#  3   kaisai_kai                  91678 non-null  int64
#  4   kaisai_nichime              91678 non-null  int64
#  5   race_bango                  91678 non-null  int64
#  6   wakuban                     91678 non-null  int64
#  7   umaban                      91678 non-null  int64
#  8   ketto_toroku_bango          91678 non-null  int64
#  9   bamei                       91678 non-null  object
#  10  umakigo_code                91678 non-null  int64
#  11  seibetsu_code               91678 non-null  int64
#  12  hinshu_code                 91678 non-null  float64
#  13  moshoku_code                91678 non-null  int64
#  14  barei                       91678 non-null  int64
#  15  tozai_shozoku_code          91678 non-null  int64
#  16  chokyoshi_code              91678 non-null  int64
#  17  banushi_code                91678 non-null  int64
#  18  banushimei                  91678 non-null  object
#  19  futan_juryo                 91678 non-null  float64
#  20  blinker_shiyo_kubun         91678 non-null  int64
#  21  kishu_code                  91678 non-null  int64
#  22  kishumei_ryakusho           91678 non-null  object
#  23  kishu_minarai_code          91678 non-null  int64
#  24  bataiju                     91678 non-null  float64
#  25  zogen_fugo                  91678 non-null  int64
#  26  zogen_sa                    89629 non-null  float64
#  27  ijo_kubun_code              91678 non-null  int64
#  28  nyusen_juni                 91678 non-null  int64
#  29  kakutei_chakujun            91678 non-null  int64
#  30  dochaku_kubun               91678 non-null  int64
#  31  dochaku_tosu                91678 non-null  int64
#  32  soha_time                   91678 non-null  int64
#  33  chakusa_code_1              62359 non-null  float64
#  34  chakusa_code_2              2 non-null      float64
#  35  chakusa_code_3              0 non-null      float64
#  36  corner_1                    91678 non-null  int64
#  37  corner_2                    91678 non-null  int64
#  38  corner_3                    91678 non-null  int64
#  39  corner_4                    91678 non-null  int64
#  40  tansho_odds                 91678 non-null  int64
#  41  tansho_ninkijun             91678 non-null  int64
#  42  kakutoku_honshokin          91678 non-null  int64
#  43  kakutoku_fukashokin         91678 non-null  int64
#  44  kohan_4f                    91678 non-null  int64
#  45  kohan_3f                    91678 non-null  int64
#  46  aiteuma_joho_1              91678 non-null  object
#  47  aiteuma_joho_2              91678 non-null  object
#  48  aiteuma_joho_3              91678 non-null  object
#  49  time_sa                     91678 non-null  int64
#  50  record_koshin_kubun         91678 non-null  int64
#  51  kyakushitsu_hantei          91678 non-null  int64
#  52  group                       91678 non-null  object
#  53  yobi_code                   91678 non-null  int64
#  54  jusho_kaiji                 91678 non-null  int64
#  55  grade_code                  91678 non-null  int64
#  56  kyoso_shubetsu_code         91678 non-null  int64
#  57  kyoso_kigo_code             91678 non-null  int64
#  58  juryo_shubetsu_code         91678 non-null  int64
#  59  kyoso_joken_code_2sai       91678 non-null  int64
#  60  kyoso_joken_code_3sai       91678 non-null  int64
#  61  kyoso_joken_code_4sai       91678 non-null  int64
#  62  kyoso_joken_code_5sai_ijo   91678 non-null  int64
#  63  kyoso_joken_code            91678 non-null  int64
#  64  kyori                       91678 non-null  int64
#  65  track_code                  91678 non-null  int64
#  66  course_kubun                91678 non-null  int64
#  67  honshokin                   91678 non-null  float64
#  68  fukashokin                  91678 non-null  int64
#  69  hasso_jikoku                91678 non-null  int64
#  70  toroku_tosu                 91678 non-null  int64
#  71  shusso_tosu                 91678 non-null  int64
#  72  nyusen_tosu                 91678 non-null  int64
#  73  tenko_code                  91678 non-null  int64
#  74  babajotai_code_shiba        91678 non-null  int64
#  75  babajotai_code_dirt         91678 non-null  float64
#  76  fuseiritsu_flag_sanrenpuku  91237 non-null  float64
#  77  tokubarai_flag_sanrenpuku   91237 non-null  float64
#  78  henkan_flag_sanrenpuku      91237 non-null  float64
#  79  haraimodoshi_sanrenpuku_1a  91237 non-null  float64
#  80  haraimodoshi_sanrenpuku_1b  91237 non-null  float64
#  81  haraimodoshi_sanrenpuku_1c  90865 non-null  float64
# dtypes: float64(15), int64(59), object(8)
# memory usage: 57.4+ MB

# %%
pd.set_option('display.max_columns', None)
merged_df.head(1)
# Out:
#    kaisai_nen  kaisai_tsukihi keibajo_code  kaisai_kai  kaisai_nichime  \
# 0        2010             106           42           9               1
#
#    race_bango  wakuban  umaban  ketto_toroku_bango               bamei  \
# 0           1        1       1          2007100175  マリモゴゼン
#
#    umakigo_code  seibetsu_code  hinshu_code  moshoku_code  barei  \
# 0             0              2          1.0             1      3
#
#    tozai_shozoku_code  chokyoshi_code  banushi_code  \
# 0                   3            5651             0
#
#                          banushimei  futan_juryo  blinker_shiyo_kubun  \
# 0  アイファー　　　　　　　　　　　　　　　　　　　　　　　　　　　        530.0                    0
#
#    kishu_code kishumei_ryakusho  kishu_minarai_code  bataiju  zogen_fugo  \
# 0        5269              繁田健一                   0    429.0           2
#
#    zogen_sa  ijo_kubun_code  nyusen_juni  kakutei_chakujun  dochaku_kubun  \
# 0       5.0               0            8                 8              0
#
#    dochaku_tosu  soha_time  chakusa_code_1  chakusa_code_2  chakusa_code_3  \
# 0             0       1355             NaN             NaN             NaN
#
#    corner_1  corner_2  corner_3  corner_4  tansho_odds  tansho_ninkijun  \
# 0         3         3         7         7            0                0
#
#    kakutoku_honshokin  kakutoku_fukashokin  kohan_4f  kohan_3f  \
# 0                   0                    0         0       428
#
#                  aiteuma_joho_1                aiteuma_joho_2  \
# 0  2007105254ファーストバレー　　　　　　　　　　  0000000000
#
#                  aiteuma_joho_3  time_sa  record_koshin_kubun  \
# 0  0000000000　　　　　　　　　　　　　　　　　　       25                    0
#
#    kyakushitsu_hantei          group  yobi_code  jusho_kaiji  grade_code  \
# 0                   0  2010-106-42-1          6            0           0
#
#    kyoso_shubetsu_code  kyoso_kigo_code  juryo_shubetsu_code  \
# 0                   12                0                    0
#
#    kyoso_joken_code_2sai  kyoso_joken_code_3sai  kyoso_joken_code_4sai  \
# 0                      0                      0                      0
#
#    kyoso_joken_code_5sai_ijo  kyoso_joken_code  kyori  track_code  \
# 0                          0                 0   1400          23
#
#    course_kubun     honshokin  fukashokin  hasso_jikoku  toroku_tosu  \
# 0             0  1.300000e+52           0          1030           12
#
#    shusso_tosu  nyusen_tosu  tenko_code  babajotai_code_shiba  \
# 0           11           11           1                     0
#
#    babajotai_code_dirt  fuseiritsu_flag_sanrenpuku  tokubarai_flag_sanrenpuku  \
# 0                  1.0                         0.0                        0.0
#
#    henkan_flag_sanrenpuku  haraimodoshi_sanrenpuku_1a  \
# 0                     0.0                     60712.0
#
#    haraimodoshi_sanrenpuku_1b  haraimodoshi_sanrenpuku_1c
# 0                      2180.0                         NaN

# %%
merged_df['kyori'].value_counts()
# Out:
# kyori
# 1400    50685
# 1500    23267
# 800      6109
# 1600     5713
# 1300     3657
# 2000     1752
# 1900      495
# Name: count, dtype: int64

# %%
merged_df['track_code'].unique()
#23:平地　ダート 左回り
# Out:
# array([23], dtype=int64)

# %%
merged_df['grade_code'].value_counts()
# 1	G1（平地競走）
# 2	G2（平地競走）
# 3	G3（平地競走）
# 4	グレードのない重賞
# 5	重賞以外の特別競走
# 6	J･G1（障害競走）
# 7	J･G2（障害競走）
# 8	J･G3（障害競走）
# 0	一般競走　または未設定・未整備時の初期値(主に地方競馬・海外国際レースに関するデータ)
# Out:
# grade_code
# 0    67763
# 5    23437
# 2      293
# 3      137
# 1       36
# 4       12
# Name: count, dtype: int64

# %%
merged_df['umakigo_code'].value_counts()
# 00	下記以外　または未設定・未整備時の初期値(主に地方競馬・海外国際レースに関するデータ)
# Out:
# umakigo_code
# 0    91678
# Name: count, dtype: int64

# %%
merged_df['seibetsu_code'].value_counts()
# 0	未設定・未整備時の初期値(主に地方競馬・海外国際レースに関するデータ)
# 1	牡馬
# 2	牝馬
# 3	セン馬
# Out:
# seibetsu_code
# 2    44555
# 1    43256
# 3     3867
# Name: count, dtype: int64

# %%
merged_df['hinshu_code'].value_counts()
# 0	未設定・未整備時の初期値(主に地方競馬・海外国際レースに関するデータ)
# 1	サラブレッド	サラ	サラブレッドとして登録したもの。
# 2	サラブレッド系種	サラ系	アラブの血量が２５％未満
# 3	準サラブレッド	準サラ	昭和49年6月1日の登録規定改定により「準サラ」は「サラ系」となり、「準サラ」の品種は廃止された。
# 4	軽半血種	軽半	アングロノルマン、アングロノルマン系種または中半血種と連続2代以上にあたり、軽種を交配したもの。軽半血種相互の交配によって生まれたもの。
# 5	アングロアラブ	アア	アラブの血量が２５％以上（父母の組み合わせにより「アラ系」と異なる。）
# 6	アラブ系種	アラ系	アラブの血量が２５％以上（父母の組み合わせにより「アア」と異なる。）
# 7	アラブ	アラブ	純血のアラブ
# 8	中半血種	中半	異種の中間相互、中半血種の中間相互、の交配で生まれたもの。中半血種と軽種、アングロノルマンとサラブレッドを除く軽種、重半血種と軽種を交配して生まれたもの。
# Out:
# hinshu_code
# 1.0    91543
# 2.0      135
# Name: count, dtype: int64

# %%
merged_df['moshoku_code'].value_counts()
# 00	未設定・未整備時の初期値(主に地方競馬・海外国際レースに関するデータ)
# 01	栗毛	chestnut	ch.
# 02	栃栗毛	dark chestnut	d.ch.
# 03	鹿毛	bay	b.
# 04	黒鹿毛	dark bay	d.b.
# 05	青鹿毛	brown	br.
# 06	青毛	black	bl.
# 07	芦毛	grey	g.
# 08	栗粕毛		
# 09	鹿粕毛		
# 10	青粕毛		
# 11	白毛	white	w.
# Out:
# moshoku_code
# 3     39294
# 1     22594
# 4     17067
# 5      5669
# 7      5335
# 6      1159
# 2       559
# 11        1
# Name: count, dtype: int64

# %%
merged_df['barei'].value_counts()
# Out:
# barei
# 4     23504
# 3     20927
# 5     16671
# 6     11820
# 7      7955
# 2      5588
# 8      3836
# 9      1349
# 10       22
# 11        5
# 12        1
# Name: count, dtype: int64

# %%
merged_df['kishu_code'].value_counts()
# Out:
# kishu_code
# 5347     3840
# 5342     3753
# 20340    3131
# 20339    2588
# 5269     2465
#          ...
# 5489        1
# 894         1
# 1152        1
# 700         1
# 21335       1
# Name: count, Length: 361, dtype: int64

# %%
merged_df['chokyoshi_code'].value_counts()
# Out:
# chokyoshi_code
# 5609     5574
# 20593    3280
# 5656     3190
# 5101     3146
# 20444    2970
#          ...
# 1135        1
# 5726        1
# 1134        1
# 397         1
# 1182        1
# Name: count, Length: 472, dtype: int64

# %%
merged_df['banushi_code'].value_counts()
# Out:
# banushi_code
# 0         38734
# 897033     3938
# 830800     1471
# 391033     1449
# 270006     1330
#           ...
# 395033        1
# 624800        1
# 51700         1
# 844800        1
# 934006        1
# Name: count, Length: 1561, dtype: int64

# %%
merged_df['kishu_minarai_code'].value_counts()
# 0	下記以外　または未設定・未整備時の初期値(主に地方競馬・海外国際レースに関するデータ)
# 1	☆	1Kg減	通算免許期間が3年未満の騎手で勝利数が51回以上100回以下(2004年から) 通算免許期間が3年未満の騎手で勝利数が31回以上100回以下(2003年まで)
# 2	△	2Kg減	通算免許期間が3年未満の騎手で勝利数が31回以上50回以下(2004年から) 通算免許期間が3年未満の騎手で勝利数が21回以上30回以下(2003年まで)
# 3	▲	3Kg減	通算免許期間が3年未満の騎手で勝利数が30回以下(2004年から) 通算免許期間が3年未満の騎手で勝利数が20回以下(2003年まで)
# Out:
# kishu_minarai_code
# 0    84074
# 1     2718
# 3     2228
# 2     1645
# 4     1013
# Name: count, dtype: int64

# %%
merged_df['futan_juryo'].value_counts()
# Out:
# futan_juryo
# 540.0    36677
# 560.0    32506
# 550.0     8441
# 530.0     6370
# 570.0     3478
# 520.0     1610
# 510.0     1417
# 500.0      726
# 580.0      312
# 545.0       64
# 565.0       33
# 490.0       21
# 535.0        6
# 590.0        3
# 480.0        3
# 555.0        3
# 515.0        3
# 505.0        2
# 525.0        2
# 470.0        1
# Name: count, dtype: int64

# %%
merged_df['bataiju'].value_counts()
# Out:
# bataiju
# 465.0    1222
# 460.0    1213
# 472.0    1196
# 468.0    1185
# 454.0    1184
#          ...
# 602.0       1
# 598.0       1
# 616.0       1
# 361.0       1
# 338.0       1
# Name: count, Length: 242, dtype: int64

# %%
merged_df['hutan_wariai'] = merged_df['futan_juryo'] / merged_df['bataiju']

# %%
merged_df['zogen_fugo'].value_counts()
# Out:
# zogen_fugo
# 2    45304
# 0    37078
# 1     9296
# Name: count, dtype: int64

# %%
merged_df['zogen_sa'].value_counts()
# Out:
# zogen_sa
# 1.0      12855
# 2.0      12227
# 3.0      10877
# 4.0       9528
# 5.0       8131
# 0.0       6601
# 6.0       6503
# 7.0       5268
# 8.0       4050
# 9.0       3132
# 10.0      2313
# 11.0      1745
# 12.0      1289
# 13.0       954
# 14.0       708
# 999.0      646
# 15.0       590
# 16.0       448
# 17.0       332
# 18.0       261
# 19.0       225
# 20.0       165
# 21.0       131
# 22.0       112
# 23.0       102
# 24.0        86
# 26.0        64
# 25.0        50
# 29.0        38
# 27.0        33
# 30.0        29
# 28.0        28
# 31.0        23
# 33.0        20
# 32.0        10
# 34.0         9
# 35.0         6
# 36.0         5
# 39.0         5
# 38.0         5
# 37.0         4
# 47.0         3
# 43.0         3
# 40.0         3
# 50.0         2
# 41.0         2
# 49.0         2
# 44.0         1
# 53.0         1
# 54.0         1
# 46.0         1
# 64.0         1
# 45.0         1
# Name: count, dtype: int64

# %%
def combine_sign_and_diff(row):
    if row['zogen_fugo'] == 2:
        return row['zogen_sa']
    elif row['zogen_fugo'] == 0:
        return -row['zogen_sa']
    else:
        return 0

merged_df['zogen_ryou'] = merged_df.apply(combine_sign_and_diff, axis=1)

scaler = MinMaxScaler()
merged_df['zogen_ryou'] = scaler.fit_transform(merged_df[['zogen_ryou']])

# %%
merged_df['ijo_kubun_code'].value_counts()
# 0	下記以外　または未設定・未整備時の初期値(主に地方競馬・海外国際レースに関するデータ)
# 1	出走取消	取消	SCRATCHED	S
# 2	発走除外	発除	EXCLUDED BY STARTERS	ES
# 3	競走除外	競除	EXCLUDED BY STEWARDS	ER
# 4	競走中止	中止	FALL TO FINISH	FF
# 5	失格	失格	DISQUALIFIED	DQ
# 6	落馬再騎乗	再騎	REMOUNT AFTER A CROPPER	RM
# 7	降着	降着	DISQUALIFIED AND PLACED	DQ&P
merged_df = merged_df[merged_df['ijo_kubun_code'] == 0]

# %%
merged_df['kyoso_shubetsu_code'].value_counts()
# 00	未設定・未整備時の初期値(主に地方競馬・海外国際レースに関するデータ)
# 11	サラブレッド系2歳	サラ２才	サラ系２歳	サラ系２歳	TWO-YEAR-OLDS
# 12	サラブレッド系3歳	サラ３才	サラ系３歳	サラ系３歳	THREE-YEAR-OLDS
# 13	サラブレッド系3歳以上	サラ３上	サラ系３歳上	サラ系３歳以上	THREE-YEAR-OLDS & UP
# 14	サラブレッド系4歳以上	サラ４上	サラ系４歳上	サラ系４歳以上	FOUR-YEAR-OLDS & UP
# 18	サラブレッド系障害3歳以上	障害３上	障害３歳上	サラ障害３歳以上	THREE-YEAR-OLDS & UP STEEPLE-CHASE
# 19	サラブレッド系障害4歳以上	障害４上	障害４歳上	サラ障害４歳以上	FOUR-YEAR-OLDS & UP STEEPLE-CHASE
# 21	アラブ系2歳	アラ２才	アラ系２歳	アラブ系２歳	TWO-YEAR-OLDS ANGLO-ARABS
# 22	アラブ系3歳	アラ３才	アラ系３歳	アラブ系３歳	THREE-YEAR-OLDS ANGLO-ARABS
# 23	アラブ系3歳以上	アラ３上	アラ系３歳上	アラブ系３歳以上	THREE-YEAR-OLDS & UP ANGLO-ARABS
# 24	アラブ系4歳以上	アラ４上	アラ系４歳上	アラブ系４歳以上	FOUR-YEAR-OLDS & UP ANGLO-ARABS
# Out:
# kyoso_shubetsu_code
# 49    67082
# 12    16101
# 11     5501
# 13      941
# 43      491
# 14      354
# Name: count, dtype: int64

# %%
j_race_df['kyoso_shubetsu_code'].value_counts()
# Out:
# kyoso_shubetsu_code
# 12    21794
# 0     19750
# 13    18724
# 14    13839
# 11    11907
# 18     1007
# 19      760
# Name: count, dtype: int64

# %%
merged_df['kyoso_kigo_code'].value_counts()
# 000	記号なし　または未設定・未整備時の初期値(主に地方競馬・海外国際レースに関するデータ)
# 001	(指定)	DSN
# 002	見習騎手 (2003年までの表記)若手騎手 (2004年からの表記)	
# 003	[指定]	DES
# 004	(特指)	SD
# Out:
# kyoso_kigo_code
# 0    90470
# Name: count, dtype: int64

# %%
merged_df['juryo_shubetsu_code'].value_counts()
# 0	未設定・未整備時の初期値(主に地方競馬・海外国際レースに関するデータ)
# 1	ハンデ	HANDICAP	出走馬の実績等を考慮し、ハンデキャッパーが負担重量を決定するレース
# 2	別定	SPECIAL WEIGHT	レースごとに負担重量を決定する基準が設けられているレース
# 3	馬齢	WEIGHT FOR AGE	馬の年齢や性別によって負担重量を決定するレース
# 4	定量	SPECIAL WEIGHT	別定レースであって、馬の年齢や性別によって負担重量を決定するレース
# Out:
# juryo_shubetsu_code
# 0    75304
# 1     7736
# 2     5911
# 4     1442
# 3       77
# Name: count, dtype: int64

# %%
merged_df['kyoso_joken_code'].value_counts()
# 000	未設定・未整備時の初期値(主に地方競馬・海外国際レースに関するデータ)
# 001	１００万円以下	1,000,000 & LESS	収得賞金が100万円以下の馬が出走できる。
# 002	２００万円以下	2,000,000 & LESS	収得賞金が200万円以下の馬が出走できる。
# 003	３００万円以下	3,000,000 & LESS	収得賞金が300万円以下の馬が出走できる。
# 099	９９００万円以下	99,000,000 & LESS	収得賞金が9900万円以下の馬が出走できる。
# 100	１億円以下	100,000,000 & LESS	収得賞金が1億円以下の馬が出走できる。
# 701	新馬	NEWCOMER	サラブレッド系の未出走馬が出走できる。
# 702	未出走	UNRACED	当該競馬以外の競馬(地方競馬または外国の競馬を含む)において、出走したことがなく、当該競馬において、第1着または重賞競走の第2着になったことのない馬が出走できる。
# 703	未勝利	MAIDEN	該当競馬以外の競馬(地方競馬または外国の競馬を含む)において出走し、収得賞金がない馬が出走できる。また未出走馬も出走できる。
# 999	オープン	OPEN	特に記載のない限り、すべての馬が出走できる競走
# Out:
# kyoso_joken_code
# 0    90470
# Name: count, dtype: int64

# %%
merged_df['course_kubun'].value_counts()
# 半角2文字　使用するコースを設定
# "A " ～ "E " を設定 尚、2002年以前の東京競馬場は"A1"、"A2"も存在
# Out:
# course_kubun
# 0    90470
# Name: count, dtype: int64

# %%
merged_df['shusso_tosu'].value_counts()
# Out:
# shusso_tosu
# 12    45074
# 11    23803
# 10    11037
# 9      6015
# 8      2278
# 7      1091
# 6       458
# 0       440
# 5       240
# 4        31
# 3         3
# Name: count, dtype: int64

# %%
merged_df['tenko_code'].value_counts()
# 0	未設定・未整備時の初期値(主に地方競馬・海外国際レースに関するデータ)
# 1	晴	Fine
# 2	曇	Cloudy
# 3	雨	Rainy
# 4	小雨	Drizzle
# 5	雪	Snow
# 6	小雪	Light Snow
# Out:
# tenko_code
# 1    54665
# 2    27829
# 3     7684
# 5      292
# Name: count, dtype: int64

# %%
merged_df['babajotai_code_shiba'].value_counts()
# Out:
# babajotai_code_shiba
# 0    90470
# Name: count, dtype: int64

# %%
merged_df['babajotai_code_dirt'].value_counts()
# 0	未設定・未整備時の初期値(主に地方競馬・海外国際レースに関するデータ)
# 1	良	Firm	Standard
# 2	稍重	Good	Good
# 3	重	Yielding	Muddy
# 4	不良	Soft	Sloppy
# Out:
# babajotai_code_dirt
# 1.0    43900
# 2.0    24618
# 3.0    13190
# 4.0     8762
# Name: count, dtype: int64

# %%
merged_df['haraimodoshi_sanrenpuku_1b'].value_counts()
# Out:
# haraimodoshi_sanrenpuku_1b
# 720.0      362
# 760.0      346
# 770.0      337
# 640.0      332
# 790.0      331
#           ...
# 22050.0      7
# 120.0        5
# 110.0        4
# 140.0        4
# 100.0        3
# Name: count, Length: 2119, dtype: int64

# %% [markdown]
# ## LightGBM

# %% [markdown]
# ### テスト用と学習用のデータに分け、モデルを作成

# %%
# 2010年から2019年のデータを学習データとして取得
train_data = merged_df[merged_df['kaisai_nen'].isin([2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019])]

# ランキング学習のために必要な特徴量とターゲットを設定
features = [
            'kyori',
            'grade_code',
            'seibetsu_code',
            'moshoku_code',
            'barei',
            'chokyoshi_code',
            'banushi_code',
            'kishu_code',
            'kishu_minarai_code',
            'kyoso_shubetsu_code',
            'juryo_shubetsu_code',
            'shusso_tosu',
            'tenko_code',
            'babajotai_code_dirt',
            'hutan_wariai',
            'zogen_ryou',
            ]

target = 'kakutei_chakujun'

# LightGBM用のデータセットを作成
train_dataset = lgb.Dataset(train_data[features], label=train_data[target])

def objective(trial):
    # Optunaで調整するパラメータを設定
    params = {
        'objective': 'regression',
        'metric': 'rmse',
        'boosting_type': 'gbdt',
        'num_leaves': trial.suggest_int('num_leaves', 2, 256),
        'learning_rate': trial.suggest_float('learning_rate', 1e-4, 1e-1, log=True),
        'feature_fraction': trial.suggest_float('feature_fraction', 0.4, 1.0),
    }
    
    # k=5のFOLDでデータを分割
    kf = KFold(n_splits=5, shuffle=True, random_state=42)
    
    # 各FOLDでの評価値を保存するためのリスト
    rmses = []
    
    # LightGBMモデルを訓練
    for train_index, valid_index in kf.split(train_data):
        train_fold_data = train_data.iloc[train_index]
        valid_fold_data = train_data.iloc[valid_index]
        
        train_dataset = lgb.Dataset(train_fold_data[features], label=train_fold_data[target])
        valid_dataset = lgb.Dataset(valid_fold_data[features], label=valid_fold_data[target])
        
        model = lgb.train(params, train_dataset, num_boost_round=1000, valid_sets=[valid_dataset], early_stopping_rounds=100, verbose_eval=100)
        
        # RMSEを計算して保存
        y_pred = model.predict(valid_fold_data[features])
        rmse = np.sqrt(mean_squared_error(valid_fold_data[target], y_pred))
        rmses.append(rmse)
    
    # 5-FOLDの平均RMSEを返す
    return np.mean(rmses)

# Optunaでのパラメータ探索を実行
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=10)

# 最適なパラメータ
best_params = study.best_params
best_params['metric'] = 'rmse'  # ここでmetricを追加

# KFoldでのモデル訓練
kf = KFold(n_splits=5, shuffle=True, random_state=42)
models = []

for train_index, valid_index in kf.split(train_data):
    train_fold_data = train_data.iloc[train_index]
    valid_fold_data = train_data.iloc[valid_index]
    
    train_dataset = lgb.Dataset(train_fold_data[features], label=train_fold_data[target])
    valid_dataset = lgb.Dataset(valid_fold_data[features], label=valid_fold_data[target])
    
    model = lgb.train(best_params, train_dataset, num_boost_round=500, valid_sets=[valid_dataset], early_stopping_rounds=20, verbose_eval=100)  # ここでearly_stopping_roundsを50に変更
    models.append(model)
# Out:
# [I 2023-10-07 23:13:13,859] A new study created in memory with name: no-name-b1eb4eba-7f1f-42c9-8556-dd3bad526b90
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.007648 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 982
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 5.998546
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 3.24685
# [200]	valid_0's rmse: 3.23848
# [300]	valid_0's rmse: 3.23066
# [400]	valid_0's rmse: 3.22343
# [500]	valid_0's rmse: 3.21648
# [600]	valid_0's rmse: 3.2099
# [700]	valid_0's rmse: 3.20366
# [800]	valid_0's rmse: 3.19769
# [900]	valid_0's rmse: 3.19201
# [1000]	valid_0's rmse: 3.1867
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 3.1867
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003829 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 985
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 6.011295
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 3.25214
# [200]	valid_0's rmse: 3.24395
# [300]	valid_0's rmse: 3.2363
# [400]	valid_0's rmse: 3.22918
# [500]	valid_0's rmse: 3.22236
# [600]	valid_0's rmse: 3.21585
# [700]	valid_0's rmse: 3.20972
# [800]	valid_0's rmse: 3.20384
# [900]	valid_0's rmse: 3.19831
# [1000]	valid_0's rmse: 3.19319
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 3.19319
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.008281 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 988
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 6.002510
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 3.27127
# [200]	valid_0's rmse: 3.26335
# [300]	valid_0's rmse: 3.25596
# [400]	valid_0's rmse: 3.24908
# [500]	valid_0's rmse: 3.24249
# [600]	valid_0's rmse: 3.23619
# [700]	valid_0's rmse: 3.23021
# [800]	valid_0's rmse: 3.22451
# [900]	valid_0's rmse: 3.21911
# [1000]	valid_0's rmse: 3.21404
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 3.21404
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005013 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 988
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 5.996454
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 3.27074
# [200]	valid_0's rmse: 3.26266
# [300]	valid_0's rmse: 3.25511
# [400]	valid_0's rmse: 3.24817
# [500]	valid_0's rmse: 3.24149
# [600]	valid_0's rmse: 3.23518
# [700]	valid_0's rmse: 3.22918
# [800]	valid_0's rmse: 3.22349
# [900]	valid_0's rmse: 3.21809
# [1000]	valid_0's rmse: 3.21306
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 3.21306
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004446 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 983
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 5.992311
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 3.25833
# [200]	valid_0's rmse: 3.25032
# [300]	valid_0's rmse: 3.24282
# [400]	valid_0's rmse: 3.23592
# [500]	valid_0's rmse: 3.22925
# [600]	valid_0's rmse: 3.22295
# [700]	valid_0's rmse: 3.21698
# [800]	valid_0's rmse: 3.21122
# [900]	valid_0's rmse: 3.20575
# [1000]	valid_0's rmse: 3.20065
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 3.20065
# [I 2023-10-07 23:13:40,703] Trial 0 finished with value: 3.201529202996685 and parameters: {'num_leaves': 12, 'learning_rate': 0.00039292060556579786, 'feature_fraction': 0.7353117327525462}. Best is trial 0 with value: 3.201529202996685.
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003577 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 982
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 5.998546
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 3.2439
# [200]	valid_0's rmse: 3.233
# [300]	valid_0's rmse: 3.22285
# [400]	valid_0's rmse: 3.21341
# [500]	valid_0's rmse: 3.20425
# [600]	valid_0's rmse: 3.19487
# [700]	valid_0's rmse: 3.18645
# [800]	valid_0's rmse: 3.17785
# [900]	valid_0's rmse: 3.1699
# [1000]	valid_0's rmse: 3.16216
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 3.16216
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003341 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 985
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 6.011295
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 3.24939
# [200]	valid_0's rmse: 3.23879
# [300]	valid_0's rmse: 3.22899
# [400]	valid_0's rmse: 3.2198
# [500]	valid_0's rmse: 3.21091
# [600]	valid_0's rmse: 3.2018
# [700]	valid_0's rmse: 3.19353
# [800]	valid_0's rmse: 3.18516
# [900]	valid_0's rmse: 3.17745
# [1000]	valid_0's rmse: 3.16997
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 3.16997
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003098 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 988
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 6.002510
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 3.26824
# [200]	valid_0's rmse: 3.25757
# [300]	valid_0's rmse: 3.24771
# [400]	valid_0's rmse: 3.23847
# [500]	valid_0's rmse: 3.22957
# [600]	valid_0's rmse: 3.22046
# [700]	valid_0's rmse: 3.21224
# [800]	valid_0's rmse: 3.20384
# [900]	valid_0's rmse: 3.19607
# [1000]	valid_0's rmse: 3.18855
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 3.18855
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003427 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 988
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 5.996454
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 3.26763
# [200]	valid_0's rmse: 3.25683
# [300]	valid_0's rmse: 3.24687
# [400]	valid_0's rmse: 3.23753
# [500]	valid_0's rmse: 3.22856
# [600]	valid_0's rmse: 3.21929
# [700]	valid_0's rmse: 3.2109
# [800]	valid_0's rmse: 3.20235
# [900]	valid_0's rmse: 3.1945
# [1000]	valid_0's rmse: 3.18688
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 3.18688
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003717 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 983
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 5.992311
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 3.25529
# [200]	valid_0's rmse: 3.24454
# [300]	valid_0's rmse: 3.23463
# [400]	valid_0's rmse: 3.22533
# [500]	valid_0's rmse: 3.21634
# [600]	valid_0's rmse: 3.20718
# [700]	valid_0's rmse: 3.1989
# [800]	valid_0's rmse: 3.19044
# [900]	valid_0's rmse: 3.18261
# [1000]	valid_0's rmse: 3.175
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 3.175
# [I 2023-10-07 23:15:44,521] Trial 1 finished with value: 3.17651211322921 and parameters: {'num_leaves': 120, 'learning_rate': 0.000445812386364245, 'feature_fraction': 0.4043208351479151}. Best is trial 1 with value: 3.17651211322921.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004759 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 982
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 5.998546
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 3.23453
# [200]	valid_0's rmse: 3.21504
# [300]	valid_0's rmse: 3.1968
# [400]	valid_0's rmse: 3.18014
# [500]	valid_0's rmse: 3.16462
# [600]	valid_0's rmse: 3.15051
# [700]	valid_0's rmse: 3.13773
# [800]	valid_0's rmse: 3.12622
# [900]	valid_0's rmse: 3.1151
# [1000]	valid_0's rmse: 3.10524
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 3.10524
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003160 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 985
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 6.011295
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 3.24021
# [200]	valid_0's rmse: 3.22127
# [300]	valid_0's rmse: 3.2036
# [400]	valid_0's rmse: 3.18752
# [500]	valid_0's rmse: 3.17242
# [600]	valid_0's rmse: 3.15862
# [700]	valid_0's rmse: 3.14616
# [800]	valid_0's rmse: 3.13512
# [900]	valid_0's rmse: 3.12441
# [1000]	valid_0's rmse: 3.11495
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 3.11495
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003669 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 988
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 6.002510
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 3.25906
# [200]	valid_0's rmse: 3.24008
# [300]	valid_0's rmse: 3.22238
# [400]	valid_0's rmse: 3.20613
# [500]	valid_0's rmse: 3.19089
# [600]	valid_0's rmse: 3.17705
# [700]	valid_0's rmse: 3.16437
# [800]	valid_0's rmse: 3.15308
# [900]	valid_0's rmse: 3.14221
# [1000]	valid_0's rmse: 3.13256
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 3.13256
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.007281 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 988
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 5.996454
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 3.25853
# [200]	valid_0's rmse: 3.23943
# [300]	valid_0's rmse: 3.22153
# [400]	valid_0's rmse: 3.20522
# [500]	valid_0's rmse: 3.18983
# [600]	valid_0's rmse: 3.17587
# [700]	valid_0's rmse: 3.16318
# [800]	valid_0's rmse: 3.15168
# [900]	valid_0's rmse: 3.1406
# [1000]	valid_0's rmse: 3.13091
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 3.13091
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003546 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 983
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 5.992311
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 3.24605
# [200]	valid_0's rmse: 3.22701
# [300]	valid_0's rmse: 3.20911
# [400]	valid_0's rmse: 3.19286
# [500]	valid_0's rmse: 3.17752
# [600]	valid_0's rmse: 3.16354
# [700]	valid_0's rmse: 3.15086
# [800]	valid_0's rmse: 3.13952
# [900]	valid_0's rmse: 3.12865
# [1000]	valid_0's rmse: 3.11899
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 3.11899
# [I 2023-10-07 23:18:49,300] Trial 2 finished with value: 3.1205327716209466 and parameters: {'num_leaves': 155, 'learning_rate': 0.0007369924247501989, 'feature_fraction': 0.550421513936088}. Best is trial 2 with value: 3.1205327716209466.
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.008652 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 982
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 5.998546
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.95201
# [200]	valid_0's rmse: 2.9387
# [300]	valid_0's rmse: 2.93888
# Early stopping, best iteration is:
# [274]	valid_0's rmse: 2.93577
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004258 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 985
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 6.011295
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.96692
# [200]	valid_0's rmse: 2.95986
# [300]	valid_0's rmse: 2.95957
# Early stopping, best iteration is:
# [267]	valid_0's rmse: 2.95672
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003512 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 988
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 6.002510
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.97656
# [200]	valid_0's rmse: 2.9659
# [300]	valid_0's rmse: 2.96409
# Early stopping, best iteration is:
# [281]	valid_0's rmse: 2.96339
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003341 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 988
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 5.996454
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.98036
# [200]	valid_0's rmse: 2.96748
# [300]	valid_0's rmse: 2.96824
# Early stopping, best iteration is:
# [275]	valid_0's rmse: 2.96571
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002650 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 983
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 5.992311
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.98482
# [200]	valid_0's rmse: 2.97984
# Early stopping, best iteration is:
# [184]	valid_0's rmse: 2.97912
# [I 2023-10-07 23:19:54,215] Trial 3 finished with value: 2.9601448821757366 and parameters: {'num_leaves': 186, 'learning_rate': 0.07804179486592978, 'feature_fraction': 0.6467323691276626}. Best is trial 3 with value: 2.9601448821757366.
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004057 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 982
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 5.998546
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 3.225
# [200]	valid_0's rmse: 3.19832
# [300]	valid_0's rmse: 3.17506
# [400]	valid_0's rmse: 3.15454
# [500]	valid_0's rmse: 3.13647
# [600]	valid_0's rmse: 3.1208
# [700]	valid_0's rmse: 3.10682
# [800]	valid_0's rmse: 3.09441
# [900]	valid_0's rmse: 3.08326
# [1000]	valid_0's rmse: 3.07362
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 3.07362
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004272 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 985
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 6.011295
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 3.23094
# [200]	valid_0's rmse: 3.20507
# [300]	valid_0's rmse: 3.18261
# [400]	valid_0's rmse: 3.16271
# [500]	valid_0's rmse: 3.14498
# [600]	valid_0's rmse: 3.12949
# [700]	valid_0's rmse: 3.11622
# [800]	valid_0's rmse: 3.10437
# [900]	valid_0's rmse: 3.09383
# [1000]	valid_0's rmse: 3.08432
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 3.08432
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.006425 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 988
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 6.002510
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 3.25009
# [200]	valid_0's rmse: 3.22445
# [300]	valid_0's rmse: 3.20187
# [400]	valid_0's rmse: 3.18176
# [500]	valid_0's rmse: 3.16412
# [600]	valid_0's rmse: 3.14884
# [700]	valid_0's rmse: 3.13494
# [800]	valid_0's rmse: 3.12249
# [900]	valid_0's rmse: 3.11136
# [1000]	valid_0's rmse: 3.10121
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 3.10121
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005416 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 988
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 5.996454
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 3.2493
# [200]	valid_0's rmse: 3.22332
# [300]	valid_0's rmse: 3.20042
# [400]	valid_0's rmse: 3.18021
# [500]	valid_0's rmse: 3.16239
# [600]	valid_0's rmse: 3.14668
# [700]	valid_0's rmse: 3.13281
# [800]	valid_0's rmse: 3.1205
# [900]	valid_0's rmse: 3.10942
# [1000]	valid_0's rmse: 3.09947
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 3.09947
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005821 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 983
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 5.992311
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 3.23705
# [200]	valid_0's rmse: 3.21116
# [300]	valid_0's rmse: 3.18859
# [400]	valid_0's rmse: 3.16889
# [500]	valid_0's rmse: 3.15172
# [600]	valid_0's rmse: 3.13654
# [700]	valid_0's rmse: 3.12286
# [800]	valid_0's rmse: 3.11067
# [900]	valid_0's rmse: 3.09984
# [1000]	valid_0's rmse: 3.09015
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 3.09015
# [I 2023-10-07 23:24:17,160] Trial 4 finished with value: 3.0897535849101425 and parameters: {'num_leaves': 240, 'learning_rate': 0.0008510964226578993, 'feature_fraction': 0.8962175816525952}. Best is trial 3 with value: 2.9601448821757366.
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004814 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 982
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 5.998546
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 3.00503
# [200]	valid_0's rmse: 2.97448
# [300]	valid_0's rmse: 2.96119
# [400]	valid_0's rmse: 2.95327
# [500]	valid_0's rmse: 2.9478
# [600]	valid_0's rmse: 2.94382
# [700]	valid_0's rmse: 2.93901
# [800]	valid_0's rmse: 2.93528
# [900]	valid_0's rmse: 2.93402
# [1000]	valid_0's rmse: 2.9326
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 2.9326
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003237 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 985
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 6.011295
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 3.01975
# [200]	valid_0's rmse: 2.99042
# [300]	valid_0's rmse: 2.97869
# [400]	valid_0's rmse: 2.97128
# [500]	valid_0's rmse: 2.96721
# [600]	valid_0's rmse: 2.96422
# [700]	valid_0's rmse: 2.95968
# [800]	valid_0's rmse: 2.95773
# [900]	valid_0's rmse: 2.95479
# [1000]	valid_0's rmse: 2.95357
# Did not meet early stopping. Best iteration is:
# [987]	valid_0's rmse: 2.9533
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003896 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 988
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 6.002510
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 3.03415
# [200]	valid_0's rmse: 3.00247
# [300]	valid_0's rmse: 2.98831
# [400]	valid_0's rmse: 2.98218
# [500]	valid_0's rmse: 2.97595
# [600]	valid_0's rmse: 2.97051
# [700]	valid_0's rmse: 2.9673
# [800]	valid_0's rmse: 2.96482
# [900]	valid_0's rmse: 2.96353
# [1000]	valid_0's rmse: 2.96215
# Did not meet early stopping. Best iteration is:
# [982]	valid_0's rmse: 2.96197
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003264 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 988
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 5.996454
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 3.03199
# [200]	valid_0's rmse: 3.00118
# [300]	valid_0's rmse: 2.98883
# [400]	valid_0's rmse: 2.98059
# [500]	valid_0's rmse: 2.97509
# [600]	valid_0's rmse: 2.96968
# [700]	valid_0's rmse: 2.96573
# [800]	valid_0's rmse: 2.96386
# [900]	valid_0's rmse: 2.96245
# [1000]	valid_0's rmse: 2.96145
# Did not meet early stopping. Best iteration is:
# [989]	valid_0's rmse: 2.96144
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003192 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 983
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 5.992311
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 3.02464
# [200]	valid_0's rmse: 2.99647
# [300]	valid_0's rmse: 2.98483
# [400]	valid_0's rmse: 2.97717
# [500]	valid_0's rmse: 2.97382
# [600]	valid_0's rmse: 2.9717
# [700]	valid_0's rmse: 2.96974
# [800]	valid_0's rmse: 2.96861
# [900]	valid_0's rmse: 2.96655
# [1000]	valid_0's rmse: 2.96634
# Did not meet early stopping. Best iteration is:
# [987]	valid_0's rmse: 2.96628
# [I 2023-10-07 23:25:44,673] Trial 5 finished with value: 2.955117079031498 and parameters: {'num_leaves': 74, 'learning_rate': 0.030134858491077103, 'feature_fraction': 0.6529494521305499}. Best is trial 5 with value: 2.955117079031498.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004755 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 982
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 5.998546
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 3.12978
# [200]	valid_0's rmse: 3.07293
# [300]	valid_0's rmse: 3.04253
# [400]	valid_0's rmse: 3.02324
# [500]	valid_0's rmse: 3.00935
# [600]	valid_0's rmse: 2.99881
# [700]	valid_0's rmse: 2.99075
# [800]	valid_0's rmse: 2.98429
# [900]	valid_0's rmse: 2.97888
# [1000]	valid_0's rmse: 2.97437
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 2.97437
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004649 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 985
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 6.011295
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 3.1399
# [200]	valid_0's rmse: 3.08324
# [300]	valid_0's rmse: 3.05343
# [400]	valid_0's rmse: 3.03439
# [500]	valid_0's rmse: 3.02138
# [600]	valid_0's rmse: 3.01162
# [700]	valid_0's rmse: 3.00433
# [800]	valid_0's rmse: 2.99842
# [900]	valid_0's rmse: 2.99248
# [1000]	valid_0's rmse: 2.98836
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 2.98836
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003422 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 988
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 6.002510
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 3.1594
# [200]	valid_0's rmse: 3.10197
# [300]	valid_0's rmse: 3.07104
# [400]	valid_0's rmse: 3.0515
# [500]	valid_0's rmse: 3.03803
# [600]	valid_0's rmse: 3.02817
# [700]	valid_0's rmse: 3.01968
# [800]	valid_0's rmse: 3.01255
# [900]	valid_0's rmse: 3.00764
# [1000]	valid_0's rmse: 3.00396
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 3.00396
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003932 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 988
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 5.996454
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 3.15627
# [200]	valid_0's rmse: 3.09791
# [300]	valid_0's rmse: 3.06629
# [400]	valid_0's rmse: 3.04738
# [500]	valid_0's rmse: 3.03358
# [600]	valid_0's rmse: 3.02352
# [700]	valid_0's rmse: 3.01658
# [800]	valid_0's rmse: 3.00974
# [900]	valid_0's rmse: 3.00512
# [1000]	valid_0's rmse: 3.00088
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 3.00088
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003783 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 983
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 5.992311
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 3.14578
# [200]	valid_0's rmse: 3.09022
# [300]	valid_0's rmse: 3.06063
# [400]	valid_0's rmse: 3.04276
# [500]	valid_0's rmse: 3.02961
# [600]	valid_0's rmse: 3.01984
# [700]	valid_0's rmse: 3.01344
# [800]	valid_0's rmse: 3.00714
# [900]	valid_0's rmse: 3.00279
# [1000]	valid_0's rmse: 2.99975
# Did not meet early stopping. Best iteration is:
# [999]	valid_0's rmse: 2.99975
# [I 2023-10-07 23:27:49,079] Trial 6 finished with value: 2.993463820040952 and parameters: {'num_leaves': 90, 'learning_rate': 0.005497975547211707, 'feature_fraction': 0.9599377137353869}. Best is trial 5 with value: 2.955117079031498.
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002731 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 982
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 5.998546
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.96415
# [200]	valid_0's rmse: 2.93704
# [300]	valid_0's rmse: 2.92655
# [400]	valid_0's rmse: 2.92268
# [500]	valid_0's rmse: 2.92206
# [600]	valid_0's rmse: 2.92243
# Early stopping, best iteration is:
# [531]	valid_0's rmse: 2.92162
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004068 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 985
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 6.011295
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.98356
# [200]	valid_0's rmse: 2.96125
# [300]	valid_0's rmse: 2.95178
# [400]	valid_0's rmse: 2.94789
# [500]	valid_0's rmse: 2.9473
# Early stopping, best iteration is:
# [461]	valid_0's rmse: 2.94674
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002481 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 988
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 6.002510
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.99914
# [200]	valid_0's rmse: 2.97278
# [300]	valid_0's rmse: 2.96444
# [400]	valid_0's rmse: 2.96053
# [500]	valid_0's rmse: 2.9594
# Early stopping, best iteration is:
# [495]	valid_0's rmse: 2.9591
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003110 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 988
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 5.996454
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.99392
# [200]	valid_0's rmse: 2.96654
# [300]	valid_0's rmse: 2.95784
# [400]	valid_0's rmse: 2.9539
# [500]	valid_0's rmse: 2.95183
# [600]	valid_0's rmse: 2.95219
# Early stopping, best iteration is:
# [535]	valid_0's rmse: 2.95085
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004938 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 983
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 5.992311
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.98806
# [200]	valid_0's rmse: 2.96685
# [300]	valid_0's rmse: 2.95963
# [400]	valid_0's rmse: 2.95825
# [500]	valid_0's rmse: 2.95952
# Early stopping, best iteration is:
# [406]	valid_0's rmse: 2.95789
# [I 2023-10-07 23:30:12,054] Trial 7 finished with value: 2.9472415877897316 and parameters: {'num_leaves': 222, 'learning_rate': 0.03536535035038847, 'feature_fraction': 0.5072717228046091}. Best is trial 7 with value: 2.9472415877897316.
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003589 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 982
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 5.998546
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 3.20644
# [200]	valid_0's rmse: 3.16531
# [300]	valid_0's rmse: 3.13173
# [400]	valid_0's rmse: 3.10392
# [500]	valid_0's rmse: 3.08092
# [600]	valid_0's rmse: 3.06208
# [700]	valid_0's rmse: 3.04617
# [800]	valid_0's rmse: 3.03305
# [900]	valid_0's rmse: 3.02187
# [1000]	valid_0's rmse: 3.01233
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 3.01233
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002027 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 985
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 6.011295
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 3.21291
# [200]	valid_0's rmse: 3.1729
# [300]	valid_0's rmse: 3.14052
# [400]	valid_0's rmse: 3.11384
# [500]	valid_0's rmse: 3.09205
# [600]	valid_0's rmse: 3.07394
# [700]	valid_0's rmse: 3.05894
# [800]	valid_0's rmse: 3.04684
# [900]	valid_0's rmse: 3.03633
# [1000]	valid_0's rmse: 3.02747
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 3.02747
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002176 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 988
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 6.002510
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 3.23151
# [200]	valid_0's rmse: 3.19147
# [300]	valid_0's rmse: 3.15847
# [400]	valid_0's rmse: 3.13136
# [500]	valid_0's rmse: 3.10864
# [600]	valid_0's rmse: 3.09015
# [700]	valid_0's rmse: 3.07473
# [800]	valid_0's rmse: 3.06217
# [900]	valid_0's rmse: 3.05113
# [1000]	valid_0's rmse: 3.04196
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 3.04196
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002090 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 988
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 5.996454
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 3.23077
# [200]	valid_0's rmse: 3.1903
# [300]	valid_0's rmse: 3.15698
# [400]	valid_0's rmse: 3.12937
# [500]	valid_0's rmse: 3.10607
# [600]	valid_0's rmse: 3.08727
# [700]	valid_0's rmse: 3.07169
# [800]	valid_0's rmse: 3.05873
# [900]	valid_0's rmse: 3.04772
# [1000]	valid_0's rmse: 3.03869
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 3.03869
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002234 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 983
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 5.992311
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 3.21867
# [200]	valid_0's rmse: 3.17828
# [300]	valid_0's rmse: 3.14522
# [400]	valid_0's rmse: 3.11812
# [500]	valid_0's rmse: 3.09606
# [600]	valid_0's rmse: 3.07807
# [700]	valid_0's rmse: 3.06307
# [800]	valid_0's rmse: 3.05093
# [900]	valid_0's rmse: 3.04052
# [1000]	valid_0's rmse: 3.03156
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 3.03156
# [I 2023-10-07 23:33:12,167] Trial 8 finished with value: 3.0304005648586014 and parameters: {'num_leaves': 254, 'learning_rate': 0.0016325545049464074, 'feature_fraction': 0.6200673069121038}. Best is trial 7 with value: 2.9472415877897316.
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001804 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 982
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 5.998546
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.96025
# [200]	valid_0's rmse: 2.93762
# [300]	valid_0's rmse: 2.93075
# [400]	valid_0's rmse: 2.92863
# [500]	valid_0's rmse: 2.92826
# Early stopping, best iteration is:
# [440]	valid_0's rmse: 2.92786
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001919 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 985
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 6.011295
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.98164
# [200]	valid_0's rmse: 2.96047
# [300]	valid_0's rmse: 2.95346
# [400]	valid_0's rmse: 2.95128
# [500]	valid_0's rmse: 2.95065
# Early stopping, best iteration is:
# [486]	valid_0's rmse: 2.95027
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002969 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 988
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 6.002510
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.99625
# [200]	valid_0's rmse: 2.97284
# [300]	valid_0's rmse: 2.96439
# [400]	valid_0's rmse: 2.96013
# [500]	valid_0's rmse: 2.95902
# Early stopping, best iteration is:
# [497]	valid_0's rmse: 2.95895
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002191 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 988
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 5.996454
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.98751
# [200]	valid_0's rmse: 2.96071
# [300]	valid_0's rmse: 2.95413
# [400]	valid_0's rmse: 2.95187
# Early stopping, best iteration is:
# [398]	valid_0's rmse: 2.95157
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001999 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 983
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 5.992311
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.98519
# [200]	valid_0's rmse: 2.96657
# [300]	valid_0's rmse: 2.963
# [400]	valid_0's rmse: 2.96255
# Early stopping, best iteration is:
# [374]	valid_0's rmse: 2.96214
# [I 2023-10-07 23:34:16,227] Trial 9 finished with value: 2.950159174226228 and parameters: {'num_leaves': 228, 'learning_rate': 0.03985209168034691, 'feature_fraction': 0.5886652331631481}. Best is trial 7 with value: 2.9472415877897316.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002750 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 982
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 5.998546
# Training until validation scores don't improve for 20 rounds
# [100]	valid_0's rmse: 2.96415
# [200]	valid_0's rmse: 2.93704
# [300]	valid_0's rmse: 2.92655
# Early stopping, best iteration is:
# [348]	valid_0's rmse: 2.92279
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004899 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 985
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 6.011295
# Training until validation scores don't improve for 20 rounds
# [100]	valid_0's rmse: 2.98356
# [200]	valid_0's rmse: 2.96125
# [300]	valid_0's rmse: 2.95178
# [400]	valid_0's rmse: 2.94789
# Early stopping, best iteration is:
# [461]	valid_0's rmse: 2.94674
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002127 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 988
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 6.002510
# Training until validation scores don't improve for 20 rounds
# [100]	valid_0's rmse: 2.99914
# [200]	valid_0's rmse: 2.97278
# [300]	valid_0's rmse: 2.96444
# [400]	valid_0's rmse: 2.96053
# Early stopping, best iteration is:
# [427]	valid_0's rmse: 2.95994
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003367 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 988
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 5.996454
# Training until validation scores don't improve for 20 rounds
# [100]	valid_0's rmse: 2.99392
# [200]	valid_0's rmse: 2.96654
# [300]	valid_0's rmse: 2.95784
# [400]	valid_0's rmse: 2.9539
# Early stopping, best iteration is:
# [417]	valid_0's rmse: 2.95379
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001877 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 983
# [LightGBM] [Info] Number of data points in the train set: 50200, number of used features: 16
# [LightGBM] [Info] Start training from score 5.992311
# Training until validation scores don't improve for 20 rounds
# [100]	valid_0's rmse: 2.98806
# [200]	valid_0's rmse: 2.96685
# [300]	valid_0's rmse: 2.95963
# Early stopping, best iteration is:
# [374]	valid_0's rmse: 2.95791

# %% [markdown]
# ### テストデータで予測

# %%
# 2020年から2022年のテストデータを取得
test_data_2020 = merged_df[merged_df['kaisai_nen'] == 2020].copy()
test_data_2021 = merged_df[merged_df['kaisai_nen'] == 2021].copy()
test_data_2022 = merged_df[merged_df['kaisai_nen'] == 2022].copy()

# 2021年と2022年のデータに対して予測を行い、平均を取る
test_data_2020.loc[:, 'y_pred'] = sum([model.predict(test_data_2020[features], num_iteration=model.best_iteration) for model in models]) / len(models)
test_data_2021.loc[:, 'y_pred'] = sum([model.predict(test_data_2021[features], num_iteration=model.best_iteration) for model in models]) / len(models)
test_data_2022.loc[:, 'y_pred'] = sum([model.predict(test_data_2022[features], num_iteration=model.best_iteration) for model in models]) / len(models)

# 予測されたランクをグループごとに計算
test_data_2020.loc[:, 'predicted_rank'] = test_data_2020.groupby('group')['y_pred'].rank(method='min')
test_data_2021.loc[:, 'predicted_rank'] = test_data_2021.groupby('group')['y_pred'].rank(method='min')
test_data_2022.loc[:, 'predicted_rank'] = test_data_2022.groupby('group')['y_pred'].rank(method='min')

# 結果を表示
test_data_2021[['group', 'predicted_rank', 'kakutei_chakujun']]
# Out:
#                  group  predicted_rank  kakutei_chakujun
# 71239    2021-106-42-1            11.0                11
# 71240    2021-106-42-1             3.0                 7
# 71241    2021-106-42-1             9.0                12
# 71242    2021-106-42-1             8.0                 8
# 71243    2021-106-42-1             7.0                 4
# ...                ...             ...               ...
# 78886  2021-1224-42-12             5.0                 4
# 78887  2021-1224-42-12             2.0                 5
# 78888  2021-1224-42-12             3.0                 3
# 78889  2021-1224-42-12            10.0                 2
# 78890  2021-1224-42-12             4.0                 9
#
# [7546 rows x 3 columns]

# %% [markdown]
# ## モデル評価

# %%
# RMSEを計算
rmse_2020 = np.sqrt(mean_squared_error(test_data_2020['predicted_rank'], test_data_2020['kakutei_chakujun']))
print(f"2021 RMSE: {rmse_2020:.3%}")
rmse_2021 = np.sqrt(mean_squared_error(test_data_2021['predicted_rank'], test_data_2021['kakutei_chakujun']))
print(f"2021 RMSE: {rmse_2021:.3%}")
rmse_2022 = np.sqrt(mean_squared_error(test_data_2022['predicted_rank'], test_data_2022['kakutei_chakujun']))
print(f"2022 RMSE: {rmse_2022:.3%}")
rmse_mean = np.mean([rmse_2020, rmse_2021, rmse_2022])
print(f"Mean RMSE: {rmse_mean:.3%}")
# Out:
# 2021 RMSE: 386.743%
# 2021 RMSE: 372.988%
# 2022 RMSE: 372.462%
# Mean RMSE: 377.398%

# %%
group_ids_2020 = test_data_2020['group'].unique()
precisions = []
recalls = []

# %%
def precision_at_5(predictions, actual):
    top_5_predictions = predictions.argsort()[-5:][::-1]  # 予測の上位5頭のインデックス
    top_3_actual = actual.argsort()[-3:][::-1]  # 実際の上位3頭のインデックス
    common_elements = np.intersect1d(top_5_predictions, top_3_actual)  # 共通の要素を抽出
    precision = len(common_elements) / 5
    return precision

def recall_at_5(predictions, actual):
    top_5_predictions = predictions.argsort()[-5:][::-1]  # 予測の上位5頭のインデックス
    top_3_actual = actual.argsort()[-3:][::-1]  # 実際の上位3頭のインデックス
    common_elements = np.intersect1d(top_5_predictions, top_3_actual)  # 共通の要素を抽出
    recall = len(common_elements) / 3
    return recall

# %%
def check_top3_in_top5_predictions(group):
    predicted_top5 = group.nsmallest(5, 'y_pred').index.tolist()
    actual_top3 = group.nsmallest(3, 'kakutei_chakujun').index.tolist()
    return all([horse in predicted_top5 for horse in actual_top3])

def calculate_group_profit(group):
    if check_top3_in_top5_predictions(group):
        payout_value = group['haraimodoshi_sanrenpuku_1b'].iloc[0]
        return payout_value - 1000
    else:
        return -1000

# %%
for test_data in [test_data_2020, test_data_2021, test_data_2022]:
    merged_data = test_data
    profits = merged_data.groupby('group').apply(calculate_group_profit).reset_index()
    profits.columns = ['group', 'profit']
    test_data = pd.merge(test_data, profits, on='group', how='left')

for group_id in group_ids_2020:
    test_data = test_data_2020[test_data_2020['group'] == group_id]
    p = precision_at_5(test_data['predicted_rank'].values, test_data['kakutei_chakujun'].values)
    r = recall_at_5(test_data['predicted_rank'].values, test_data['kakutei_chakujun'].values)
    precisions.append(p)
    recalls.append(r)

precision_5_2020 = np.mean(precisions)
recall_5_2020 = np.mean(recalls)

print(f"2020 Precision@5: {precision_5_2020:.3%}")
print(f"2020 Recall@5: {recall_5_2020:.3%}")

group_ids_2021 = test_data_2021['group'].unique()
precisions = []
recalls = []
# Out:
# 2020 Precision@5: 36.484%
# 2020 Recall@5: 60.806%

# %%
for group_id in group_ids_2021:
    test_data = test_data_2021[test_data_2021['group'] == group_id]
    p = precision_at_5(test_data['predicted_rank'].values, test_data['kakutei_chakujun'].values)
    r = recall_at_5(test_data['predicted_rank'].values, test_data['kakutei_chakujun'].values)
    precisions.append(p)
    recalls.append(r)

precision_5_2021 = np.mean(precisions)
recall_5_2021 = np.mean(recalls)

print(f"2021 Precision@5: {precision_5_2021:.3%}")
print(f"2021 Recall@5: {recall_5_2021:.3%}")


roup_ids_2022 = test_data_2022['group'].unique()
precisions = []
recalls = []

for group_id in roup_ids_2022:
    test_data = test_data_2022[test_data_2022['group'] == group_id]
    p = precision_at_5(test_data['predicted_rank'].values, test_data['kakutei_chakujun'].values)
    r = recall_at_5(test_data['predicted_rank'].values, test_data['kakutei_chakujun'].values)
    precisions.append(p)
    recalls.append(r)

precision_5_2022 = np.mean(precisions)
recall_5_2022 = np.mean(recalls)

print(f"2022 Precision@5: {precision_5_2022:.3%}")
print(f"2022 Recall@5: {recall_5_2022:.3%}")


precision_5_mean = np.mean([precision_5_2020, precision_5_2021, precision_5_2022])
recall_5_mean = np.mean([recall_5_2020, recall_5_2021, recall_5_2022])

print(f"Mean Precision@5: {precision_5_mean:.3%}")
print(f"Mean Recall@5: {recall_5_mean:.3%}")

# 各レースで上記の関数を適用
results_2020 = test_data_2020.groupby('group').apply(check_top3_in_top5_predictions)
results_2021 = test_data_2021.groupby('group').apply(check_top3_in_top5_predictions)
results_2022 = test_data_2022.groupby('group').apply(check_top3_in_top5_predictions)

# 予測モデルが成功したレースのインデックスを取得する
successful_groups_2020 = results_2020[results_2020].index
successful_groups_2021 = results_2021[results_2021].index
successful_groups_2022 = results_2022[results_2022].index

# そのインデックスを使用して、harai_dfから対応する支払倍率を取得する
successful_payout_2020 = merged_df[merged_df['group'].isin(successful_groups_2020)]
successful_payout_2021 = merged_df[merged_df['group'].isin(successful_groups_2021)]
successful_payout_2022 = merged_df[merged_df['group'].isin(successful_groups_2022)]

payouts_2020 = successful_payout_2020['haraimodoshi_sanrenpuku_1b']
payouts_2021 = successful_payout_2021['haraimodoshi_sanrenpuku_1b']
payouts_2022 = successful_payout_2022['haraimodoshi_sanrenpuku_1b']

# すべての成功したレースに対して、100円をかけた場合の支払いを計算する
total_payout_2020 = (payouts_2020).sum()
total_payout_2021 = (payouts_2021).sum()
total_payout_2022 = (payouts_2022).sum()

# 合計の支払いから、すべてのレースにかけた合計金額を引くことで、純利益を計算する
total_investment_2020 = test_data_2020['group'].nunique() * 1000
total_investment_2021 = test_data_2021['group'].nunique() * 1000
total_investment_2022 = test_data_2021['group'].nunique() * 1000

net_profit_2020 = total_payout_2020 - total_investment_2020
net_profit_2021 = total_payout_2021 - total_investment_2021
net_profit_2022 = total_payout_2022 - total_investment_2022

average_net_profit_2020 = net_profit_2020/len(test_data_2020)
average_net_profit_2021 = net_profit_2021/len(test_data_2021)
average_net_profit_2022 = net_profit_2020/len(test_data_2022)

print(f"2020 Average Net Profit: {average_net_profit_2020:.3f} yen")
print(f"2021 Average Net Profit: {average_net_profit_2021:.3f} yen")
print(f"2022 Average Net Profit: {average_net_profit_2022:.3f} yen")

mean_average_net_profit = np.mean([average_net_profit_2020, average_net_profit_2021, average_net_profit_2022])
print(f"Mean Average Net Profit: {mean_average_net_profit:.3f} yen")
# Out:
# 2021 Precision@5: 37.221%
# 2021 Recall@5: 62.036%
# 2022 Precision@5: 37.553%
# 2022 Recall@5: 62.589%
# Mean Precision@5: 37.086%
# Mean Recall@5: 61.810%
# 2020 Average Net Profit: 727.070 yen
# 2021 Average Net Profit: 687.857 yen
# 2022 Average Net Profit: 700.050 yen
# Mean Average Net Profit: 704.992 yen

# %%
# models[0]の特徴量の重要度を取得
feature_importance = models[0].feature_importance(importance_type='gain')

# 特徴量の名前と重要度をDataFrameに変換
importance_df = pd.DataFrame({
    'Feature': features,
    'Importance': feature_importance
})

# 重要度の降順にソート
importance_df = importance_df.sort_values(by='Importance', ascending=False)

# プロット
plt.figure(figsize=(10, 8))
sns.barplot(data=importance_df, x='Importance', y='Feature')
plt.title('Feature Importance')
plt.tight_layout()
plt.show()

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt

# # 1. 箱ひげ図
# for feature in features:
#     plt.figure(figsize=(10, 6))
#     sns.boxplot(x='kyakushitsu_hantei', y=feature, data=test_data_2020)
#     plt.title(f'Box plot of {feature} by label')
#     plt.show()

# # 2. バイオリンプロット
# for feature in features:
#     plt.figure(figsize=(10, 6))
#     sns.violinplot(x='kyakushitsu_hantei', y=feature, data=test_data_2020)
#     plt.title(f'Violin plot of {feature} by label')
#     plt.show()

# # 3. ペアプロット (特徴量が多すぎる場合は時間がかかる可能性があるので注意)
# sns.pairplot(test_data_2020, hue='kyakushitsu_hantei', vars=features)
# plt.show()

# %% [markdown]
# # モデル保存

# %%
# 学習
full_train_dataset = lgb.Dataset(merged_df[features], label=merged_df[target])
full_model = lgb.train(best_params, full_train_dataset, num_boost_round=500, verbose_eval=100)  # ここではvalid_setsやearly_stopping_roundsは使用しない

# モデルを保存
model_save_path = 'bestmodels/urayasu.pkl'
with open(model_save_path, 'wb') as f:
    pickle.dump(full_model, f)

print(f"Model saved to {model_save_path}")
# Out:
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003377 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1002
# [LightGBM] [Info] Number of data points in the train set: 90470, number of used features: 16
# [LightGBM] [Info] Start training from score 5.986117
# Model saved to bestmodels/urayasu.pkl
