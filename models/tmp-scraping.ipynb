# %% [markdown]
# # preparation

# %%
import streamlit as st
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import requests

# %%
# def get_driver():
#     return webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# %%
# options = Options()
# options.add_argument('--disable-gpu')
# options.add_argument('--headless')

# driver = get_driver()
# driver.get("https://nar.netkeiba.com/top/")

# %%
# html = driver.page_source
# html

# %%
# driver.quit()

# %%
url = 'https://nar.netkeiba.com/top/'

# %%
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <!-- metaエリア -->
# <!-- block=meta_tag_race_top (d) -->
# <meta content="ja" http-equiv="content-language"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible">
# <meta content="width=1000" name="viewport"/>
# <meta content="telephone=no" name="format-detection">
# <meta content="No.1競馬サイト「netkeiba.com」は地方競馬（NAR）の全国地方競馬場のレース情報、開催日程、出馬表、オッズ、予想、結果払戻、ニュース速報や地方競馬予想に役立つ競馬新聞・競走馬・騎手・調教師のデータ分析など国内最大級のデータベースを提供しています。南関東4競馬場（大井･川崎･船橋･浦和）、帯広･門別･盛岡･水沢･金沢･笠松･名古屋･園田･姫路･高知･佐賀など全国の地方競馬最新情報を提供しています。" name="description">
# <meta content="地方競馬,オッズ,レース結果,競馬予想,大井競馬,川崎競馬,船橋競馬,浦和競馬,南関競馬,ネット競馬,netkeiba" name="keywords"/>
# <meta content="https://www.netkeiba.com/style/netkeiba.ja/image/netkeiba.png" name="thumbnail"/>
# <!-- ogp用 -->
# <meta content="netkeiba.com" property="og:site_name"/>
# <meta content="article" property="og:type"/>
# <meta content="地方競馬(NAR) | 国内最大級の競馬情報サイト - netkeiba.com" property="og:title"/>
# <meta content="https://nar.netkeiba.com/top/" property="og:url"/>
# <meta content="No.1競馬サイト「netkeiba.com」は地方競馬（NAR）の全国地方競馬場のレース情報、開催日程、出馬表、オッズ、予想、結果払戻、ニュース速報や地方競馬予想に役立つ競馬新聞・競走馬・騎手・調教師のデータ分析など国内最大級のデータベースを提供しています。南関東4競馬場（大井･川崎･船橋･浦和）、帯広･門別･盛岡･水沢･金沢･笠松･名古屋･園田･姫路･高知･佐賀など全国の地方競馬最新情報を提供しています。" property="og:description"/>
# <meta content="https://www.netkeiba.com/style/netkeiba.ja/image/netkeiba.png" property="og:image"/>
# <!-- Twitter用 -->
# <meta content="summary" property="twitter:card"/>
# <meta content="@netkeiba" property="twitter:site"/>
# <!-- Facebook用 -->
# <meta content="30367" property="fb:admins">
# <!-- アノテーション -->
# <link href="https://nar.netkeiba.com/top/" rel="canonical"/>
# <link href="https://nar.sp.netkeiba.com/top/" media="only screen and (max-width: 640px)" rel="alternate"/>
# <link href="https://dir.netkeiba.com/keiba/news_rss.html" rel="alternate" type="application/rss+xml"/>
# <link href="https://dir.netkeiba.com/keiba/tv_rss.html" rel="alternate" type="application/rss+xml"/>
# <link href="https://dir.netkeiba.com/keiba/column_rss.html" rel="alternate" type="application/rss+xml"/>
# <title>地方競馬(NAR) | 国内最大級の競馬情報サイト - netkeiba.com</title>
# <!-- 構造化データ -->
# <script type="application/ld+json">
# [
# {
# "@context": "http://schema.org",
# "@type": "BreadcrumbList",
# "itemListElement": [
# {
# "@type": "ListItem",
# "position": 1,
# "item": "https://www.netkeiba.com",
# "name": "netkeiba.com"
# }, {
# "@type": "ListItem",
# "position": 2,
# "item": "https://nar.netkeiba.com/top/",
# "name": "地方競馬(NAR)"
# }
# ]
# },
# {
# "@context":"http://schema.org",
# "@type":"WebSite",
# "url":"https://www.netkeiba.com",
# "name":"netkeiba.com",
# "alternateName":"netkeiba.com - 国内最大級の競馬情報サイト",
# "description": "netkeiba.comは国内最大級の競馬情報サイトです。JRA・NAR全レースの出馬表やオッズ・予想・競馬新聞、ニュース、コラム、競走馬50万頭以上収録の競馬データベース、地方競馬、POG、予想大会、コミュニティなどがご利用いただけます。",
# "sameAs":[
# "https://twitter.com/netkeiba",
# "https://www.facebook.com/netkeiba"
# ]
# }
# ]
# </script>
# <!-- block=common__advertisement_taboola_head (d) -->
# <script type="text/javascript">
# window._taboola = window._taboola || [];
# _taboola.push({article:'auto'});
# !function (e, f, u, i) {
# if (!document.getElementById(i)){
# e.async = 1;
# e.src = u;
# e.id = i;
# f.parentNode.insertBefore(e, f);
# }
# }(document.createElement('script'),
# document.getElementsByTagName('script')[0],
# '//cdn.taboola.com/libtrc/netkeiba/loader.js',
# 'tb_loader_script');
# if(window.performance && typeof window.performance.mark == 'function') {window.performance.mark('tbl_ic');}
# </script>
# <!-- 共通css include -->
# <!-- block=race_common_css (d) -->
# <link href="/favicon.ico" rel="shortcut icon"/>
# <link href="https://cdn.netkeiba.com/img.nar/common/css/race_pc_new.css?20231004" media="all" rel="stylesheet" type="text/css">
# <link href="https://cdn.netkeiba.com/img.nar/common/css/colorbox.css" media="all" rel="stylesheet" type="text/css"/>
# <!-- 共通js include -->
# <!-- block=race_common_js (d) -->
# <script src="https://cdn.netkeiba.com/img.nar/common/js/jquery-1.12.4.min.js?2019122401"></script>
# <script src="https://cdn.netkeiba.com/img.nar/common/js/slick.min.js?2019122501" type="text/javascript"></script>
# <script src="https://cdn.netkeiba.com/img.nar/common/js/common_util.js?2019121001"></script>
# <script src="https://regist.sp.netkeiba.com/common/js/monthly_goods_link.js?2019121001" type="text/javascript"></script>
# <script src="https://cdn.netkeiba.com/img.nar/common/js/jquery.lazyscript.js?2019121001"></script>
# <script src="https://cdn.netkeiba.com/img.yoso2.sp/common/js/yoso/YosoJraNar.js?2019121001" type="text/javascript"></script>
# <script src="https://cdn.netkeiba.com/img.sp/common/js/sweetalert.min.js?2019121001" type="text/javascript"></script>
# <script type="text/javascript">
# <!--
# var _contents_action_api_url = "https://nknewsapi.netkeiba.com/";
# // -->
# </script>
# <script src="https://cdn.netkeiba.com/img.newsapi.sp/common/js/contents.action.js?2019121001" type="text/javascript"></script>
# <script src="https://cdn.netkeiba.com/img.nar/common/js/jquery.cookie.js?2019121001" type="text/javascript"></script>
# <script src="https://cdn.netkeiba.com/img.nar/common/js/jquery.colorbox.js?2019121001" type="text/javascript"></script>
# <script src="https://cdn.netkeiba.com/img.nar/common/js/common_pc_new.js?2019121001" type="text/javascript"></script>
# <!-- Geniee Wrapper Head Tag -->
# <script>
# window.gnshbrequest = window.gnshbrequest || {cmd:[]};
# gnshbrequest.cmd.push(function(){
# gnshbrequest.registerPassback("1491444");
# gnshbrequest.registerPassback("1492792");
# gnshbrequest.registerPassback("1491445");
# gnshbrequest.registerPassback("1491463");
# gnshbrequest.forceInternalRequest();
# });
# </script>
# <script async="" src="https://cpt.geniee.jp/hb/v1/211239/47/wrapper.min.js"></script>
# <!-- /Geniee Wrapper Head Tag -->
# <!-- Netkeiba Ads Lib  -->
# <script src="https://cdn.netkeiba.com/img.sp/common/js/loadFif.js?ver=20200228"></script>
# <script>
# var googletag = googletag || {};
# googletag.cmd = googletag.cmd || [];
# </script>
# <script type="text/javascript">
# googletag.cmd.push(function() {
# var nkAdCategory = "nar";
# var href_value = location.href.split("://")[1];
# var url_value = href_value.split("?")[0].substr(0, 40);
# var parameter_value = "null";
# if (location.search) {
# parameter_value = href_value.split("?")[1].substr(0, 40);
# }
# var ref_value = "null";
# if (document.referrer) {
# var ref_array=[];
# ref_array=document.referrer.split("/");
# ref_value = ref_array[2];
# }
# googletag.pubads().setTargeting("url", url_value).setTargeting("url_parameter", parameter_value).setTargeting("ref", ref_value).setTargeting("category", nkAdCategory);
# });
# </script>
# <!-- その他 include -->
# <!-- block=race_common_other (d) -->
# <!-- Google Tag Manager -->
# <script>
# window.dataLayer = window.dataLayer || [];
# dataLayer.push({
# 'itemInfo': '','memberRank': 'NotLogin','memberId': ''
# });
# </script>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-K6PJT6');</script>
# <!-- End Google Tag Manager -->
# </link></meta></meta></meta></meta></head>
# <body class="local page_nar_top" id="Netkeiba_Race_Nar_Top">
# <div class="Wrap fc">
# <!-- block=race_header (d) -->
# <link href="https://cdn.netkeiba.com/img.www/style/netkeiba.ja/css/pc_header.css" media="screen" rel="stylesheet" type="text/css"/>
# <header class="Header_Area fc">
# <div class="Header_Inner">
# <h1>
# <a href="https://www.netkeiba.com/?rf=logo" title="netkeiba.com">
# <img alt="netkeiba.com" src="https://cdn.netkeiba.com/img.www/style/netkeiba.ja/image/common/netkeiba_logo01.png?2020022001"/>
# </a>
# </h1>
# <div class="DB_Search_Input">
# <form action="https://www.netkeiba.com/" class="Search_Box" method="POST">
# <input name="pid" type="hidden" value="search"/>
# <input name="type" type="hidden" value="db"/>
# <div class="InputTxt_Form_Box">
# <input class="Txt_Form" id="keywords" name="word" placeholder="馬名で検索" type="text" value=""/>
# </div><!-- / .InputTxt_Form -->
# <div class="Submit_Btn_Box">
# <svg class="IconInput01" height="41.05" viewbox="0 0 41.05 41.05" width="41.05" xmlns="http://www.w3.org/2000/svg">
# <g id="icon_search" transform="translate(-234.6 -459.7)">
# <circle class="st0" cx="15.6" cy="15.6" r="15.6" transform="translate(236.1 461.2)"></circle>
# <g>
# <path class="st1" d="M275.2,498.2a1.335,1.335,0,0,1,0,2l-.1.1a1.335,1.335,0,0,1-2,0l-11.2-11.2a1.335,1.335,0,0,1,0-2l.1-.1a1.335,1.335,0,0,1,2,0Z"></path>
# </g>
# </g>
# </svg>
# <input class="Submit_Btn" name="submit" type="submit" value="検 索"/>
# </div><!-- / .Submit_Btn_Box -->
# </form>
# </div><!-- / .DB_Search_Input -->
# <ul class="UserMyMenu fc">
# <li>
# <a href="https://regist.netkeiba.com/?pid=premium&amp;rf=header">
# <span>プレミアムサービス</span>
# </a>
# </li>
# <li>
# <a class="Icon_Header Icon_MyfavHorse" href="https://race.netkeiba.com/?pid=bookmark&amp;rf=navi">
# <span>お気に入り馬</span>
# </a>
# </li>
# <li>
# <a class="Icon_Header Icon_Login" href="https://regist.netkeiba.com/account/?pid=login">
# <span>ログイン/会員登録</span>
# </a>
# </li>
# <li class="disp_none header_stage_area no_login_show">
# <a href="https://regist.netkeiba.com/?pid=stage_login&amp;action=login&amp;return_url=https://regist.netkeiba.com">
# <span>(s)ログイン</span>
# </a>
# </li>
# <li class="disp_none header_stage_area no_login_show">
# <a href="https://regist.netkeiba.com/?pid=user_add_form&amp;payment=nk_user&amp;goods_cd=310409&amp;opt=init">
# <span>(s)無料会員登録</span>
# </a>
# <li class="disp_none header_stage_area login_show">
# <a href="https://regist.netkeiba.com/?pid=stage_login&amp;action=logout&amp;return_url=https://regist.netkeiba.com">
# <span>(s)ログアウト</span>
# </a>
# </li>
# </li></ul>
# <div class="SiteToggleBtn01 Keirin">
# <a href="https://keirin.netkeiba.com/?rf=nk_pc_header">
# <span class="LiveRace">LIVE</span>
# <img alt="" class="KeirinLogoMark01" height="16" src="https://cdn.netkeiba.com/img.www/style/netkeiba.ja/image/common/icon_keirin01.png" width="21"/>競輪
# </a>
# </div><!-- /.SiteToggleBtn01 -->
# </div><!-- /.Header_Inner -->
# </header>
# <nav class="ContentNavi01">
# <ul class="fc">
# <li class="Top">
# <a href="https://www.netkeiba.com/?rf=navi" id="navi_link_top" title="トップ">トップ</a>
# </li>
# <li class="News">
# <a href="https://news.netkeiba.com/?rf=navi" id="navi_link_news" title="ニュース">ニュース</a>
# </li>
# <li class="Race">
# <a href="https://race.netkeiba.com/top/" id="navi_link_race" title="レース">レース</a>
# </li>
# <li class="Yoso">
# <a href="https://yoso.netkeiba.com/?access=init&amp;rf=navi" id="navi_link_yoso" title="予想">予想</a>
# </li>
# <li class="Column">
# <a href="https://news.netkeiba.com/?pid=column_top&amp;rf=navi" id="navi_link_column" title="コラム">コラム</a>
# </li>
# <li class="Tv">
# <a href="https://tv.netkeiba.com/?rf=navi" id="navi_link_tv" title="netkeibaTV">netkeibaTV</a>
# </li>
# <li class="Local">
# <a href="../top/" id="navi_link_nar" title="地方競馬">地方競馬</a>
# </li>
# <li class="Db">
# <a href="https://db.netkeiba.com/?rf=navi" id="navi_link_db" title="データベース">データベース</a>
# </li>
# <li class="Paper">
# <a href="https://yoso.netkeiba.com/senmonshi/?rf=navi" id="navi_link_senmonshi" title="競馬新聞">競馬新聞</a>
# </li>
# <li class="YosoCS">
# <a href="https://orepro.netkeiba.com/?rf=navi" id="navi_link_orepro" title="俺プロ">俺プロ</a>
# </li>
# <li class="Owner">
# <a href="https://owner.netkeiba.com/?rf=navi" id="navi_link_owner" title="一口馬主">一口馬主</a>
# </li>
# <li class="Pog">
# <a href="https://pog.netkeiba.com/?rf=navi" id="navi_link_pog" title="POG">POG</a>
# </li>
# <li class="Matome">
# <a href="https://dir.netkeiba.com/keibamatome/index.html?rf=navi" id="navi_link_keibamatome" title="まとめ">まとめ</a>
# </li>
# </ul>
# </nav><!-- /.ContentNavi01 -->
# <!-- 広告配信用 -->
# <script>
# var googletag = googletag || {};
# googletag.cmd = googletag.cmd || [];
# </script>
# <!-- /広告配信用 -->
# <script async="" src="https://cdn.netkeiba.com/img.racev4.sp/common/js/nd_util.min.js"></script>
# <script type="text/javascript">
# $(document).ready(function() {
# show_user();
# });
# function show_user(){
# var is_stage = '';
# var is_user  = '';
# var is_alert = '';
# var is_sp    = '';
# var nickname = '';
# var user_img = '';
# if(is_sp) {
# $('.sp_nk_btn').show();
# }
# if(! is_stage) {
# $('.header_stage_area').remove();
# }
# if(is_user){
# //ログイン中
# $('.login_show').show();
# if(is_alert) {
# $('.Alert_New').show();
# }
# } else {
# //未ログイン
# $('.no_login_show').show();
# $('.login_show').remove();
# }
# }
# </script>
# <div class="Contents">
# <div class="Main_Column">
# <!-- block=box_return_version (d) -->
# <div class="SiteInfoAlert" style="display:none">
# <a href="https://dir.netkeiba.com/keibamatome/topics/covid-19.html">
# <span>【コロナ関連】競馬場開催情報はこちら</span>
# </a>
# </div>
# <!-- block=header_information (d) -->
# <div class="nar_top_message_box" style="display: none">
# <!-- block=common__advertisement (d) -->
# <div class="nk_AdvBox_pc new_wlb_text1 top_index">
# <div id="new_wlb_text1"></div>
# <script language="JavaScript" type="text/javascript">
# $.ajax('https://netdreamersad.durasite.net/A-affiliate2/mobile?keyword=new_wlb_text1&site=23', {
# timeout : 10000, /* 10000 ms */
# }).then(function(data) { $("#new_wlb_text1").html(data)} )
# </script>
# </div>
# <!-- block=common__advertisement (d) -->
# <div class="nk_AdvBox_pc new_wlb_text2 top_index">
# <div id="new_wlb_text2"></div>
# <script language="JavaScript" type="text/javascript">
# $.ajax('https://netdreamersad.durasite.net/A-affiliate2/mobile?keyword=new_wlb_text2&site=23', {
# timeout : 10000, /* 10000 ms */
# }).then(function(data) { $("#new_wlb_text2").html(data)} )
# </script>
# </div>
# <!-- block=common__advertisement (d) -->
# <div class="nk_AdvBox_pc new_wlb_text3 top_index">
# <div id="new_wlb_text3"></div>
# <script language="JavaScript" type="text/javascript">
# $.ajax('https://netdreamersad.durasite.net/A-affiliate2/mobile?keyword=new_wlb_text3&site=23', {
# timeout : 10000, /* 10000 ms */
# }).then(function(data) { $("#new_wlb_text3").html(data)} )
# </script>
# </div>
# </div>
# <script>if ($('#new_wlb_text1, #new_wlb_text2, #new_wlb_text3').length) { $('.nar_top_message_box').show(); }</script>
# <!-- block=special_info (cp) -->
# <div class="mt15">
# <div class="Jra_RaceList_Inner RaceInfo">
# <div class="PickupRace_Contents">
# <div class="" id="TopRaceMain">
# <div class="PickupRace_Contents_Inner">
# <a class="TopRaceMain" href="../special/index.html?id=0132&amp;rf=top_pickup">
# <div class="Sprint_Block">
# <p class="Sprint"></p>
# </div>
# <div class="PickupRace01">
# <h2 class="RaceTitle">鎌倉記念<span class="Icon_Grade Icon_Grade_None_Text Icon_GradeType Icon_GradeType4">重賞</span></h2>
# <p class="RaceData">10月11日<span class="Wed">(水)</span> 川崎 11R ダ1500m  <!-- BEGIN block_hasso_time -->  発走時刻 20:10 <!-- block_hasso_time --></p>
# </div><!-- /.PickupRace01 -->
# </a><!-- /#TopRaceMain -->
# </div><!-- /.PickupRace_Contents_Inner -->
# <div class="PickupRace_fc">
# <a href="../special/index.html?id=0132&amp;rf=top_pickup" title="鎌倉記念特集">
# <div class="Image_Layer01 BgImgCenter" style="background-image: url('https://cdn.netkeiba.com/img.db/v1.1/show_photo.php?horse_id=2021100034&amp;no=691&amp;tn=yes&amp;tmp=no')">
# <span class="Image_Cover"></span>
# <div class="RaceText">
# <span>鎌倉記念特集</span>
# </div>
# <div class="Horse">出走馬 カタルシス</div>
# </div>
# </a>
# <div class="PickupRaceMenu_Wrap">
# <div class="Inner fc">
# <div class="TextPickup">
# <h3 class="Title">
# <a href="../odds/index.html?race_id=202345101111&amp;rf=top_pickup">
# <span class="Icon_Sprite_Nk Icon_Sprite_Nk_Title"></span>予想オッズ</a>
# </h3>
# <div class="Btn_See_More">
# <a class="LinkMore" href="../odds/index.html?race_id=202345101111&amp;rf=top_pickup">
# <span>もっとみる</span>
# </a>
# </div>
# </div>
# <ul class="PickupRace_Point">
# <li class="fc">
# <p>
# <span>1番人気</span>
# <a class="HorseName" href="https://db.netkeiba.com/horse/2021105761?rf=top_pickup" target="_blank">スノーシュー</a>
# <span class="OddsData">1.7倍</span>
# </p>
# </li><li class="fc">
# <p>
# <span>2番人気</span>
# <a class="HorseName" href="https://db.netkeiba.com/horse/2021100316?rf=top_pickup" target="_blank">アジアミッション</a>
# <span class="OddsData">6.9倍</span>
# </p>
# </li><li class="fc">
# <p>
# <span>3番人気</span>
# <a class="HorseName" href="https://db.netkeiba.com/horse/2021104139?rf=top_pickup" target="_blank">アムクラージュ</a>
# <span class="OddsData">8.0倍</span>
# </p>
# </li><li class="fc">
# <p>
# <span>4番人気</span>
# <a class="HorseName" href="https://db.netkeiba.com/horse/2021106935?rf=top_pickup" target="_blank">サントノーレ</a>
# <span class="OddsData">8.5倍</span>
# </p>
# </li><li class="fc">
# <p>
# <span>5番人気</span>
# <a class="HorseName" href="https://db.netkeiba.com/horse/2021100008?rf=top_pickup" target="_blank">ホークマン</a>
# <span class="OddsData">11.8倍</span>
# </p>
# </li>
# </ul>
# </div><!-- /.Inner -->
# </div><!-- /.PickupRaceMenu_Wrap -->
# </div><!-- /.PickupRace_fc -->
# </div>
# <ul class="PickupRace_Other_Race">
# <li class="PickupRaceMenu_Btn">
# <a class="PickupRace_LinkBtn" href="../race/shutuba.html?race_id=202345101111&amp;rf=top_pickup" title="出馬表">
# <span class="Icon_Sprite_Nk Icon_RaceInfo01"></span>出馬表
# </a>
# </li>
# <li class="PickupRaceMenu_Btn">
# <a class="PickupRace_LinkBtn" href="../yoso/mark_list.html?race_id=202345101111&amp;rf=top_pickup" title="予想">
# <span class="Icon_Sprite_Nk Icon_RaceInfo02"></span>予想
# </a>
# </li>
# <li class="PickupRaceMenu_Btn">
# <a class="PickupRace_LinkBtn" href="../race/newspaper.html?race_id=202345101111&amp;rf=top_pickup" title="競馬新聞">
# <span class="Icon_Sprite_Nk Icon_RaceInfo03"></span>競馬新聞
# </a>
# </li>
# <li class="PickupRaceMenu_Btn">
# <a class="PickupRace_LinkBtn" href="../race/bbs.html?race_id=202345101111&amp;rf=top_pickup" title="レース掲示板">
# <span class="Icon_Sprite_Nk Icon_RaceInfo05"></span>レース掲示板
# </a>
# </li>
# </ul>
# <ul class="RaceHeadBtnArea">
# <li>
# <a class="Popup_Img MapRaceBtn" href="https://cdn.netkeiba.com/img.nar/common/img/course/45_d1500.png?2019073001">
# <span><img alt="Course" onerror="replaceDefaultNoImage()" src="https://cdn.netkeiba.com/img.nar/common/img/course/thumb_62/45_d1500.png?2019073001"/></span>
# コース詳細
# </a>
# <script>
# function replaceDefaultNoImage() {
# var baseurl = "https://cdn.netkeiba.com/img.nar/common/img/course/";
# $("a.Popup_Img").attr("href", baseurl + "soon.png");
# $("a.Popup_Img img").attr("src", baseurl + "soon.png");
# }
# </script>
# </li>
# <li>
# <a class="IpatBtn01" href="/ipat/dispatch.html?race_id=202345101111&amp;rf=top_pickup" target="_blank">
# <!--img disabled="false" src="https://cdn.netkeiba.com/img.nar/common/img/icon/icon_ipat01.png?2019073001" alt="IPAT" /--><span>馬券投票</span>
# </a>
# </li>
# </ul>
# </div><!-- /.PickupRace_Contents -->
# </div><!-- /.Jra_RaceList_Inner-->
# <div class="RaceMostRecentBox">
# <div class="RaceMostRecent">
# <ul id="TopRaceSub">
# <li>
# <a class="LinkBox_01" href="../race/shutuba.html?race_id=202335101012&amp;rf=top_pickup" title="初雁特別">
# <div>
# <h2 class="RaceTitle">初雁特別</h2>
# <p class="RaceData">10/10<span class="Tue">(火) </span>盛岡 12R ダ1600m
# </p></div>
# </a>
# </li><li>
# <a class="LinkBox_01" href="../race/shutuba.html?race_id=202345101011&amp;rf=top_pickup" title="サルビアカップ">
# <div>
# <h2 class="RaceTitle">サルビアカップ<span class="Icon_Grade Icon_Grade_None_Text Icon_GradeType Icon_GradeType5">OP</span></h2>
# <p class="RaceData">10/10<span class="Tue">(火) </span>川崎 11R ダ2000m
# </p></div>
# </a>
# </li><li>
# <a class="LinkBox_01" href="../race/shutuba.html?race_id=202345101010&amp;rf=top_pickup" title="大磯まつり2023特別">
# <div>
# <h2 class="RaceTitle">大磯まつり2023特別</h2>
# <p class="RaceData">10/10<span class="Tue">(火) </span>川崎 10R ダ1600m
# </p></div>
# </a>
# </li>
# </ul>
# </div>
# </div><!-- /.RaceMostRecentBox -->
# </div>
# <!-- block=common__advertisement_gam (d) -->
# <div class="nk_AdvBox_pc mt30">
# <!-- Geniee Wrapper Body Tag 1491444 -->
# <div data-cptid="1491444">
# <script>
# gnshbrequest.cmd.push(function() {
# gnshbrequest.applyPassback("1491444", "[data-cptid='1491444']");
# });
# </script>
# </div>
# <!-- /Geniee Wrapper Body Tag 1491444 -->
# </div>
# <!-- block=midnight_keirin_banner (d) -->
# <script type="text/javascript">
# // コンソール画面にて確認
# //# sourceURL=http://debug/test.js
# // ミッドナイト競輪開催状況を取得
# const openingFlg = false;
# // ミッドナイト競輪開催時間に表示する 19:30~23:30
# if(openingFlg){
# // ミッドナイト競輪レース情報取得
# //get_midnight_keirin_race(callback_keirin_banner_show);
# // var json = {is_midnight : 'true'};
# var tmp_json = '{"is_midnight":"true"}';
# var json = {};
# if(tmp_json){
# var json = JSON.parse(tmp_json);
# }
# callback_keirin_banner_show(json);
# }
# // ミッドナイト競輪のレース開催情報を取得する
# function callback_keirin_banner_show(json){
# console.log('callback_midnight_keirin_banner_show');
# //競輪レース開催日のみ表示
# const midnight_keirin_banner = document.getElementById("keirin_banner");
# if(json.is_midnight === 'true'){
# // ミッドナイト競輪を表示
# midnight_keirin_banner.style.display = "block";
# }
# }
# // 競輪からレース開催情報を取得する
# function get_midnight_keirin_race(_callback)
# {
# console.log('get_midnight_keirin_race');
# var url = 'https://keirin.netkeiba.com/api/midnight_check/';
# var _data = {};
# _data.input  = 'UTF-8';
# _data.output = 'jsonp';
# $.ajax( { type     : 'GET',
# url      : url,
# data     : _data,
# dataType : _data.output,
# xhrFields: {
# withCredentials: true
# },
# success  : function( json ) {
# if(undefined != _callback){
# _callback( json );
# }
# },
# error  : function(XMLHttpRequest, textStatus, errorThrown) {
# console.log('textStatus='+textStatus);
# }
# });
# return url;
# }
# </script>
# <div class="RaceList_Header">
# <h3 class="TitleHeading TitleIcon">
# <span>開催レース一覧</span>
# <a class="LinkMore Heading_Win" href="calendar.html?rf=race_list" style="margin-left: 20px" title="今月の地方競馬開催一覧">今月の地方競馬開催一覧</a>
# <a class="LinkMore Heading_Win" href="pdf.html?rf=race_list" id="link_to_pdf" title="PDF競馬新聞">PDF競馬新聞</a>
# </h3>
# </div>
# <!-- レース一覧メニュー -->
# <!-- block=race_list (d) -->
# <script type="text/javascript">
# // $Id: race_list.html 4135 2015-09-08 10:23:20Z h-suzuki $
# // var _action_api_url = 'https://nar.netkeiba.com';
# var _action_api_my_horse_url = 'https://nar.netkeiba.com/api/api_get_myhorse_entry.html';
# var _action_api_url_myhorse_data = 'https://nar.netkeiba.com/api/api_get_myhorse_entry_data.html';
# var _action_api_url_myrace_data = 'https://nar.netkeiba.com/api/api_get_my_race.html';
# </script>
# <script src="https://cdn.netkeiba.com/img.nar/common/js/race/race_list.js?20221227" type="text/javascript"></script>
# <script src="https://cdn.netkeiba.com/img.nar/common/js/race/api_myhorse.action.js?20221227" type="text/javascript"></script>
# <script src="https://cdn.netkeiba.com/img.nar/common/js/jquery-ui-1.12.1.js?2019121001"></script>
# <!-- ここからレースの一覧 -->
# <div class="RaceList_Date_Top" id="RaceTopRace">
# <div id="race_list">
# <div class="RaceList_Area" id="date_list"></div>
# <div class="FileLoader"><img alt="" src="https://cdn.netkeiba.com/img.nar/common/img/common/gif-load.gif?2019121001"/></div>
# </div><!-- /#race_list -->
# </div><!-- /#RaceTopRace -->
# <div class="RaceList_TxtBox" style="margin: 5px 0 25px;">
# <p>※結果・成績・オッズなどのデータは、必ず主催者発表のものと照合しご確認ください。</p>
# </div>
# <div class="RaceList_Footer">
# <dl class="Description_Box">
# <dt class="GuideTitle">レース一覧の見方<span class="Icon_ArrowB"></span></dt>
# <dd class="GuideContents" style="display: none;">
# <div class="ContentsInner">
# <table>
# <tbody>
# <tr>
# <th><span class="Icon_Guide GuideBg01">11R</span></th>
# <td><span class="mr05">…</span>結果確定前</td>
# </tr>
# <tr>
# <th><span class="Icon_Guide GuideBg02">11R</span></th>
# <td><span class="mr05">…</span>次のレース(発走直前)</td>
# </tr>
# <tr>
# <th><span class="Icon_Guide GuideBg03">11R</span></th>
# <td><span class="mr05">…</span>結果確定</td>
# </tr>
# <tr>
# <th><img alt="" src="https://cdn.netkeiba.com/img.nar/common/img/icon/icon_ipat03.png?2019121001" style="vertical-align:-1px;" width="32"/></th>
# <td><span class="mr05">…</span>地方競馬IPAT発売レース</td>
# </tr>
# </tbody>
# </table>
# </div>
# </dd>
# </dl>
# </div>
# <script>
# (function($) {
# var is_banei = '';
# if ($('.RaceList_Item01 > .Race_Num').hasClass('Race_Next')) {
# $('.Race_Next').parents('li').addClass('Next_Racing');
# }
# $('.Description_Box').each(function() {
# var box = $(this);
# var btn = box.find('.GuideTitle');
# var contents = box.find('.GuideContents');
# contents.hide();
# btn.append('<span class="Icon_ArrowB"></span>');
# btn.click(function() {
# btn.find('span').toggleClass('Icon_ArrowT').toggleClass('Icon_ArrowB');
# contents.slideToggle(200);
# });
# });
# //ばんえいの場合は無条件で非表示
# if(is_banei){
# return;
# }
# //新聞の出し分け(Android5未満、iOS10未満は新聞非表示)
# var ua = navigator.userAgent.toLowerCase();
# if( ua.indexOf("android") > 0 ) {
# var version = parseFloat(ua.slice(ua.indexOf("android")+8));
# if( version < 5 ) {
# //$("#shutuba_past_link").removeAttr('style');
# } else {
# $(".newspaper_link_race_list_submenu").removeAttr('style');
# }
# } else if(ua.indexOf('ipod touch') >= 0 || ua.indexOf('iphone') >= 0 || ua.indexOf('ipad') >= 0){
# var version = ua.split('os ')[1].split(' ')[0];
# if (version.indexOf('_') >= 0){
# version = parseInt(version.split('_')[0]);
# }
# if( version < 10 ) {
# //$("#shutuba_past_link").removeAttr('style');
# } else {
# $(".newspaper_link_race_list_submenu").removeAttr('style');
# }
# } else {
# $(".newspaper_link_race_list_submenu").removeAttr('style');
# }
# })(jQuery);
# //Get race_list
# $( function() {
# var q = get_page_query();
# var selectDate = q['kaisai_date']? q['kaisai_date']:'';
# var kaisai_id = q['kaisai_id']? q['kaisai_id']:'';
# getDateList ("race_list_get_date_list.html", selectDate, kaisai_id, function(resp) {
# $("#date_list").html(resp);
# createTabs();
# });
# });
# function getDateList(url, kaisai_date, kaisai_id, fn) {
# var _data = {
# kaisai_date: kaisai_date,
# kaisai_id : kaisai_id,
# encoding: "UTF-8"
# };
# $.ajax({
# type : 'GET',
# url : url,
# data : _data,
# success : function(data){
# if (typeof fn !== undefined) {
# fn(data);
# }
# },
# error : function(XMLHttpRequest,textStatus,errorThrown){
# // console.log('XMLHttpRequest:'+XMLHttpRequest.status);
# // console.log('textStatus:'+textStatus);
# // console.log('errorThrown:'+errorThrown.message);
# }
# });
# }
# function showHideLoader(isShow) {
# if (isShow) {
# $(".FileLoader").show();
# } else {
# $(".FileLoader").hide();
# }
# }
# function createPrevNextEvents() {
# $("#prevBtn").click ( function() {
# $( "#race_list" ).tabs( "destroy" );
# showHideLoader(true);
# getDateList ("race_list_get_date_list.html", $(this).attr('date'), '', function(resp) {
# $("#date_list").html(resp);
# createTabs();
# history.replaceState({}, "", $('#date_list_sub li.ui-state-active a').attr("href").replace("race_list_sub.html", ""));
# });
# });
# $("#nextBtn").click ( function() {
# $( "#race_list" ).tabs( "destroy" );
# showHideLoader(true);
# getDateList ("race_list_get_date_list.html", $(this).attr('date'), '', function(resp) {
# $("#date_list").html(resp);
# createTabs();
# history.replaceState({}, "", $('#date_list_sub li.ui-state-active a').attr("href").replace("race_list_sub.html", ""));
# });
# });
# }
# function createTabs() {
# createPrevNextEvents();
# $( "#race_list" ).tabs({
# beforeLoad: function( event, ui ) {
# ui.jqXHR.fail(function() {
# ui.panel.html(
# "Couldn't load this tab. We'll try to fix this as soon as possible. " +
# "If this wouldn't be a demo." );
# });
# }
# ,activate: function( event, ui ) {
# showHideLoader(true);
# ui.newPanel.hide();
# var curSelectHref = ui.newTab.find("a").attr("href").replace("race_list_sub.html", "");
# history.replaceState({}, "", curSelectHref);
# }
# ,load: function( event, ui ) {
# showHideLoader(false);
# ui.panel.show();
# onLoadTab($("#date_list_sub li.ui-state-active").attr("date"));
# },
# active: $("#date_list_sub li.Active").index()
# });
# }
# function get_page_query() {
# var query = location.search.replace(/^\?/, '').split('&');
# var ary_q = {};
# for(i=0; i<query.length; i++){
# var q = query[i].split('=');
# ary_q[q[0]] = q[1];
# }
# return ary_q;
# }
# function onLoadTab(kaisai_date) {
# var ary_race_id = [];
# $('[aria-hidden="false"] [id^=myhorse_]').each(function(){
# var tmp_id = $(this).prop('id');
# var race_id = tmp_id.replace(/myhorse_/,'',tmp_id);
# ary_race_id.push( race_id );
# });
# get_myhorse_entry_data(ary_race_id, callback_myhorse_show_data);
# get_myrace_data(kaisai_date, callback_myrace_data);
# var ks_date = kaisai_date ? '&kaisai_date='+kaisai_date : '';
# $('#link_to_pdf').attr('href','pdf.html?rf=race_list'+ ks_date);
# }
# </script>
# <script type="text/javascript">
# $(document).on('click', '.RaceList_ProvinceSelect a', function (e) {
# e.preventDefault();
# var id = parseInt($(this).attr('target'));
# selectTab($(this), id);
# });
# function selectTab(_this, id) {
# var $this = _this;
# var $parent = $this.closest('.RaceList_Body');
# var $label = $this.closest('li');
# var $targetTblContent = $('.RaceList_Box dl.RaceList_DataList:nth-child( ' + id + ')', $parent);
# $targetTblContent.siblings().hide();
# $targetTblContent.show();
# $label.addClass('Active');
# $label.siblings().removeClass('Active');
# history.replaceState({}, "", $($this).attr('href'));
# }
# </script>
# <style>
# dl.RaceList_DataList + dl {
# display: none;
# }
# </style>
# <!-- block=live_commerce_link (d) -->
# <div id="live_commerce_link" style="display:none;margin-top: 20px;"></div>
# <script>
# $(document).ready( function(){
# console.log("api_get_live_commerce_link");
# var _data = { pid : 'api_get_live_commerce_link' };
# _data.input     = 'UTF-8';
# _data.output    = 'jsonp';
# _data.syusai = "nar";
# _data.device = "pc";
# _data.mode = "video_banner";
# _data.ref  = 'nar_navi';
# jQuery.ajax( {type  :'GET',
# url      : "https://yoso.sp.netkeiba.com",
# data     : _data,
# dataType : _data.output,
# success  : function( data )
# {
# $("#live_commerce_link").html(data);
# $("#live_commerce_link").show();
# },
# error  : function(XMLHttpRequest, textStatus, errorThrown)
# {
# console.log("view data not exiest");
# }
# });
# });
# </script>
# <!-- block=senmonshi_race_top (d) -->
# <div id="delay_umai_yosoka_f">
# <div id="umai_yosoka_f_view">
# <div class="FileLoader"><img alt="" src="https://cdn.netkeiba.com/img.nar/common/img/common/gif-load.gif?2019121001"/></div>
# </div>
# </div>
# <script src="https://cdn.netkeiba.com/img.nar/common/js/jquery.lazyscript.js"></script>
# <script type="text/javascript">
# $(document).ready(function() {
# var _syusai = '20';
# var _show_id = 'umai_yosoka_f_view';
# var options = {
# type: "visible",
# id: "delay_umai_yosoka_f",
# scripts: [
# ],
# success: function () {
# get_umai_yosoka_f_data(_syusai, _show_id, function(data) {
# // console.log(data);
# if (data.status == 'OK') {
# $("#sec_umai_goods_f").css("display", "block");
# $("#" + _show_id).html( data.html );
# }
# });
# }
# };
# $.lazyscript(options);
# // ------------------------------------------------------------------------
# function get_umai_yosoka_f_data(_syusai, _show_id, _callback)
# {
# console.log('get_umai_goods_f_data');
# var _data = {};
# _data.input       = 'UTF-8';
# _data.output      = 'jsonp';
# _data.syusai      = _syusai;
# _data.show_id     = _show_id;
# _data.rf_param    = 'pc_nartop';
# $.ajax({
# type     : 'GET',
# url      : 'https://yoso.netkeiba.com/senmonshi/api/api_get_yosoka_sales.html',
# data     : _data,
# dataType : _data.output,
# success  : function( data ){
# if (undefined != _callback) {
# _callback( data );
# }
# },
# error    : function(XMLHttpRequest, textStatus, errorThrown) {
# console.log('XMLHttpRequest: %O',XMLHttpRequest);
# console.log('textStatus: %O',textStatus);
# }
# });
# }
# });
# </script>
# <div class="HorseBookmark_Main">
# <!-- block=race_top__horse_bookmark (d) -->
# <div class="HorseBookmark_Box" style="display: none">
# <div>
# <h3 class="TitleHeading">
# <span>お気に入り馬の出走情報</span>
# </h3>
# </div>
# <div>
# <table cellpadding="0" cellspacing="0" class="Table_Horse_Bookmark" summary="お気に入り馬の出走情報">
# <tr>
# <th>馬名</th>
# <th>性齢</th>
# <th colspan="2">レース</th>
# <th>メモ</th>
# <th>最新情報</th>
# </tr>
# </table>
# </div>
# </div>
# </div>
# <!-- block=common__advertisement_taboola_main (d) -->
# <div id="taboola-below-article-thumbnails_race"></div>
# <script type="text/javascript">
# window._taboola = window._taboola || [];
# _taboola.push({
# mode: 'alternating-thumbnails-a-race',
# container: 'taboola-below-article-thumbnails_race',
# placement: 'Below Article Thumbnails_race',
# target_type: 'mix'
# });
# </script>
# <!-- block=common__advertisement_gam (d) -->
# <div class="nk_AdvBox_pc mt30">
# <!-- Geniee Wrapper Body Tag 1492792 -->
# <div data-cptid="1492792">
# <script>
# gnshbrequest.cmd.push(function() {
# gnshbrequest.applyPassback("1492792", "[data-cptid='1492792']");
# });
# </script>
# </div>
# <!-- /Geniee Wrapper Body Tag 1492792 -->
# </div>
# </div>
# <div class="Side_Column">
# <!-- block=common__advertisement (d) -->
# <script src="https://cdn.netkeiba.com/img.sp/common/js/loadFif.js?ver=20200228"></script>
# <div class="nk_AdvBox_pc new_wlb_rectangle top_index">
# <div id="new_wlb_rectangle"></div>
# <script language="JavaScript" type="text/javascript">
# if(typeof loadDuraFiF !== "undefined") {
# loadDuraFiF("new_wlb_rectangle",23);
# }
# </script>
# </div>
# <!-- block=kaisai_racecourse_list (cp) -->
# <div class="TodayLocalRace_Slide">
# <h3 class="Subtitle">本日の開催競馬場</h3>
# <ul class="TodayLocalRace_SlideBox">
# <li class="TodayLocalRace_SlideBoxItem">
# <a href="https://nar.netkeiba.com/racecourse/racecourse_page.html?jyo_cd=45&amp;rf=top_pickup">
# <div class="TodayLocalRace_Inner">
# <div class="Left_TodayLocalRace">
# <img alt="川崎競馬場" class="LocalFacilitiesLogo" height="auto" onerror="this.src='https://cdn.netkeiba.com/img.nar/common/img/jyologo/noimage.png?2020022501'" src="https://cdn.netkeiba.com/img.nar/common/img/jyologo/icon_jyologo_45.png?20220401" width="48"/>
# <small class="icon-nighter"></small>
# </div>
# <div class="Right_TodayLocalRace">
# <h3>川崎</h3>
# <h3>5R</h3>
# <p class="Race_Title">大返し賞</p>
# <div class="Race_State">
# <span class="Time">17:00</span>
# </div>
# </div>
# </div>
# </a>
# </li><li class="TodayLocalRace_SlideBoxItem">
# <a href="https://nar.netkeiba.com/racecourse/racecourse_page.html?jyo_cd=30&amp;rf=top_pickup">
# <div class="TodayLocalRace_Inner">
# <div class="Left_TodayLocalRace">
# <img alt="門別競馬場" class="LocalFacilitiesLogo" height="auto" onerror="this.src='https://cdn.netkeiba.com/img.nar/common/img/jyologo/noimage.png?2020022501'" src="https://cdn.netkeiba.com/img.nar/common/img/jyologo/icon_jyologo_30.png?20220401" width="48"/>
# <small class="icon-nighter"></small>
# </div>
# <div class="Right_TodayLocalRace">
# <h3>門別</h3>
# <h3>5R</h3>
# <p class="Race_Title">2歳 3組</p>
# <div class="Race_State">
# <span class="Time">16:50</span>
# </div>
# </div>
# </div>
# </a>
# </li><li class="TodayLocalRace_SlideBoxItem">
# <a href="https://nar.netkeiba.com/racecourse/racecourse_page.html?jyo_cd=35&amp;rf=top_pickup">
# <div class="TodayLocalRace_Inner">
# <div class="Left_TodayLocalRace">
# <img alt="盛岡競馬場" class="LocalFacilitiesLogo" height="auto" onerror="this.src='https://cdn.netkeiba.com/img.nar/common/img/jyologo/noimage.png?2020022501'" src="https://cdn.netkeiba.com/img.nar/common/img/jyologo/icon_jyologo_35.png?20220401" width="48"/>
# </div>
# <div class="Right_TodayLocalRace">
# <h3>盛岡</h3>
# <h3>10R</h3>
# <p class="Race_Title">C1二組</p>
# <div class="Race_State">
# <span class="Time">17:05</span>
# </div>
# </div>
# </div>
# </a>
# </li><li class="TodayLocalRace_SlideBoxItem">
# <a href="https://nar.netkeiba.com/racecourse/racecourse_page.html?jyo_cd=47&amp;rf=top_pickup">
# <div class="TodayLocalRace_Inner">
# <div class="Left_TodayLocalRace">
# <img alt="笠松競馬場" class="LocalFacilitiesLogo" height="auto" onerror="this.src='https://cdn.netkeiba.com/img.nar/common/img/jyologo/noimage.png?2020022501'" src="https://cdn.netkeiba.com/img.nar/common/img/jyologo/icon_jyologo_47.png?20220401" width="48"/>
# </div>
# <div class="Right_TodayLocalRace">
# <h3>笠松</h3>
# <h3>10R</h3>
# <p class="Race_Title">秋の四辺形特...</p>
# <div class="Race_State">
# <span class="Time Completed">開催終了</span>
# </div>
# </div>
# </div>
# </a>
# </li><li class="TodayLocalRace_SlideBoxItem">
# <a href="https://nar.netkeiba.com/racecourse/racecourse_page.html?jyo_cd=46&amp;rf=top_pickup">
# <div class="TodayLocalRace_Inner">
# <div class="Left_TodayLocalRace">
# <img alt="金沢競馬場" class="LocalFacilitiesLogo" height="auto" onerror="this.src='https://cdn.netkeiba.com/img.nar/common/img/jyologo/noimage.png?2020022501'" src="https://cdn.netkeiba.com/img.nar/common/img/jyologo/icon_jyologo_46.png?20220401" width="48"/>
# </div>
# <div class="Right_TodayLocalRace">
# <h3>金沢</h3>
# <h3>10R</h3>
# <p class="Race_Title">B25</p>
# <div class="Race_State">
# <span class="Time">16:55</span>
# </div>
# </div>
# </div>
# </a>
# </li>
# </ul>
# </div>
# <!-- block=race_list_menu (d) -->
# <script src="https://cdn.netkeiba.com/img.nar/common/js/jquery.colorbox.js?2019121001" type="text/javascript"></script>
# <script src="https://cdn.netkeiba.com/img.nar/common/js/race/race_list_menu_v2.js?2019121001" type="text/javascript"></script>
# <script src="https://cdn.netkeiba.com/img.nar/common/js/race/api_ipat.action.js?2019121001" type="text/javascript"></script>
# <script type="text/javascript">
# var _action_api_url = '/api/api_post_social_cart.html';
# </script>
# <section class="banner_top Margin-20B">
# <a href="https://yoso.netkeiba.com/senmonshi/nar/?rf=nar_banner"><img alt="専門紙" src="https://cdn.netkeiba.com/img.nar/common/img/race/top_img.jpg"/></a>
# </section>
# <div class="RaceMenu Margin-20B">
# <h3 class="RaceMenuTitle RightMenuTitle">地方競馬メニュー</h3>
# <div class="RaceMenuPanel">
# <ul class="ListRaceMenu">
# <li class="RaceMenuItem">
# <a href="../top/calendar.html?rf=sidemenu" title="開催一覧">
# <span class="Icon_Nk Icon_01"></span>開催一覧
# </a>
# </li>
# <li class="RaceMenuItem">
# <a href="../top/payback_list.html?rf=sidemenu" title="結果払戻">
# <span class="Icon_Nk Icon_02"></span>結果払戻
# </a>
# </li>
# <li class="RaceMenuItem">
# <a href="../top/schedule.html?rf=sidemenu" title="重賞日程">
# <span class="Icon_Nk Icon_03"></span>
# 重賞日程
# </a>
# </li>
# <li class="RaceMenuItem">
# <a href="../top/race_trend.html?rf=sidemenu" title="レース傾向">
# <span class="Icon_Nk Icon_05"></span>
# レース傾向
# </a>
# </li>
# <li class="RaceMenuItem">
# <a href="../race/search.html?rf=sidemenu" style="font-size:10px" title="騎乗騎手・出走馬">
# <span class="Icon_Nk Icon_06" style="margin-bottom:3px"></span>
# 騎乗騎手・出走馬
# </a>
# </li>
# <li class="RaceMenuItem">
# <a href="../top/information.html?rf=sidemenu" title="変更情報">
# <span class="Icon_Nk Icon_09"></span>変更情報
# </a>
# </li>
# <li class="RaceMenuItem">
# <a href="../shushi/index.html?rf=sidemenu" title="My収支">
# <span class="Icon_Nk Icon_12"></span>My収支
# </a>
# </li>
# <li class="RaceMenuItem">
# <a href="https://race.netkeiba.com/bookmark/bookmark.html?type=nar" title="お気に入り馬">
# <span class="Icon_Nk Icon_07"></span>お気に入り馬
# </a>
# </li>
# <li class="RaceMenuItem">
# <a href="../racecourse/racecourse_list.html?rf=sidemenu"> <span class="Icon_Nk Icon_15"></span>地方競馬場</a>
# </li>
# <li class="RaceMenuItem">
# <a class="Mark_New" href="https://yoso.netkeiba.com/senmonshi/nar/?rf=nar_column" title="専門紙">
# <span class="Icon_Nk Icon_Specialty"></span>
# 専門紙
# </a>
# </li>
# </ul>
# </div><!-- /.RaceMenuPanel -->
# </div><!-- /.RaceMenu -->
# <script type="text/javascript">
# function check_geolocation(url){
# function GetCookie( name ) {
# var result = null;
# var cookieName = name + '=';
# var allcookies = document.cookie;
# var position = allcookies.indexOf( cookieName );
# if( position != -1 ) {
# var startIndex = position + cookieName.length;
# var endIndex = allcookies.indexOf( ';', startIndex );
# if( endIndex == -1 ) {
# endIndex = allcookies.length;
# }
# result = decodeURIComponent(allcookies.substring( startIndex, endIndex ));
# }
# result = typeof result === 'string' ? window.atob(window.atob(result)) : '';
# return [result.split(',')[1],result.split(',')[4]];
# }
# var cookie = GetCookie('browser_appli[keiba]');
# if ( window.parent.navigator !== undefined && cookie[0] === 'iphone' && cookie[1] >= '4.0.0' ) {
# window.parent.navigator.geolocation.getCurrentPosition(
# function(position) {
# var request = {};
# request.position = {lat: position.coords.latitude,
# lng: position.coords.longitude};
# window.parent.cordova.plugins.Geocoder.geocode( request, function(result, error) {
# if(!!error){
# swal("位置情報の取得に失敗しました。",{
# }).then(function(val){
# window.parent.location.href = '';
# });
# }
# var countryCode;
# if(result[0].extra && result[0].extra.address){
# countryCode = result[0].extra.address.CountryCode;
# } else {
# countryCode = '';
# }
# if(countryCode === 'JP'){
# if(url){
# window.parent.location.href = url;
# }
# } else {
# swal("この機能は日本国内からのみ利用できます。",{
# }).then(function(val){
# window.parent.location.href = '';
# });
# }
# });
# },
# function(error) {
# swal("「設定」→「netkeiba」→「位置情報」→「許可する」を選び、再度お試しください。",{
# }).then(function(val){
# window.parent.location.href = '';
# });
# $('.swal-overlay').css('transform', 'translateZ(101px)');
# }
# );
# } else {
# if(url){
# window.parent.location.href = url;
# }
# }
# }
# </script>
# <section class="SideContents OpinionBox Margin-20B">
# <h2>ご意見・ご要望</h2>
# <div class="OpinionBoxWrap" id="OpinionBoxWrap">
# <form action="/?pid=opinion" method="post">
# <p class="OpinionBoxCheckTxt">頂いたご意見には必ずスタッフが目を通します。個々のご意見に回答できないことを予めご了承ください。</p>
# <a alt="ご意見はこちら" class="SideOpinionBtn" height="34" href="https://regist.netkeiba.com/?pid=users_opinion" width="150"><span>ご意見はこちら</span></a>
# </form>
# </div><!-- /.OpinionBoxWrap -->
# </section>
# <div class="Margin-20B">
# <div class="mb20">
# <a href="http://uma36.com/" target="_blank">
# <img alt="馬三郎" height="60" src="https://cdn.netkeiba.com/img.nar/common/img/other/20941netkeiba_220_60.gif?2020041601" width="220"/>
# </a>
# </div>
# <div>
# <a href="https://www.nikkankeiba.com/pdf/" target="_blank">
# <img alt="日刊競馬" height="70" src="https://cdn.netkeiba.com/img.nar/common/img/other/21650nikkankeiba.gif?2020041601" width="220"/>
# </a>
# </div>
# </div>
# <!-- block=common__advertisement_gam (d) -->
# <div class="nk_AdvBox_pc mt30">
# <!-- Geniee Wrapper Body Tag 1491445 -->
# <div data-cptid="1491445">
# <script>
# gnshbrequest.cmd.push(function() {
# gnshbrequest.applyPassback("1491445", "[data-cptid='1491445']");
# });
# </script>
# </div>
# <!-- /Geniee Wrapper Body Tag 1491445 -->
# </div>
# </div><!-- /. Side_Column -->
# </div><!-- /. Contents -->
# </div><!-- /.Wrap -->
# <footer>
# <!-- block=race_footer (cp) -->
# <div class="NkFooterArea">
# <div class="BtnPagetop">
# <a href="javascript:void(0)" title="ページトップへ"></a>
# </div><!-- /.BtnPagetop -->
# <script type="text/javascript">
# $(function() {
# $('.BtnPagetop a').click(function () {
# $('body,html').animate({
# scrollTop: 0
# }, 400);
# return false;
# });
# });
# </script>
# <div class="KeirinLink01">
# <a href="//keirin.netkeiba.com/?rf=nk_pc_footer" title="netkeirin"><img alt="いま競輪が熱い！nerkeirinで競輪を気軽に楽しもう" src="https://cdn.netkeiba.com/img.www/style/netkeiba.ja/image/common/PC_footer_bnr01.png"/></a>
# </div><!-- /.KeirinLink01 -->
# <dl class="FootSiteTitle fc">
# <dt>
# <a href="https://www.netkeiba.com/?rf=footer" title="netkeiba.com">
# <img alt="netkeiba.com" src="https://cdn.netkeiba.com/img.www/style/netkeiba.ja/image/common/netkeiba_logo01.png?2019121001">
# </img></a>
# </dt>
# <dd>
# <p>利用者数<strong>1700</strong>万人突破！<strong>No.1</strong>競馬サイト</p>
# </dd>
# </dl>
# <div class="FootWrap">
# <dl class="NkFoot01 NkFootCateLink">
# <dt>カテゴリ</dt>
# <dd class="fc">
# <ul>
# <li>
# <a href="https://news.netkeiba.com/?rf=footer" title="ニュース">ニュース</a>
# </li>
# <li>
# <a href="https://race.netkeiba.com/top/?rf=footer" title="レース">レース</a>
# </li>
# <li>
# <a href="https://yoso.netkeiba.com/?rf=footer" title="ウマい馬券">ウマい馬券</a>
# </li>
# <li>
# <a href="https://news.netkeiba.com/?pid=column_top&amp;rf=footer" title="コラム">コラム</a>
# </li>
# <li>
# <a href="https://tv.netkeiba.com/?rf=footer" title="netkeibaTV">netkeibaTV</a>
# </li>
# <li>
# <a href="https://nar.netkeiba.com/?rf=footer" title="地方競馬">地方競馬</a>
# </li>
# <li>
# <a href="https://db.netkeiba.com/?rf=footer" title="データベース">データベース</a>
# </li>
# <li>
# <a href="https://orepro.netkeiba.com/?rf=footer" title="俺プロ">俺プロ</a>
# </li>
# </ul>
# <ul>
# <li>
# <a href="https://owner.netkeiba.com/?rf=footer" title="一口馬主">一口馬主</a>
# </li>
# <li>
# <a href="https://pog.netkeiba.com/?rf=footer" title="POG">POG</a>
# </li>
# <li>
# <a href="https://bbs.pc.keiba.findfriends.jp/?rf=footer" title="競馬広場">競馬広場</a>
# </li>
# <li>
# <a href="https://dir.netkeiba.com/keibamatome/index.html?rf=footer" title="まとめ">まとめ</a>
# </li>
# <li>
# <a href="https://yoso.netkeiba.com/senmonshi/?rf=footer" title="競馬新聞">競馬新聞</a>
# </li>
# <li>
# <a href="https://race.netkeiba.com/?pid=bookmark&amp;rf=footer" title="お気に入り馬">お気に入り馬</a>
# </li>
# <li>
# <a href="https://regist.netkeiba.com/?rf=footer" title="アカウント">アカウント</a>
# </li>
# </ul>
# </dd>
# </dl>
# <dl class="NkFoot01">
# <dt>ヘルプ＆ガイド</dt>
# <dd>
# <ul>
# <li>
# <a href="https://info.netkeiba.com/?rf=footer" title="お知らせ">お知らせ</a>
# </li>
# <li>
# <a href="https://regist.netkeiba.com/?pid=premium&amp;rf=footer" title="プレミアムサービスのご案内">プレミアムサービスのご案内</a>
# </li>
# <li>
# <a href="https://regist.netkeiba.com/?pid=help&amp;rf=footer" title="よくある質問・お問い合わせ">よくある質問・お問い合わせ</a>
# </li>
# </ul>
# </dd>
# </dl>
# <dl class="NkFoot01">
# <dt>netkeiba.comについて</dt>
# <dd>
# <ul>
# <li>
# <a href="https://www.netkeiba.com/recruit/?rf=footer" title="採用情報">採用情報</a>
# </li>
# <li>
# <a href="https://www.netkeiba.com/info/ad/?rf=footer" title="広告掲載について">広告掲載について</a>
# </li>
# <li>
# <a href="https://www.netkeiba.com/info/kiyaku.html?rf=footer" title="利用規約">利用規約</a>
# </li>
# <li>
# <a href="https://www.netdreamers.co.jp/company/about/privacy.html?rf=footer" title="プライバシーポリシー">プライバシーポリシー</a>
# </li>
# <li>
# <a href="https://www.netkeiba.com/info/guide.html?rf=footer" title="投稿ガイドライン">投稿ガイドライン</a>
# </li>
# <li>
# <a href="https://www.netkeiba.com/info/tokusyo.html?rf=footer" title="特定商取引法に基づく表記">特定商取引法に基づく表記</a>
# </li>
# <li>
# <a href="https://www.netdreamers.co.jp/?rf=footer" title="運営会社">運営会社</a>
# </li>
# </ul>
# </dd>
# </dl>
# <dl class="NkFoot01">
# <dt>スマホでnetkeiba</dt>
# <dd class="SpNkInfoImg">
# <img alt="検索" class="SearchImg01" src="https://cdn.netkeiba.com/img.www/style/netkeiba.ja/image/common/img_nk_searchimg01.png?2019121001">
# <img alt="バーコード" class="QrImg01" src="https://cdn.netkeiba.com/img.www/style/netkeiba.ja/image/common/img_nk_qr01.png?2019121001">
# </img></img></dd>
# <dt>アプリでサクサクnetkeiba</dt>
# <dd>
# <ul class="AprStoreList fc">
# <li>
# <a href="https://itunes.apple.com/jp/app/id464562684/" title="Appstore"><img alt="Appstore" class="" src="https://cdn.netkeiba.com/img.www/style/netkeiba.ja/image/common/bnr_appstore_01.png?2019121001"/></a>
# </li>
# <li>
# <a href="https://play.google.com/store/apps/details?id=jp.co.netdreamers.netkeiba" title="googleplay"><img alt="googleplay" class="" src="https://cdn.netkeiba.com/img.www/style/netkeiba.ja/image/common/bnr_googleplay_01.png?20210728"/></a>
# </li>
# </ul>
# </dd>
# <dd class="Nk_Sns">
# <ul class="fc">
# <li>
# <a class="Tw" href="https://twitter.com/netkeiba" title="公式 X"></a>
# </li>
# <li>
# <a class="Fb" href="https://ja-jp.facebook.com/netkeiba" title="公式 Facebook"></a>
# </li>
# <li>
# <a class="Line" href="https://line.me/R/ti/p/%40oa-netkeiba" title="LINE"></a>
# </li>
# <li>
# <a class="Yt" href="http://www.youtube.com/user/netkeibaTV" title="netkeibaチャンネル"></a>
# </li>
# <li>
# <a class="Ig" href="https://www.instagram.com/netkeiba/" title="Instagram"></a>
# </li>
# <li>
# <a class="Rss" href="https://www.netkeiba.com/?pid=rss" title="RSS"></a>
# </li>
# </ul>
# </dd>
# </dl>
# </div><!-- /.FootWrap -->
# </div><!-- /.NkFooterArea -->
# <div class="GlobalFooterArea">
# <div class="FootWrap">
# <dl class="NkFoot02">
# <dt class="GfootIcon01 IconGame01">netkeiba.com 公式競馬ゲーム</dt>
# <dd>
# <ul>
# <li>
# <a href="https://www.netkeiba.com/game/umasta.html?rf=footer" target="_blank" title="うまいるスタジアム">みんなの愛馬とバトル！ <strong>うまいるスタジアム</strong></a>
# </li>
# </ul>
# </dd>
# <dt class="GfootIcon01 IconSisterSite01">netkeiba.com 姉妹サイト</dt>
# <dd>
# <ul>
# <li>
# <a href="//keirin.netkeiba.com/?rf=footer" target="_blank">競輪総合メディア <strong>netkeirin(ネットケイリン)</strong></a>
# </li>
# </ul>
# </dd>
# </dl>
# <dl class="NkFoot02">
# <dt class="GfootIcon01 IconMedia01">関連メディア</dt>
# <dd>
# <ul>
# <li>
# <a href="https://sp.baseball.findfriends.jp/?rf=footer" target="_blank" title="週刊ベースボールONLINE">徹底取材！野球情報は <strong>週刊ベースボールONLINE</strong></a>
# </li>
# <li>
# <a href="https://sp.golf.findfriends.jp/?rf=footer" target="_blank" title="ワッグルオンライン">ゴルフレッスン情報サイト <strong>ワッグルオンライン</strong></a>
# </li>
# <li>
# <a href="https://recipe.sp.findfriends.jp/?rf=footer" target="_blank" title="KATSUYOレシピ">小林カツ代直伝！ <strong>KATSUYOレシピ</strong></a>
# </li>
# </ul>
# </dd>
# </dl>
# <dl class="NkFoot02">
# <dt class="GfootIcon01 IconSoftware01">ソフトウェア・プロダクト</dt>
# <dd>
# <ul>
# <li>
# <a href="https://smart.lets-ktai.jp/?rf=footer" target="_blank" title="SMART会員証">もっともセキュアな店舗売上向上アプリ <strong>SMART会員証</strong></a>
# </li>
# <li>
# <a href="https://lets-ktai.jp/?rf=footer" target="_blank" title="Let'sケータイ！">スマホサイト制作ASP <strong>Let'sケータイ！</strong></a>
# </li>
# <li>
# <a href="https://webspiral.jp/?rf=footer" target="_blank" title="WEB SPIRAL">サイト運営を劇的に効率化するCMS <strong>WEB SPIRAL</strong></a>
# </li>
# </ul>
# </dd>
# </dl>
# </div><!-- /.FootWrap -->
# <p class="CopyRight">
# <small>© Net Dreamers Co., Ltd.</small>
# </p>
# </div><!-- /.GlobalFooterArea -->
# <!-- Google Tag Manager -->
# <!-- remove gtm_20220924 -->
# <!-- End Google Tag Manager -->
# <!-- block=common__advertisement_gam (d) -->
# <div class="nk_AdvBox_pc mt30">
# <div id="geniee_overlay_outer" style="position:fixed; bottom: 0px; width:100%; height:90px; left:0px; right:0px; margin:auto; z-index:1000000000; text-align: center;background-color: rgba(40, 40, 40, 0.2);"> <img id="gn_interstitial_close_icon" onclick="document.getElementById('geniee_overlay_outer').style.display='none';" src="https://js.gsspcln.jp/i/7c087a913cb9d4e76b672c4dc767c1a2.png" style="height: 29px; width: 29px; display: block; position: absolute; top: 0px; left: 0px; right:0px; margin: 0px auto; z-index: 999999; transform: translateX(-378.5px);"/>
# <!-- Geniee Wrapper Body Tag 1491463 -->
# <div data-cptid="1491463">
# <script>
# gnshbrequest.cmd.push(function() {
# gnshbrequest.applyPassback("1491463", "[data-cptid='1491463']");
# });
# </script>
# </div>
# <!-- /Geniee Wrapper Body Tag 1491463 -->
# </div>
# </div>
# </footer>
# <!-- block=common__advertisement_taboola_bottom (d) -->
# <script type="text/javascript">
# window._taboola = window._taboola || [];
# _taboola.push({flush: true});
# </script>
# <!-- block=nkauth_login_sess_tag (d) -->
# <!-- Google Tag Manager -->
# <noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-K6PJT6" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager -->
# </body>
# </html>

# %%
url =  'https://yoso.netkeiba.com/nar/?pid=race_list'
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <!-- block=meta_tag_common_yoso (cg) -->
# <meta content="ja" http-equiv="content-language"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=1000" name="viewport"/>
# <meta content="telephone=no" name="format-detection">
# <meta content="netkeiba.comの【ウマい馬券】地方競馬予想 競馬予想レース一覧です。競馬プロ予想家が指数･データ･血統など各ジャンルで、地方競馬の大井･川崎･船橋･浦和の南関東4競馬場はじめ、帯広･門別･盛岡･水沢･金沢･笠松･名古屋･園田･姫路･高知･佐賀など全国の地方競馬で厳選競馬予想！" name="description">
# <meta content="地方競馬,競馬,予想,netkeiba.com,ネット競馬,ネットケイバ,南関東,帯広,門別,盛岡,水沢,浦和,船橋,大井,川崎,金沢,笠松,名古屋,園田,姫路,高知,佐賀,指数,データ,血統,競馬予想レース一覧" name="keywords">
# <meta content="https://www.netkeiba.com/style/netkeiba.ja/image/netkeiba.png" name="thumbnail">
# <!-- ogp用 -->
# <meta content="netkeiba.com" property="og:site_name"/>
# <meta content="article" property="og:type"/>
# <meta content="競馬予想レース一覧 | 【ウマい馬券】地方競馬予想 - netkeiba.com" property="og:title"/>
# <meta content="https://yoso.netkeiba.com/nar/?pid=race_list" property="og:url"/>
# <meta content="netkeiba.comの【ウマい馬券】地方競馬予想 競馬予想レース一覧です。競馬プロ予想家が指数･データ･血統など各ジャンルで、地方競馬の大井･川崎･船橋･浦和の南関東4競馬場はじめ、帯広･門別･盛岡･水沢･金沢･笠松･名古屋･園田･姫路･高知･佐賀など全国の地方競馬で厳選競馬予想！" property="og:description"/>
# <meta content="https://www.netkeiba.com/style/netkeiba.ja/image/netkeiba.png" property="og:image"/>
# <!-- Twitter用 -->
# <meta content="summary" property="twitter:card"/>
# <meta content="@netkeiba" property="twitter:site"/>
# <meta content="@netkeiba" name="twitter:creator">
# <!-- Facebook用 -->
# <meta content="30367" property="fb:admins">
# <!-- アノテーション -->
# <link href="https://yoso.netkeiba.com/nar/?pid=race_list" rel="canonical"/>
# <link href="https://yoso.sp.netkeiba.com/nar/?pid=race_list" media="only screen and (max-width: 640px)" rel="alternate"/>
# <title>競馬予想レース一覧 | 【ウマい馬券】地方競馬予想 - netkeiba.com</title>
# <!-- 構造化データ -->
# <script type="application/ld+json">
# [
# {
# "@context": "http://schema.org",
# "@type": "BreadcrumbList",
# "itemListElement": [
# {
# "@type": "ListItem",
# "position": 1,
# "item": {
# "@id": "https://www.netkeiba.com/",
# "name": "netkeiba.comトップ"
# }
# }, {
# "@type": "ListItem",
# "position": 2,
# "item": {
# "@id": "https://yoso.netkeiba.com/nar/",
# "name": "【ウマい馬券】地方競馬予想"
# }
# }, {
# "@type": "ListItem",
# "position": 3,
# "item": {
# "@id": "https://yoso.netkeiba.com/nar/?pid=race_list",
# "name": "競馬予想レース一覧"
# }
# }
# ]
# },{
# "@context":"http://schema.org",
# "@type":"WebSite",
# "url":"https://www.netkeiba.com/",
# "name":"netkeiba.com",
# "alternateName":"netkeiba.com - 国内最大級の競馬情報サイト",
# "description": "netkeiba.comは国内最大級の競馬情報サイトです。JRA全レースの出馬表やオッズ・予想、ニュース、コラム、競走馬50万頭以上収録の競馬データベース、地方競馬、POG、予想大会、コミュニティなどがご利用いただけます。",
# "sameAs":[
# "https://twitter.com/netkeiba",
# "https://www.facebook.com/netkeiba"
# ]
# },{
# "@context": "http://www.schema.org",
# "@type": "Organization",
# "name": "netkeiba.com",
# "url": "https://www.netkeiba.com/",
# "logo": "http://cimg3.sp.netkeiba.com/common/img/common/netkeiba_logo.png",
# "description": "netkeiba.comは国内最大級の競馬情報サイト「netkeiba.com」を運営しています。"
# }
# ]
# </script>
# <!-- block=yoso_common_js (cg) -->
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.12.0/jquery.min.js"></script>
# <script src="https://cdn.netkeiba.com/img.yoso/nar/common/js/social_cart.js?17072601"></script>
# <script src="https://cdn.netkeiba.com/img.yoso/nar/common/js/yoso/YosoNar.js?2017082801"></script>
# <script src="https://cdn.netkeiba.com/img.yoso2.sp/common/js/yoso/YosoJra.js?2018080801"></script>
# <script src="https://cdn.netkeiba.com/img.yoso/common/js/yoso/YosoJraNar.js?2021030301"></script>
# <script type="text/javascript">
# var _nar_action_api_url = 'https://yoso.netkeiba.com/nar/';
# YosoNar = new YosoNar('https://yoso.netkeiba.com/nar/'); //yoso.action.jsをオブジェクト化
# // $Id$
# window.console = {};
# window.console.log = function(i){return;};
# //
# </script>
# <!-- block=yoso_common_css (d) -->
# <link href="/favicon.ico" rel="shortcut icon"/>
# <link href="https://maxcdn.bootstrapcdn.com/font-awesome/4.5.0/css/font-awesome.min.css" rel="stylesheet"/>
# <link href="https://cdn.netkeiba.com/img.yoso/nar/common/css/race_yoso_list.css?2018051102" rel="stylesheet">
# <link href="https://cdn.netkeiba.com/img.yoso/nar/common/css/common_pc.css?2017030901" rel="stylesheet">
# <link href="https://cdn.netkeiba.com/img.yoso/nar/common/css/reset.css?2017030901" rel="stylesheet"/>
# <link href="https://cdn.netkeiba.com/img.yoso/nar/common/css/yoso_pc01.css?20230126" rel="stylesheet"/>
# <!-- link rel="stylesheet" href="https://cdn.netkeiba.com/img.www/style/netkeiba.ja/css/common_header.css" type="text/css" -->
# <!--
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.12.0/jquery.min.js"></script>
# -->
# <script src="//code.jquery.com/ui/1.11.4/jquery-ui.js"></script>
# <!-- Google Tag Manager -->
# <script>
# window.dataLayer = window.dataLayer || [];
# dataLayer.push({
# 'itemInfo': '','memberRank': 'NotLogin','memberId': ''
# });
# </script>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-K6PJT6');</script>
# <!-- End Google Tag Manager -->
# </link></link></meta></meta></meta></meta></meta></meta></head>
# <body class="Yoso">
# <div id="page">
# <!-- block=netkeiba_header (d) -->
# <link href="https://cdn.netkeiba.com/img.www/style/netkeiba.ja/css/pc_header.css" media="screen" rel="stylesheet" type="text/css"/>
# <p class="sp_nk_btn disp_none"><a href="http://www.netkeiba.com/?pid=go_sp" title="スマートフォン版へ"><img alt="スマートフォン版へ" class="imgover" src="https://cdn.netkeiba.com/img.www/style/netkeiba.ja/image/sp_nk_link_02.png"/></a></p>
# <header class="Header_Area fc">
# <div class="Header_Inner fc">
# <h1>
# <a href="https://www.netkeiba.com/?rf=logo" title="netkeiba.com">
# <img alt="netkeiba.com" src="https://cdn.netkeiba.com/img.www/style/netkeiba.ja/image/common/netkeiba_logo01.png"/>
# </a>
# </h1>
# <div class="DB_Search_Input">
# <form action="https://www.netkeiba.com/" class="Search_Box" method="POST">
# <input name="pid" type="hidden" value="search"/>
# <input name="type" type="hidden" value="db"/>
# <div class="InputTxt_Form_Box">
# <input class="Txt_Form" id="keywords" name="word" placeholder="馬名で検索" type="text" value=""/>
# </div><!-- / .InputTxt_Form -->
# <div class="Submit_Btn_Box">
# <svg class="IconInput01" height="41.05" viewbox="0 0 41.05 41.05" width="41.05" xmlns="http://www.w3.org/2000/svg">
# <g id="icon_search" transform="translate(-234.6 -459.7)">
# <circle class="st0" cx="15.6" cy="15.6" r="15.6" transform="translate(236.1 461.2)"></circle>
# <g>
# <path class="st1" d="M275.2,498.2a1.335,1.335,0,0,1,0,2l-.1.1a1.335,1.335,0,0,1-2,0l-11.2-11.2a1.335,1.335,0,0,1,0-2l.1-.1a1.335,1.335,0,0,1,2,0Z"></path>
# </g>
# </g>
# </svg>
# <input class="Submit_Btn" name="submit" type="submit" value="検 索"/>
# </div><!-- / .Submit_Btn_Box -->
# </form>
# </div><!-- / .DB_Search_Input -->
# <ul class="UserMyMenu fc">
# <li>
# <a href="https://regist.netkeiba.com/?pid=premium&amp;rf=header">
# <span>プレミアムサービス</span>
# </a>
# </li>
# <li>
# <a class="Icon_Header Icon_MyfavHorse" href="https://race.netkeiba.com/bookmark/bookmark.html?rf=navi">
# <span>お気に入り馬</span>
# </a>
# </li>
# <li>
# <a class="Icon_Header Icon_Login" href="https://regist.netkeiba.com/account/?pid=login">
# <span>ログイン/会員登録</span>
# </a>
# </li>
# <li class="disp_none header_stage_area no_login_show">
# <a href="https://regist.netkeiba.com/?pid=stage_login&amp;action=login&amp;return_url=https://regist.netkeiba.com/">
# <span>(s)ログイン</span>
# </a>
# </li>
# <li class="disp_none header_stage_area no_login_show">
# <a href="https://regist.netkeiba.com/?pid=user_add_form&amp;payment=nk_user&amp;goods_cd=310409&amp;opt=init">
# <span>(s)無料会員登録</span>
# </a>
# <li class="disp_none header_stage_area login_show">
# <a href="https://regist.netkeiba.com/?pid=stage_login&amp;action=logout&amp;return_url=https://regist.netkeiba.com/">
# <span>(s)ログアウト</span>
# </a>
# </li>
# </li>
# </ul>
# <div class="SiteToggleBtn01 Keirin">
# <a href="https://keirin.netkeiba.com/?rf=nk_pc_header">
# <span class="LiveRace">LIVE</span>
# <img alt="" class="KeirinLogoMark01" height="16" src="https://cdn.netkeiba.com/img.www/style/netkeiba.ja/image/common/icon_keirin01.png" width="21"/>競輪
# </a>
# </div><!-- /.SiteToggleBtn01 -->
# </div><!-- /.Header_Inner -->
# </header>
# <nav class="ContentNavi01">
# <ul class="fc">
# <li class="Top">
# <a href="https://www.netkeiba.com/?rf=navi" id="navi_link_top" title="トップ">トップ</a>
# </li>
# <li class="News">
# <a href="https://news.netkeiba.com/?rf=navi" id="navi_link_news" title="ニュース">ニュース</a>
# </li>
# <li class="Race">
# <a href="https://race.netkeiba.com/top/?rf=navi" id="navi_link_race" title="レース">レース</a>
# </li>
# <li class="Yoso">
# <a href="https://yoso.netkeiba.com/?access=init&amp;rf=navi" id="navi_link_yoso" title="予想">予想</a>
# </li>
# <li class="Column">
# <a href="https://news.netkeiba.com/?pid=column_top&amp;rf=navi" id="navi_link_column" title="コラム">コラム</a>
# </li>
# <li class="Tv">
# <a href="https://tv.netkeiba.com/?rf=navi" id="navi_link_tv" title="netkeibaTV">netkeibaTV</a>
# </li>
# <li class="Local">
# <a href="https://nar.netkeiba.com/top/?rf=navi" id="navi_link_nar" title="地方競馬">地方競馬</a>
# </li>
# <li class="Db">
# <a href="https://db.netkeiba.com/?rf=navi" id="navi_link_db" title="データベース">データベース</a>
# </li>
# <li class="Paper">
# <a href="https://yoso.netkeiba.com/senmonshi/?rf=navi" id="navi_link_senmonshi" title="競馬新聞">競馬新聞</a>
# </li>
# <li class="YosoCS">
# <a href="https://orepro.netkeiba.com/?rf=navi" id="navi_link_orepro" title="俺プロ">俺プロ</a>
# </li>
# <li class="Owner">
# <a href="https://owner.netkeiba.com/?rf=navi" id="navi_link_owner" title="一口馬主">一口馬主</a>
# </li>
# <li class="Pog">
# <a href="https://pog.netkeiba.com/?rf=navi" id="navi_link_pog" title="POG">POG</a>
# </li>
# <li class="Matome">
# <a href="https://dir.netkeiba.com/keibamatome/index.html?rf=navi" id="navi_link_keibamatome" title="まとめ">まとめ</a>
# </li>
# </ul>
# </nav><!-- /.ContentNavi01 -->
# <!-- Geniee Wrapper Head Tag -->
# <script>
# window.gnshbrequest = window.gnshbrequest || {cmd:[]};
# gnshbrequest.cmd.push(function(){
# gnshbrequest.registerPassback("1491440");
# gnshbrequest.forceInternalRequest();
# });
# </script>
# <script async="" src="https://cpt.geniee.jp/hb/v1/211239/47/wrapper.min.js"></script>
# <!-- /Geniee Wrapper Head Tag -->
# <script async="" src="https://cdn.netkeiba.com/img.racev4.sp/common/js/nd_util.min.js"></script>
# <script type="text/javascript">
# $(document).ready(function() {
# show_user();
# });
# function show_user(){
# var is_stage = '';
# var is_user  = '';
# var is_alert = '';
# var is_sp    = '';
# var nickname = '';
# var user_img = '';
# if(is_sp) {
# $('.sp_nk_btn').show();
# }
# if(! is_stage) {
# $('.header_stage_area').remove();
# }
# if(is_user){
# //ログイン中
# $('.login_show').show();
# if(is_alert) {
# $('.Alert_New').show();
# }
# } else {
# //未ログイン
# $('.no_login_show').show();
# $('.login_show').remove();
# }
# }
# </script>
# <!-- block=yoso_menu (d) -->
# <div class="YosoGenreMenu TypeNarYoso">
# <div class="GenreMenuWrap">
# <div class="GenreMenuArea02">
# <ul class="SubMenu_02">
# <li class="TypeJra" id="type_change_jra">
# <a href="https://yoso.netkeiba.com/">中央競馬</a>
# </li>
# <li class="TypeNar Active" id="type_change_nar">
# <a href="https://yoso.netkeiba.com/nar/">地方競馬</a>
# </li>
# </ul>
# </div><!--/ .GenreMenuArea02 -->
# <div class="GenreMenuArea01">
# <ul class="SubMenu_01 fc">
# <li id="yoso_menu_001">
# <a href="?pid=top">
# <span class="YosoLogo01">ウマい馬券</span>地方 トップ
# </a>
# </li>
# <li id="yoso_menu_002">
# <a href="?pid=yosoka_ranking">予想家から探す</a>
# </li>
# <li id="yoso_menu_003">
# <a href="?pid=race_list">レースから探す</a>
# </li>
# <li id="yoso_menu_004">
# <a href="?pid=mypage&amp;user_tab=purchase&amp;syusai=nar">購入履歴</a>
# </li>
# </ul>
# </div><!--/ .GenreMenuArea01 -->
# </div><!--/ .GenreMenuWrap -->
# </div><!--/ .YosoGenreMenu .TypeNarYoso -->
# <script type="text/javascript">
# $(function(){
# $('.No_Link a').click(function() {
# return false;
# });
# /* navigation tab active */
# $('#type_change_nar').addClass("Active");
# $('#yoso_menu_003').addClass("Active");
# });
# </script>
# <div class="RaceNaviArea01 RaceListNavi">
# <script language="JavaScript" type="text/javascript">
# noCacheParam=Math.random()*10000000000;document.write('<scr'+'ipt type="text/javascript" src="https://netdreamersad.durasite.net/A-affiliate2/mobile?site=23&keyword=pc_nk_yoso_racelist_001&isJS=true&encoding=EUC-JP&ord=' + noCacheParam + '"></scr'+'ipt>');
# </script>
# <!-- 開催日・開催場の選択 -->
# <!-- block=race_kaisai_navi (d) -->
# <link href="https://cdn.netkeiba.com/img.yoso/nar/common/css/jquery.fancybox.css?2015081401" media="screen" rel="stylesheet" type="text/css"/>
# <script src="https://cdn.netkeiba.com/img.yoso/nar/common/js/jquery.fancybox.pack.js?2015081401" type="text/javascript"></script>
# <div class="RaceDayWrap">
# <div class="RaceDayPrev">
# <a class="Active" href="?pid=race_list&amp;kaisai_date=20231007">前へ</a>
# </div><!-- /.RaceDayPrev -->
# <div class="Tab_RaceDaySelect">
# <ul class="Col3 Tab">
# <li>
# <a href="?pid=race_list&amp;kaisai_date=20231009">
# <span class="DaysTxt01">10/9<span class="MonColor">(月)</span></span>
# <span class="KaisaiTxt01">川崎/帯広(ば)/盛岡</span>
# </a>
# </li><li class="Active">
# <a href="?pid=race_list&amp;kaisai_date=20231010">
# <span class="DaysTxt01">10/10<span class="TueColor">(火)</span></span>
# <span class="KaisaiTxt01">川崎/門別/笠松/金沢/盛岡</span>
# </a>
# </li>
# <li>
# <a href="?pid=race_list&amp;kaisai_date=20231011">
# <span class="DaysTxt01">10/11<span class="WedColor">(水)</span></span>
# <span class="KaisaiTxt01">川崎/園田/門別/笠松</span>
# </a>
# </li>
# </ul>
# </div><!-- /.Tab_RaceDaySelect -->
# <div class="RaceDayNext">
# <a class="Active" href="?pid=race_list&amp;kaisai_date=20231013">次へ</a>
# </div><!-- /.RaceDayNext -->
# <div class="RaceNavi_Calender Fancy_Calendar">
# <a href="#"><img alt="" src="https://cdn.netkeiba.com/img.yoso/nar/common/img/icon/icon_calendar.png" width="29"/></a>
# </div><!-- /.Calender -->
# </div>
# <script>
# (function($) {
# $('.No_Link a').click(function() {
# return false;
# });
# })(jQuery);
# $(function() {
# $(".Fancy_Calendar").fancybox({
# 'padding': 8,
# 'type': 'iframe',
# 'width': 960,
# 'scrolling': 'no',
# beforeLoad: function(){
# this.href = '?pid=race_calendar';
# }
# });
# });
# // ページURLのパラメータ取得
# function get_page_query()
# {
# var query = location.search.replace(/^\?/, '').split('&');
# var ary_q = {};
# for(i=0; i<query.length; i++){
# var q = query[i].split('=');
# ary_q[q[0]] = q[1];
# }
# return ary_q;
# }
# </script>
# </div><!-- /#RaceNaviArea01 -->
# <div class="fc" id="contents">
# <!--
# <link rel="stylesheet" href="https://cdn.netkeiba.com/img.yoso/nar//common/css/live_commerce_link.css" type="text/css" media="screen" />
# -->
# <div id="live_commerce_link" style="display:none"></div>
# <script>
# $(document).ready( function(){
# console.log("api_get_live_commerce_link");
# var _data = { pid : 'api_get_live_commerce_link' };
# _data.input     = 'UTF-8';
# _data.output    = 'jsonp';
# _data.syusai = "nar";
# _data.device = "pc";
# _data.mode = "text_banner";
# _data.ref = "yoso_pc_nar_race_list";
# jQuery.ajax( {type  :'GET',
# url      : "https://yoso.sp.netkeiba.com/",
# data     : _data,
# dataType : _data.output,
# success  : function( data )
# {
# $("#live_commerce_link").html(data);
# $("#live_commerce_link").show();
# },
# error  : function(XMLHttpRequest, textStatus, errorThrown)
# {
# console.log("view data not exiest");
# }
# });
# });
# </script>
# <!-- レース一覧 -->
# <!-- block=race_list (cp) -->
# <link href="https://cdn.netkeiba.com/img.yoso/nar/common/css/race_yoso_list.css" rel="stylesheet"/>
# <link href="https://cdn.netkeiba.com/img.yoso/nar/common/css/common_pc.css" rel="stylesheet"/>
# <link href="https://cdn.netkeiba.com/img.yoso/nar/common/css/reset.css" rel="stylesheet"/>
# <link href="https://cdn.netkeiba.com/img.yoso/nar/common/css/yoso_pc01.css" rel="stylesheet"/>
# <div class="RaceList_Wrap fc">
# <div class="RaceList">
# <div class="RaceList_Header">
# <div class="Jyo"><a href="https://yoso.netkeiba.com/nar/?pid=keibajou&amp;jou=kawasaki">川崎</a><span>(8回2日目)</span></div>
# <ul class="JyoData">
# <li class="Weather">天気：<span class="Icon_Weather IconWeather02"></span></li>
# <li class="DartColor">ダ：重</li>
# </ul>
# </div>
# <div class="RaceList_Main">
# <ul>
# <li>
# <a class="RaceFixed" href="?pid=race_yoso_list&amp;race_id=202345101001">
# <div class="RaceNum"><span>1R</span></div>
# <dl>
# <dt class="RaceName">3歳4<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">15:00</span>
# <span class="DartColor">ダ1400m</span>
# <span class="Count">8頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202345101001"><span id="gv_202345101001">0</span></span>
# </a>
# </li><li>
# <a class="RaceFixed" href="?pid=race_yoso_list&amp;race_id=202345101002">
# <div class="RaceNum"><span>2R</span></div>
# <dl>
# <dt class="RaceName">未受賞(2歳)<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">15:30</span>
# <span class="DartColor">ダ1400m</span>
# <span class="Count">7頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202345101002"><span id="gv_202345101002">0</span></span>
# </a>
# </li><li>
# <a class="RaceFixed" href="?pid=race_yoso_list&amp;race_id=202345101003">
# <div class="RaceNum"><span>3R</span></div>
# <dl>
# <dt class="RaceName">松虫賞(2歳)<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">16:00</span>
# <span class="DartColor">ダ1400m</span>
# <span class="Count">12頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202345101003"><span id="gv_202345101003">0</span></span>
# </a>
# </li><li>
# <a class="RaceFixed" href="?pid=race_yoso_list&amp;race_id=202345101004">
# <div class="RaceNum"><span>4R</span></div>
# <dl>
# <dt class="RaceName">天王山賞(C2二)<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">16:30</span>
# <span class="DartColor">ダ1600m</span>
# <span class="Count">9頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202345101004"><span id="gv_202345101004">0</span></span>
# </a>
# </li><li>
# <a href="?pid=race_yoso_list&amp;race_id=202345101005">
# <div class="RaceNum"><span>5R</span></div>
# <dl>
# <dt class="RaceName">大返し賞(C2二)<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">17:00</span>
# <span class="DartColor">ダ1400m</span>
# <span class="Count">11頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202345101005"><span id="gv_202345101005">0</span></span>
# </a>
# </li><li>
# <a class="RaceNext" href="?pid=race_yoso_list&amp;race_id=202345101006">
# <div class="RaceNum"><span>6R</span></div>
# <dl>
# <dt class="RaceName">四面楚歌賞(C2二)<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">17:30</span>
# <span class="DartColor">ダ1500m</span>
# <span class="Count">6頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202345101006"><span id="gv_202345101006">0</span></span>
# </a>
# </li><li>
# <a href="?pid=race_yoso_list&amp;race_id=202345101007">
# <div class="RaceNum"><span>7R</span></div>
# <dl>
# <dt class="RaceName">高麗山賞(C1五)<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">18:00</span>
# <span class="DartColor">ダ1600m</span>
# <span class="Count">10頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202345101007"><span id="gv_202345101007">0</span></span>
# </a>
# </li><li>
# <a href="?pid=race_yoso_list&amp;race_id=202345101008">
# <div class="RaceNum"><span>8R</span></div>
# <dl>
# <dt class="RaceName">大磯らしい潤いづくり賞(C1)<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">18:30</span>
# <span class="DartColor">ダ900m</span>
# <span class="Count">11頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202345101008"><span id="gv_202345101008">0</span></span>
# </a>
# </li><li>
# <a href="?pid=race_yoso_list&amp;race_id=202345101009">
# <div class="RaceNum"><span>9R</span></div>
# <dl>
# <dt class="RaceName">めいど いんおおいそ賞(B3)<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">19:05</span>
# <span class="DartColor">ダ1400m</span>
# <span class="Count">10頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202345101009"><span id="gv_202345101009">0</span></span>
# </a>
# </li><li>
# <a href="?pid=race_yoso_list&amp;race_id=202345101010">
# <div class="RaceNum"><span>10R</span></div>
# <dl>
# <dt class="RaceName">大磯まつり2023特別(B1B2)<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">19:40</span>
# <span class="DartColor">ダ1600m</span>
# <span class="Count">11頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202345101010"><span id="gv_202345101010">0</span></span>
# </a>
# </li><li>
# <a href="?pid=race_yoso_list&amp;race_id=202345101011">
# <div class="RaceNum"><span>11R</span></div>
# <dl>
# <dt class="RaceName">サルビアカップ(OP)(3歳)<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">20:15</span>
# <span class="DartColor">ダ2000m</span>
# <span class="Count">13頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202345101011"><span id="gv_202345101011">0</span></span>
# </a>
# </li><li>
# <a href="?pid=race_yoso_list&amp;race_id=202345101012">
# <div class="RaceNum"><span>12R</span></div>
# <dl>
# <dt class="RaceName">津久井やまびこ祭りカップ(3歳)<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">20:50</span>
# <span class="DartColor">ダ1500m</span>
# <span class="Count">11頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202345101012"><span id="gv_202345101012">0</span></span>
# </a>
# </li>
# </ul>
# </div>
# </div><!-- /.RaceList_Main -->
# <div class="RaceList">
# <div class="RaceList_Header">
# <div class="Jyo"><a href="https://yoso.netkeiba.com/nar/?pid=keibajou&amp;jou=monbetsu">門別</a><span>(13回4日目)</span></div>
# <ul class="JyoData">
# <li class="Weather">天気：<span class="Icon_Weather IconWeather02"></span></li>
# <li class="DartColor">ダ：稍</li>
# </ul>
# </div>
# <div class="RaceList_Main">
# <ul>
# <li>
# <a class="RaceFixed" href="?pid=race_yoso_list&amp;race_id=202330101001">
# <div class="RaceNum"><span>1R</span></div>
# <dl>
# <dt class="RaceName">2歳 未勝利<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">14:45</span>
# <span class="DartColor">ダ1100m</span>
# <span class="Count">12頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202330101001"><span id="gv_202330101001">0</span></span>
# </a>
# </li><li>
# <a class="RaceFixed" href="?pid=race_yoso_list&amp;race_id=202330101002">
# <div class="RaceNum"><span>2R</span></div>
# <dl>
# <dt class="RaceName">2歳牝馬 未勝利<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">15:15</span>
# <span class="DartColor">ダ1000m</span>
# <span class="Count">12頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202330101002"><span id="gv_202330101002">0</span></span>
# </a>
# </li><li>
# <a class="RaceFixed" href="?pid=race_yoso_list&amp;race_id=202330101003">
# <div class="RaceNum"><span>3R</span></div>
# <dl>
# <dt class="RaceName">3歳以上 C4ー3<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">15:45</span>
# <span class="DartColor">ダ1600m</span>
# <span class="Count">10頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202330101003"><span id="gv_202330101003">0</span></span>
# </a>
# </li><li>
# <a class="RaceFixed" href="?pid=race_yoso_list&amp;race_id=202330101004">
# <div class="RaceNum"><span>4R</span></div>
# <dl>
# <dt class="RaceName">3歳以上 C4ー3<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">16:20</span>
# <span class="DartColor">ダ1700m</span>
# <span class="Count">12頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202330101004"><span id="gv_202330101004">0</span></span>
# </a>
# </li><li>
# <a class="RaceFixed" href="?pid=race_yoso_list&amp;race_id=202330101005">
# <div class="RaceNum"><span>5R</span></div>
# <dl>
# <dt class="RaceName">2歳 3組<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">16:50</span>
# <span class="DartColor">ダ1000m</span>
# <span class="Count">8頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202330101005"><span id="gv_202330101005">0</span></span>
# </a>
# </li><li>
# <a class="RaceNext" href="?pid=race_yoso_list&amp;race_id=202330101006">
# <div class="RaceNum"><span>6R</span></div>
# <dl>
# <dt class="RaceName">3歳以上 C4ー2<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">17:20</span>
# <span class="DartColor">ダ1200m</span>
# <span class="Count">8頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202330101006"><span id="gv_202330101006">0</span></span>
# </a>
# </li><li>
# <a href="?pid=race_yoso_list&amp;race_id=202330101007">
# <div class="RaceNum"><span>7R</span></div>
# <dl>
# <dt class="RaceName">3歳以上 C3ー2 C4ー1<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">17:50</span>
# <span class="DartColor">ダ1000m</span>
# <span class="Count">12頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202330101007"><span id="gv_202330101007">0</span></span>
# </a>
# </li><li>
# <a href="?pid=race_yoso_list&amp;race_id=202330101008">
# <div class="RaceNum"><span>8R</span></div>
# <dl>
# <dt class="RaceName">3歳以上 C3ー2 C4ー1<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">18:20</span>
# <span class="DartColor">ダ1700m</span>
# <span class="Count">11頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202330101008"><span id="gv_202330101008">0</span></span>
# </a>
# </li><li>
# <a href="?pid=race_yoso_list&amp;race_id=202330101009">
# <div class="RaceNum"><span>9R</span></div>
# <dl>
# <dt class="RaceName">トルマリン特別(OP)(2歳)<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">18:55</span>
# <span class="DartColor">ダ1000m</span>
# <span class="Count">8頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202330101009"><span id="gv_202330101009">0</span></span>
# </a>
# </li><li>
# <a href="?pid=race_yoso_list&amp;race_id=202330101010">
# <div class="RaceNum"><span>10R</span></div>
# <dl>
# <dt class="RaceName">キンモクセイ特別(B1)<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">19:30</span>
# <span class="DartColor">ダ1200m</span>
# <span class="Count">12頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202330101010"><span id="gv_202330101010">0</span></span>
# </a>
# </li><li>
# <a href="?pid=race_yoso_list&amp;race_id=202330101011">
# <div class="RaceNum"><span>11R</span></div>
# <dl>
# <dt class="RaceName">静内軽種馬生産振興会特別(A4)<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">20:05</span>
# <span class="DartColor">ダ1200m</span>
# <span class="Count">11頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202330101011"><span id="gv_202330101011">0</span></span>
# </a>
# </li><li>
# <a href="?pid=race_yoso_list&amp;race_id=202330101012">
# <div class="RaceNum"><span>12R</span></div>
# <dl>
# <dt class="RaceName">毎日の贅沢。らんこし米特別(A3)<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">20:40</span>
# <span class="DartColor">ダ1800m</span>
# <span class="Count">9頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202330101012"><span id="gv_202330101012">0</span></span>
# </a>
# </li>
# </ul>
# </div>
# </div><!-- /.RaceList_Main -->
# <div class="RaceList">
# <div class="RaceList_Header">
# <div class="Jyo"><a href="https://yoso.netkeiba.com/nar/?pid=keibajou&amp;jou=kasamatsu">笠松</a><span>(10回1日目)</span></div>
# <ul class="JyoData">
# <li class="Weather">天気：<span class="Icon_Weather IconWeather01"></span></li>
# <li class="DartColor">ダ：良</li>
# </ul>
# </div>
# <div class="RaceList_Main">
# <ul>
# <li>
# <a class="RaceFixed" href="?pid=race_yoso_list&amp;race_id=202347101001">
# <div class="RaceNum"><span>1R</span></div>
# <dl>
# <dt class="RaceName">C26組<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">10:50</span>
# <span class="DartColor">ダ800m</span>
# <span class="Count">7頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202347101001"><span id="gv_202347101001">0</span></span>
# </a>
# </li><li>
# <a class="RaceFixed" href="?pid=race_yoso_list&amp;race_id=202347101002">
# <div class="RaceNum"><span>2R</span></div>
# <dl>
# <dt class="RaceName">C27組<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">11:25</span>
# <span class="DartColor">ダ1400m</span>
# <span class="Count">7頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202347101002"><span id="gv_202347101002">0</span></span>
# </a>
# </li><li>
# <a class="RaceFixed" href="?pid=race_yoso_list&amp;race_id=202347101003">
# <div class="RaceNum"><span>3R</span></div>
# <dl>
# <dt class="RaceName">C25組<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">12:00</span>
# <span class="DartColor">ダ1400m</span>
# <span class="Count">8頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202347101003"><span id="gv_202347101003">0</span></span>
# </a>
# </li><li>
# <a class="RaceFixed" href="?pid=race_yoso_list&amp;race_id=202347101004">
# <div class="RaceNum"><span>4R</span></div>
# <dl>
# <dt class="RaceName">C24組<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">12:35</span>
# <span class="DartColor">ダ1400m</span>
# <span class="Count">8頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202347101004"><span id="gv_202347101004">0</span></span>
# </a>
# </li><li>
# <a class="RaceFixed" href="?pid=race_yoso_list&amp;race_id=202347101005">
# <div class="RaceNum"><span>5R</span></div>
# <dl>
# <dt class="RaceName">笠松けいば秋まつりまであと4日(C)<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">13:10</span>
# <span class="DartColor">ダ1400m</span>
# <span class="Count">8頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202347101005"><span id="gv_202347101005">0</span></span>
# </a>
# </li><li>
# <a class="RaceFixed" href="?pid=race_yoso_list&amp;race_id=202347101006">
# <div class="RaceNum"><span>6R</span></div>
# <dl>
# <dt class="RaceName">C22組<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">13:45</span>
# <span class="DartColor">ダ1400m</span>
# <span class="Count">8頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202347101006"><span id="gv_202347101006">0</span></span>
# </a>
# </li><li>
# <a class="RaceFixed" href="?pid=race_yoso_list&amp;race_id=202347101007">
# <div class="RaceNum"><span>7R</span></div>
# <dl>
# <dt class="RaceName">C21組<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">14:20</span>
# <span class="DartColor">ダ1400m</span>
# <span class="Count">8頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202347101007"><span id="gv_202347101007">0</span></span>
# </a>
# </li><li>
# <a class="RaceFixed" href="?pid=race_yoso_list&amp;race_id=202347101008">
# <div class="RaceNum"><span>8R</span></div>
# <dl>
# <dt class="RaceName">C20組<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">14:55</span>
# <span class="DartColor">ダ1400m</span>
# <span class="Count">8頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202347101008"><span id="gv_202347101008">0</span></span>
# </a>
# </li><li>
# <a class="RaceFixed" href="?pid=race_yoso_list&amp;race_id=202347101009">
# <div class="RaceNum"><span>9R</span></div>
# <dl>
# <dt class="RaceName">六連星特別(B)<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">15:25</span>
# <span class="DartColor">ダ1600m</span>
# <span class="Count">7頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202347101009"><span id="gv_202347101009">0</span></span>
# </a>
# </li><li>
# <a class="RaceFixed" href="?pid=race_yoso_list&amp;race_id=202347101010">
# <div class="RaceNum"><span>10R</span></div>
# <dl>
# <dt class="RaceName">秋の四辺形特別(B)<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">16:05</span>
# <span class="DartColor">ダ1400m</span>
# <span class="Count">8頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202347101010"><span id="gv_202347101010">0</span></span>
# </a>
# </li>
# </ul>
# </div>
# </div><!-- /.RaceList_Main -->
# </div><div class="RaceList_Wrap fc">
# <div class="RaceList">
# <div class="RaceList_Header">
# <div class="Jyo"><a href="https://yoso.netkeiba.com/nar/?pid=keibajou&amp;jou=kanazawa">金沢</a><span>(14回4日目)</span></div>
# <ul class="JyoData">
# <li class="Weather">天気：<span class="Icon_Weather IconWeather02"></span></li>
# <li class="DartColor">ダ：不</li>
# </ul>
# </div>
# <div class="RaceList_Main">
# <ul>
# <li>
# <a class="RaceFixed" href="?pid=race_yoso_list&amp;race_id=202346101001">
# <div class="RaceNum"><span>1R</span></div>
# <dl>
# <dt class="RaceName">うまかつ.net金沢ジョッキー選手権6(C2)<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">11:35</span>
# <span class="DartColor">ダ1400m</span>
# <span class="Count">12頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202346101001"><span id="gv_202346101001">0</span></span>
# </a>
# </li><li>
# <a class="RaceFixed" href="?pid=race_yoso_list&amp;race_id=202346101002">
# <div class="RaceNum"><span>2R</span></div>
# <dl>
# <dt class="RaceName">地方競馬教養センター騎手候補生募集中賞(C1)<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">12:10</span>
# <span class="DartColor">ダ1400m</span>
# <span class="Count">9頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202346101002"><span id="gv_202346101002">0</span></span>
# </a>
# </li><li>
# <a class="RaceFixed" href="?pid=race_yoso_list&amp;race_id=202346101003">
# <div class="RaceNum"><span>3R</span></div>
# <dl>
# <dt class="RaceName">C18<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">12:45</span>
# <span class="DartColor">ダ1400m</span>
# <span class="Count">10頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202346101003"><span id="gv_202346101003">0</span></span>
# </a>
# </li><li>
# <a class="RaceFixed" href="?pid=race_yoso_list&amp;race_id=202346101004">
# <div class="RaceNum"><span>4R</span></div>
# <dl>
# <dt class="RaceName">2歳3<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">13:20</span>
# <span class="DartColor">ダ1400m</span>
# <span class="Count">8頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202346101004"><span id="gv_202346101004">0</span></span>
# </a>
# </li><li>
# <a class="RaceFixed" href="?pid=race_yoso_list&amp;race_id=202346101005">
# <div class="RaceNum"><span>5R</span></div>
# <dl>
# <dt class="RaceName">サンビタリア賞(C1以下)<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">13:55</span>
# <span class="DartColor">ダ1400m</span>
# <span class="Count">9頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202346101005"><span id="gv_202346101005">0</span></span>
# </a>
# </li><li>
# <a class="RaceFixed" href="?pid=race_yoso_list&amp;race_id=202346101006">
# <div class="RaceNum"><span>6R</span></div>
# <dl>
# <dt class="RaceName">守らせろ最期まで!杯(C1特別)<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">14:30</span>
# <span class="DartColor">ダ1400m</span>
# <span class="Count">11頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202346101006"><span id="gv_202346101006">0</span></span>
# </a>
# </li><li>
# <a class="RaceFixed" href="?pid=race_yoso_list&amp;race_id=202346101007">
# <div class="RaceNum"><span>7R</span></div>
# <dl>
# <dt class="RaceName">C12特別編成(C1特別)<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">15:05</span>
# <span class="DartColor">ダ1400m</span>
# <span class="Count">9頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202346101007"><span id="gv_202346101007">0</span></span>
# </a>
# </li><li>
# <a class="RaceFixed" href="?pid=race_yoso_list&amp;race_id=202346101008">
# <div class="RaceNum"><span>8R</span></div>
# <dl>
# <dt class="RaceName">いしかわ百万石文化祭開幕まであと4日賞(C1)<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">15:40</span>
# <span class="DartColor">ダ1400m</span>
# <span class="Count">7頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202346101008"><span id="gv_202346101008">0</span></span>
# </a>
# </li><li>
# <a class="RaceFixed" href="?pid=race_yoso_list&amp;race_id=202346101009">
# <div class="RaceNum"><span>9R</span></div>
# <dl>
# <dt class="RaceName">B26<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">16:15</span>
# <span class="DartColor">ダ1500m</span>
# <span class="Count">9頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202346101009"><span id="gv_202346101009">0</span></span>
# </a>
# </li><li>
# <a href="?pid=race_yoso_list&amp;race_id=202346101010">
# <div class="RaceNum"><span>10R</span></div>
# <dl>
# <dt class="RaceName">B25<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">16:55</span>
# <span class="DartColor">ダ1500m</span>
# <span class="Count">9頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202346101010"><span id="gv_202346101010">0</span></span>
# </a>
# </li><li>
# <a class="RaceNext" href="?pid=race_yoso_list&amp;race_id=202346101011">
# <div class="RaceNum"><span>11R</span></div>
# <dl>
# <dt class="RaceName">湯涌ぼんぼり祭り記念(B2)<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">17:35</span>
# <span class="DartColor">ダ1400m</span>
# <span class="Count">11頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202346101011"><span id="gv_202346101011">0</span></span>
# </a>
# </li><li>
# <a href="?pid=race_yoso_list&amp;race_id=202346101012">
# <div class="RaceNum"><span>12R</span></div>
# <dl>
# <dt class="RaceName">馬券は楽天ポイントで買おう特別(A1)<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">18:10</span>
# <span class="DartColor">ダ1700m</span>
# <span class="Count">8頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202346101012"><span id="gv_202346101012">0</span></span>
# </a>
# </li>
# </ul>
# </div>
# </div><!-- /.RaceList_Main -->
# <div class="RaceList">
# <div class="RaceList_Header">
# <div class="Jyo"><a href="https://yoso.netkeiba.com/nar/?pid=keibajou&amp;jou=morioka">盛岡</a><span>(8回6日目)</span></div>
# <ul class="JyoData">
# <li class="Weather">天気：<span class="Icon_Weather IconWeather03"></span></li>
# <li class="DartColor">ダ：不</li>
# </ul>
# </div>
# <div class="RaceList_Main">
# <ul>
# <li>
# <a class="RaceFixed" href="?pid=race_yoso_list&amp;race_id=202335101001">
# <div class="RaceNum"><span>1R</span></div>
# <dl>
# <dt class="RaceName">2歳<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">11:50</span>
# <span class="DartColor">ダ1200m</span>
# <span class="Count">9頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202335101001"><span id="gv_202335101001">0</span></span>
# </a>
# </li><li>
# <a class="RaceFixed" href="?pid=race_yoso_list&amp;race_id=202335101002">
# <div class="RaceNum"><span>2R</span></div>
# <dl>
# <dt class="RaceName">2歳<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">12:20</span>
# <span class="DartColor">ダ1200m</span>
# <span class="Count">11頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202335101002"><span id="gv_202335101002">0</span></span>
# </a>
# </li><li>
# <a class="RaceFixed" href="?pid=race_yoso_list&amp;race_id=202335101003">
# <div class="RaceNum"><span>3R</span></div>
# <dl>
# <dt class="RaceName">C2四組<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">12:55</span>
# <span class="DartColor">ダ1400m</span>
# <span class="Count">8頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202335101003"><span id="gv_202335101003">0</span></span>
# </a>
# </li><li>
# <a class="RaceFixed" href="?pid=race_yoso_list&amp;race_id=202335101004">
# <div class="RaceNum"><span>4R</span></div>
# <dl>
# <dt class="RaceName">C2三組<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">13:30</span>
# <span class="DartColor">ダ1400m</span>
# <span class="Count">8頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202335101004"><span id="gv_202335101004">0</span></span>
# </a>
# </li><li>
# <a class="RaceFixed" href="?pid=race_yoso_list&amp;race_id=202335101005">
# <div class="RaceNum"><span>5R</span></div>
# <dl>
# <dt class="RaceName">C2二組<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">14:05</span>
# <span class="DartColor">ダ1400m</span>
# <span class="Count">8頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202335101005"><span id="gv_202335101005">0</span></span>
# </a>
# </li><li>
# <a class="RaceFixed" href="?pid=race_yoso_list&amp;race_id=202335101006">
# <div class="RaceNum"><span>6R</span></div>
# <dl>
# <dt class="RaceName">C2一組<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">14:40</span>
# <span class="DartColor">ダ1400m</span>
# <span class="Count">8頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202335101006"><span id="gv_202335101006">0</span></span>
# </a>
# </li><li>
# <a class="RaceFixed" href="?pid=race_yoso_list&amp;race_id=202335101007">
# <div class="RaceNum"><span>7R</span></div>
# <dl>
# <dt class="RaceName">C2<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">15:15</span>
# <span class="DartColor">ダ1600m</span>
# <span class="Count">12頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202335101007"><span id="gv_202335101007">0</span></span>
# </a>
# </li><li>
# <a class="RaceFixed" href="?pid=race_yoso_list&amp;race_id=202335101008">
# <div class="RaceNum"><span>8R</span></div>
# <dl>
# <dt class="RaceName">C1<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">15:50</span>
# <span class="DartColor">ダ1200m</span>
# <span class="Count">10頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202335101008"><span id="gv_202335101008">0</span></span>
# </a>
# </li><li>
# <a class="RaceFixed" href="?pid=race_yoso_list&amp;race_id=202335101009">
# <div class="RaceNum"><span>9R</span></div>
# <dl>
# <dt class="RaceName">C1五組<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">16:25</span>
# <span class="DartColor">ダ1400m</span>
# <span class="Count">9頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202335101009"><span id="gv_202335101009">0</span></span>
# </a>
# </li><li>
# <a class="RaceNext" href="?pid=race_yoso_list&amp;race_id=202335101010">
# <div class="RaceNum"><span>10R</span></div>
# <dl>
# <dt class="RaceName">C1二組<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">17:05</span>
# <span class="DartColor">ダ1600m</span>
# <span class="Count">12頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202335101010"><span id="gv_202335101010">0</span></span>
# </a>
# </li><li>
# <a href="?pid=race_yoso_list&amp;race_id=202335101011">
# <div class="RaceNum"><span>11R</span></div>
# <dl>
# <dt class="RaceName">C1一組<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">17:40</span>
# <span class="DartColor">ダ1600m</span>
# <span class="Count">12頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202335101011"><span id="gv_202335101011">0</span></span>
# </a>
# </li><li>
# <a href="?pid=race_yoso_list&amp;race_id=202335101012">
# <div class="RaceNum"><span>12R</span></div>
# <dl>
# <dt class="RaceName">初雁特別(A)<span class=""></span></dt>
# <dd class="RaceData">
# <span class="Time">18:15</span>
# <span class="DartColor">ダ1600m</span>
# <span class="Count">9頭</span>
# </dd>
# </dl>
# <span class="YosoCount" id="cnt_202335101012"><span id="gv_202335101012">0</span></span>
# </a>
# </li>
# </ul>
# </div>
# </div><!-- /.RaceList_Main -->
# </div>
# <div class="RaceList_Footer">
# <dl class="Description_Box">
# <dt class="GuideTitle">レース一覧の見方</dt>
# <dd class="GuideContents">
# <div class="ContentsInner">
# <table>
# <tr>
# <th><img alt="" src="https://cdn.netkeiba.com/img.yoso/nar/common/img/icon/icon_yoso_count_bg.png" width="16"/></th>
# <td><span class="mr05">…</span>の数字は、現在公開されている予想の数です。</td>
# </tr>
# <tr>
# <th><span class="Icon_Guide GuideBg01">11R</span></th>
# <td><span class="mr05">…</span>結果確定前</td>
# </tr>
# <tr>
# <th><span class="Icon_Guide GuideBg02">11R</span></th>
# <td><span class="mr05">…</span>次のレース(発走直前)</td>
# </tr>
# <tr>
# <th><span class="Icon_Guide GuideBg03">11R</span></th>
# <td><span class="mr05">…</span>結果確定</td>
# </tr>
# </table>
# </div>
# </dd>
# </dl>
# </div>
# <script src="https://cdn.netkeiba.com/img.yoso/common/js/yoso/yoso.action.js"></script>
# <script type="text/javascript">
# // $Id$
# var _action_api_url = 'https://yoso.netkeiba.com/';
# </script>
# <script type="text/javascript">
# $(function(){
# var ary_race_id = [];
# $('[id^="gv_"]').each(function(){
# var race_id = $(this).prop('id').replace(/gv_/,'');
# ary_race_id.push(race_id);
# });
# console.log('ary_race_id: %O',ary_race_id);
# countGoodsByRace(ary_race_id, cb_race_goods_count);
# });
# //
# function cb_race_goods_count( json )
# {
# console.log('cb_race_goods_count(%O)',json);
# for(var race_id in json){
# console.log('race_id: %s count: %d',race_id,json[race_id]['count']);
# var view_id = 'gv_'+race_id;
# if(json[race_id]['count']>0)
# {
# $('#'+view_id).text( json[race_id]['count'] );
# }
# }
# }
# </script>
# <!-- block=ad_gam (d) -->
# <div class="Ad" style="text-align:center;margin:18px 0 38px;">
# <!-- Geniee Wrapper Body Tag 1491440 -->
# <div data-cptid="1491440">
# <script>
# gnshbrequest.cmd.push(function() {
# gnshbrequest.applyPassback("1491440", "[data-cptid='1491440']");
# });
# </script>
# </div>
# <!-- /Geniee Wrapper Body Tag 1491440 -->
# </div><!-- /.nk_AdvBox_sp_01 -->
# </div><!-- /. Contents -->
# <!-- block=netkeiba_footer (d) -->
# <footer>
# <div class="NkFooterArea">
# <div class="BtnPagetop">
# <a href="javascript:void(0)" title="ページトップへ"></a>
# </div><!-- /.BtnPagetop -->
# <script type="text/javascript">
# $(function() {
# $('.BtnPagetop a').click(function () {
# $('body,html').animate({
# scrollTop: 0
# }, 400);
# return false;
# });
# });
# </script>
# <div class="KeirinLink01">
# <a href="//keirin.netkeiba.com/?rf=nk_pc_footer" title="netkeirin"><img alt="いま競輪が熱い！nerkeirinで競輪を気軽に楽しもう" src="https://cdn.netkeiba.com/img.www/style/netkeiba.ja/image/common/PC_footer_bnr01.png"/></a>
# </div><!-- /.KeirinLink01 -->
# <dl class="FootSiteTitle fc">
# <dt>
# <a href="https://www.netkeiba.com/?rf=footer" title="netkeiba.com">
# <img alt="netkeiba.com" src="https://cdn.netkeiba.com/img.www/style/netkeiba.ja/image/common/netkeiba_logo01.png">
# </img></a>
# </dt>
# <dd>
# <p>利用者数<strong>1700</strong>万人突破！<strong>No.1</strong>競馬サイト</p>
# </dd>
# </dl>
# <div class="FootWrap">
# <dl class="NkFoot01 NkFootCateLink">
# <dt>カテゴリ</dt>
# <dd class="fc">
# <ul>
# <li>
# <a href="https://news.netkeiba.com/?rf=footer" title="ニュース">ニュース</a>
# </li>
# <li>
# <a href="https://race.netkeiba.com/top/?rf=footer" title="レース">レース</a>
# </li>
# <li>
# <a href="https://yoso.netkeiba.com/?rf=footer" title="ウマい馬券">ウマい馬券</a>
# </li>
# <li>
# <a href="https://news.netkeiba.com/?pid=column_top&amp;rf=footer" title="コラム">コラム</a>
# </li>
# <li>
# <a href="https://tv.netkeiba.com/?rf=footer" title="netkeibaTV">netkeibaTV</a>
# </li>
# <li>
# <a href="https://nar.netkeiba.com/top/?rf=footer" title="地方競馬">地方競馬</a>
# </li>
# <li>
# <a href="https://db.netkeiba.com/?rf=footer" title="データベース">データベース</a>
# </li>
# <li>
# <a href="https://orepro.netkeiba.com/?rf=footer" title="俺プロ">俺プロ</a>
# </li>
# </ul>
# <ul>
# <li>
# <a href="https://owner.netkeiba.com/?rf=footer" title="一口馬主">一口馬主</a>
# </li>
# <li>
# <a href="https://pog.netkeiba.com/?rf=footer" title="POG">POG</a>
# </li>
# <li>
# <a href="https://bbs.pc.keiba.findfriends.jp/?rf=footer" title="競馬広場">競馬広場</a>
# </li>
# <li>
# <a href="https://dir.netkeiba.com/keibamatome/index.html?rf=footer" title="まとめ">まとめ</a>
# </li>
# <li>
# <a href="https://yoso.netkeiba.com/senmonshi/?rf=footer" title="競馬新聞">競馬新聞</a>
# </li>
# <li>
# <a href="https://race.netkeiba.com/bookmark/bookmark.html?rf=footer" title="お気に入り馬">お気に入り馬</a>
# </li>
# <li>
# <a href="https://regist.netkeiba.com/?rf=footer" title="アカウント">アカウント</a>
# </li>
# </ul>
# </dd>
# </dl>
# <dl class="NkFoot01">
# <dt>ヘルプ＆ガイド</dt>
# <dd>
# <ul>
# <li>
# <a href="https://info.netkeiba.com/?rf=footer" title="お知らせ">お知らせ</a>
# </li>
# <li>
# <a href="https://regist.netkeiba.com/?pid=premium&amp;rf=footer" title="プレミアムサービスのご案内">プレミアムサービスのご案内</a>
# </li>
# <li>
# <a href="https://regist.netkeiba.com/?pid=help&amp;rf=footer" title="よくある質問・お問い合わせ">よくある質問・お問い合わせ</a>
# </li>
# </ul>
# </dd>
# </dl>
# <dl class="NkFoot01">
# <dt>netkeiba.comについて</dt>
# <dd>
# <ul>
# <li>
# <a href="https://www.netkeiba.com/recruit/?rf=footer" title="採用情報">採用情報</a>
# </li>
# <li>
# <a href="https://www.netkeiba.com/info/ad/?rf=footer" title="広告掲載について">広告掲載について</a>
# </li>
# <li>
# <a href="https://www.netkeiba.com/info/kiyaku.html?rf=footer" title="利用規約">利用規約</a>
# </li>
# <li>
# <a href="https://www.netdreamers.co.jp/company/about/privacy.html?rf=footer" title="プライバシーポリシー">プライバシーポリシー</a>
# </li>
# <li>
# <a href="https://www.netkeiba.com/info/guide.html?rf=footer" title="投稿ガイドライン">投稿ガイドライン</a>
# </li>
# <li>
# <a href="https://www.netkeiba.com/info/tokusyo.html?rf=footer" title="特定商取引法に基づく表記">特定商取引法に基づく表記</a>
# </li>
# <li>
# <a href="https://www.netdreamers.co.jp/?rf=footer" title="運営会社">運営会社</a>
# </li>
# </ul>
# </dd>
# </dl>
# <dl class="NkFoot01">
# <dt>スマホでnetkeiba</dt>
# <dd class="SpNkInfoImg">
# <img alt="検索" class="SearchImg01" src="https://cdn.netkeiba.com/img.www/style/netkeiba.ja/image/common/img_nk_searchimg01.png">
# <img alt="バーコード" class="QrImg01" src="https://cdn.netkeiba.com/img.www/style/netkeiba.ja/image/common/img_nk_qr01.png">
# </img></img></dd>
# <dt>アプリでサクサクnetkeiba</dt>
# <dd>
# <ul class="AprStoreList fc">
# <li>
# <a href="https://itunes.apple.com/jp/app/id464562684/" title="Appstore"><img alt="Appstore" class="" src="https://cdn.netkeiba.com/img.www/style/netkeiba.ja/image/common/bnr_appstore_01.png"/></a>
# </li>
# <li>
# <a href="https://play.google.com/store/apps/details?id=jp.co.netdreamers.netkeiba" title="googleplay"><img alt="googleplay" class="" src="https://cdn.netkeiba.com/img.www/style/netkeiba.ja/image/common/bnr_googleplay_01.png?20210728"/></a>
# </li>
# </ul>
# </dd>
# <dd class="Nk_Sns">
# <ul class="fc">
# <li>
# <a class="Tw" href="https://twitter.com/netkeiba" title="公式 X"></a>
# </li>
# <li>
# <a class="Fb" href="https://ja-jp.facebook.com/netkeiba" title="公式 Facebook"></a>
# </li>
# <li>
# <a class="Line" href="https://line.me/R/ti/p/%40oa-netkeiba" title="LINE"></a>
# </li>
# <li>
# <a class="Yt" href="http://www.youtube.com/user/netkeibaTV" title="netkeibaチャンネル"></a>
# </li>
# <li>
# <a class="Ig" href="https://www.instagram.com/netkeiba/" title="Instagram"></a>
# </li>
# <li>
# <a class="Rss" href="https://www.netkeiba.com/?pid=rss" title="RSS"></a>
# </li>
# </ul>
# </dd>
# </dl>
# </div><!-- /.FootWrap -->
# </div><!-- /.NkFooterArea -->
# <div class="GlobalFooterArea">
# <div class="FootWrap">
# <dl class="NkFoot02">
# <dt class="GfootIcon01 IconGame01">netkeiba.com 公式競馬ゲーム</dt>
# <dd>
# <ul>
# <li>
# <a href="https://www.netkeiba.com/game/umasta.html?rf=footer" target="_blank" title="うまいるスタジアム">みんなの愛馬とバトル！ <strong>うまいるスタジアム</strong></a>
# </li>
# </ul>
# </dd>
# <dt class="GfootIcon01 IconSisterSite01">netkeiba.com 姉妹サイト</dt>
# <dd>
# <ul>
# <li>
# <a href="//keirin.netkeiba.com/?rf=footer" target="_blank">競輪総合メディア <strong>netkeirin(ネットケイリン)</strong></a>
# </li>
# </ul>
# </dd>
# </dl>
# <dl class="NkFoot02">
# <dt class="GfootIcon01 IconMedia01">関連メディア</dt>
# <dd>
# <ul>
# <li>
# <a href="https://sp.baseball.findfriends.jp/?rf=footer" target="_blank" title="週刊ベースボールONLINE">徹底取材！野球情報は <strong>週刊ベースボールONLINE</strong></a>
# </li>
# <li>
# <a href="https://sp.golf.findfriends.jp/?rf=footer" target="_blank" title="ワッグルオンライン">ゴルフレッスン情報サイト <strong>ワッグルオンライン</strong></a>
# </li>
# <li>
# <a href="https://recipe.sp.findfriends.jp/?rf=footer" target="_blank" title="KATSUYOレシピ">小林カツ代直伝！ <strong>KATSUYOレシピ</strong></a>
# </li>
# </ul>
# </dd>
# </dl>
# <dl class="NkFoot02">
# <dt class="GfootIcon01 IconSoftware01">ソフトウェア・プロダクト</dt>
# <dd>
# <ul>
# <li>
# <a href="https://smart.lets-ktai.jp/?rf=footer" target="_blank" title="SMART会員証">もっともセキュアな店舗売上向上アプリ <strong>SMART会員証</strong></a>
# </li>
# <li>
# <a href="https://lets-ktai.jp/?rf=footer" target="_blank" title="Let'sケータイ！">スマホサイト制作ASP <strong>Let'sケータイ！</strong></a>
# </li>
# <li>
# <a href="https://webspiral.jp/?rf=footer" target="_blank" title="WEB SPIRAL">サイト運営を劇的に効率化するCMS <strong>WEB SPIRAL</strong></a>
# </li>
# </ul>
# </dd>
# </dl>
# </div><!-- /.FootWrap -->
# <p class="CopyRight">
# <small>© Net Dreamers Co., Ltd.</small>
# </p>
# </div><!-- /.GlobalFooterArea -->
# </footer>
# <!-- Google Tag Manager --><!-- remove gtm_20220924 -->
# <!-- End Google Tag Manager -->
# </div><!-- /#page -->
# <!-- Google Tag Manager -->
# <noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-K6PJT6" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager -->
# </body>
# </html>

# %%
url = 'https://yoso.netkeiba.com/nar/?pid=race_list'
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# すべてのレースリストを取得
race_lists = soup.find_all('div', class_='RaceList')

race_data = []

for race_list in race_lists:
    venue = race_list.find('div', class_='Jyo').a.text
    races = race_list.find('div', class_='RaceList_Main').find_all('a')
    
    for race in races:
        race_number = race.find('div', class_='RaceNum').span.text
        race_id = race['href'].split('=')[-1]
        
        race_data.append({
            '会場': venue,
            'レース番号': race_number,
            'レースID': race_id
        })

# 結果を表示
for data in race_data:
    print(data)
# Out:
# {'会場': '川崎', 'レース番号': '1R', 'レースID': '202345101001'}
# {'会場': '川崎', 'レース番号': '2R', 'レースID': '202345101002'}
# {'会場': '川崎', 'レース番号': '3R', 'レースID': '202345101003'}
# {'会場': '川崎', 'レース番号': '4R', 'レースID': '202345101004'}
# {'会場': '川崎', 'レース番号': '5R', 'レースID': '202345101005'}
# {'会場': '川崎', 'レース番号': '6R', 'レースID': '202345101006'}
# {'会場': '川崎', 'レース番号': '7R', 'レースID': '202345101007'}
# {'会場': '川崎', 'レース番号': '8R', 'レースID': '202345101008'}
# {'会場': '川崎', 'レース番号': '9R', 'レースID': '202345101009'}
# {'会場': '川崎', 'レース番号': '10R', 'レースID': '202345101010'}
# {'会場': '川崎', 'レース番号': '11R', 'レースID': '202345101011'}
# {'会場': '川崎', 'レース番号': '12R', 'レースID': '202345101012'}
# {'会場': '門別', 'レース番号': '1R', 'レースID': '202330101001'}
# {'会場': '門別', 'レース番号': '2R', 'レースID': '202330101002'}
# {'会場': '門別', 'レース番号': '3R', 'レースID': '202330101003'}
# {'会場': '門別', 'レース番号': '4R', 'レースID': '202330101004'}
# {'会場': '門別', 'レース番号': '5R', 'レースID': '202330101005'}
# {'会場': '門別', 'レース番号': '6R', 'レースID': '202330101006'}
# {'会場': '門別', 'レース番号': '7R', 'レースID': '202330101007'}
# {'会場': '門別', 'レース番号': '8R', 'レースID': '202330101008'}
# {'会場': '門別', 'レース番号': '9R', 'レースID': '202330101009'}
# {'会場': '門別', 'レース番号': '10R', 'レースID': '202330101010'}
# {'会場': '門別', 'レース番号': '11R', 'レースID': '202330101011'}
# {'会場': '門別', 'レース番号': '12R', 'レースID': '202330101012'}
# {'会場': '笠松', 'レース番号': '1R', 'レースID': '202347101001'}
# {'会場': '笠松', 'レース番号': '2R', 'レースID': '202347101002'}
# {'会場': '笠松', 'レース番号': '3R', 'レースID': '202347101003'}
# {'会場': '笠松', 'レース番号': '4R', 'レースID': '202347101004'}
# {'会場': '笠松', 'レース番号': '5R', 'レースID': '202347101005'}
# {'会場': '笠松', 'レース番号': '6R', 'レースID': '202347101006'}
# {'会場': '笠松', 'レース番号': '7R', 'レースID': '202347101007'}
# {'会場': '笠松', 'レース番号': '8R', 'レースID': '202347101008'}
# {'会場': '笠松', 'レース番号': '9R', 'レースID': '202347101009'}
# {'会場': '笠松', 'レース番号': '10R', 'レースID': '202347101010'}
# {'会場': '金沢', 'レース番号': '1R', 'レースID': '202346101001'}
# {'会場': '金沢', 'レース番号': '2R', 'レースID': '202346101002'}
# {'会場': '金沢', 'レース番号': '3R', 'レースID': '202346101003'}
# {'会場': '金沢', 'レース番号': '4R', 'レースID': '202346101004'}
# {'会場': '金沢', 'レース番号': '5R', 'レースID': '202346101005'}
# {'会場': '金沢', 'レース番号': '6R', 'レースID': '202346101006'}
# {'会場': '金沢', 'レース番号': '7R', 'レースID': '202346101007'}
# {'会場': '金沢', 'レース番号': '8R', 'レースID': '202346101008'}
# {'会場': '金沢', 'レース番号': '9R', 'レースID': '202346101009'}
# {'会場': '金沢', 'レース番号': '10R', 'レースID': '202346101010'}
# {'会場': '金沢', 'レース番号': '11R', 'レースID': '202346101011'}
# {'会場': '金沢', 'レース番号': '12R', 'レースID': '202346101012'}
# {'会場': '盛岡', 'レース番号': '1R', 'レースID': '202335101001'}
# {'会場': '盛岡', 'レース番号': '2R', 'レースID': '202335101002'}
# {'会場': '盛岡', 'レース番号': '3R', 'レースID': '202335101003'}
# {'会場': '盛岡', 'レース番号': '4R', 'レースID': '202335101004'}
# {'会場': '盛岡', 'レース番号': '5R', 'レースID': '202335101005'}
# {'会場': '盛岡', 'レース番号': '6R', 'レースID': '202335101006'}
# {'会場': '盛岡', 'レース番号': '7R', 'レースID': '202335101007'}
# {'会場': '盛岡', 'レース番号': '8R', 'レースID': '202335101008'}
# {'会場': '盛岡', 'レース番号': '9R', 'レースID': '202335101009'}
# {'会場': '盛岡', 'レース番号': '10R', 'レースID': '202335101010'}
# {'会場': '盛岡', 'レース番号': '11R', 'レースID': '202335101011'}
# {'会場': '盛岡', 'レース番号': '12R', 'レースID': '202335101012'}

# %%
import streamlit as st

# 上記のコードで取得したrace_dataを使用

venues = list(set([data['会場'] for data in race_data]))
selected_venue = st.selectbox('会場を選択:', venues)

race_numbers = [data['レース番号'] for data in race_data if data['会場'] == selected_venue]
selected_race_number = st.selectbox('レース番号を選択:', race_numbers)

if st.button('URLを表示'):
    for data in race_data:
        if data['会場'] == selected_venue and data['レース番号'] == selected_race_number:
            st.write(f"https://yoso.netkeiba.com/nar/?pid=race_yoso_list&race_id={data['レースID']}")
# Out:
# 2023-10-10 17:13:29.686
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\kawam\miniforge3\envs\jra-van\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]

# %%
# # レース番号の取得
# race_numbers = [div.text.strip() for div in soup.select('div.Race_Num > span')]

# %%
# race_numbers
# Out:
# ['1R',
#  '2R',
#  '3R',
#  '4R',
#  '5R',
#  '6R',
#  '7R',
#  '8R',
#  '9R',
#  '10R',
#  '11R',
#  '12R',
#  '1R',
#  '2R',
#  '3R',
#  '4R',
#  '5R',
#  '6R',
#  '7R',
#  '8R',
#  '9R',
#  '10R',
#  '11R',
#  '1R',
#  '2R',
#  '3R',
#  '4R',
#  '5R',
#  '6R',
#  '7R',
#  '8R',
#  '9R',
#  '10R',
#  '11R',
#  '12R']

# %%
# 会場の取得
venues = [li.a.text.strip() for li in soup.select('ul.RaceList_ProvinceSelect li')]
venues
# Out:
# ['盛岡', '川崎', '帯広(ば)']

# %%
driver.quit()  # ブラウザを閉じる
