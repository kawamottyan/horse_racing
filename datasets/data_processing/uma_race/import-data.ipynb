# %% [markdown]
# # preparation

# %%
import pandas as pd
import psycopg2
import configparser

# %% [markdown]
# # postgres to local

# %%
config = configparser.ConfigParser()
config.read('../../../config.ini')

user = config['postgresql']['user']
password = config['postgresql']['password']
host = config['postgresql']['host']
database = config['postgresql']['database']

connection_string = f"postgresql://{user}:{password}@{host}/{database}"

# %%
# PostgreSQLに接続
# %load_ext sql
# %sql $connection_string

# %%
# %%sql
# SELECT *
# FROM jvd_se
# LIMIT 5;
# Out:
#  * postgresql://postgres:***@localhost/pckeiba
# 5 rows affected.
# ...

# %%
# SQLクエリを実行し、指定したカラムを取得
j_uma_race_sql = %sql SELECT * FROM jvd_se WHERE CAST(kaisai_nen AS INTEGER) >= 2010;
n_uma_race_sql = %sql SELECT * FROM nvd_se WHERE CAST(kaisai_nen AS INTEGER) >= 2010;

# 結果をDataFrameに変換
j_uma_race_df = pd.DataFrame(j_uma_race_sql)
n_uma_race_df = pd.DataFrame(n_uma_race_sql)
j_uma_race_df.info()
# Out:
#  * postgresql://postgres:***@localhost/pckeiba
# 1071455 rows affected.
#  * postgresql://postgres:***@localhost/pckeiba
# 2042541 rows affected.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1071455 entries, 0 to 1071454
# Data columns (total 70 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   record_id                    1071455 non-null  object
#  1   data_kubun                   1071455 non-null  object
#  2   data_sakusei_nengappi        1071455 non-null  object
#  3   kaisai_nen                   1071455 non-null  object
#  4   kaisai_tsukihi               1071455 non-null  object
#  5   keibajo_code                 1071455 non-null  object
#  6   kaisai_kai                   1071455 non-null  object
#  7   kaisai_nichime               1071455 non-null  object
#  8   race_bango                   1071455 non-null  object
#  9   wakuban                      1071455 non-null  object
# ...

# %% [markdown]
# # save as pickle

# %%
j_uma_race_df.to_pickle('../../traindata/rawdata/j_uma_race.pkl')
n_uma_race_df.to_pickle('../../traindata/rawdata/n_uma_race.pkl')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 j_uma_race_df.to_pickle('../../traindata/rawdata/j_uma_race.pkl')
#       2 n_uma_race_df.to_pickle('../../traindata/rawdata/n_uma_race.pkl')
#
# File ~\miniforge3\envs\jra-van\lib\site-packages\pandas\core\generic.py:2955, in NDFrame.to_pickle(self, path, compression, protocol, storage_options)
#    2903 """
#    2904 Pickle (serialize) object to file.
#    2905
#    (...)
#    2951 4    4    9
#    2952 """  # noqa: E501
#    2953 from pandas.io.pickle import to_pickle
# -> 2955 to_pickle(
#    2956     self,
#    2957     path,
#    2958     compression=compression,
#    2959     protocol=protocol,
#    2960     storage_options=storage_options,
#    2961 )
#
# ...
